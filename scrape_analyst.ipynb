# %%
import requests
import bs4
from bs4 import BeautifulSoup as bs
import pandas as pd
from splinter import Browser
import os
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

max_page = 670

jobs11 = []
companies11 = []
locations11 = []
summaries11 = []

for start in range(0, max_page, 10):
    indeed_url = 'http://www.indeed.com/jobs?q=data%20analyst&l=California&start=' + str(start)
    browser.visit(indeed_url)
    time.sleep(5)  
    html = browser.html
    soup = bs(html, "html.parser")
    print(indeed_url)  
    
    #grabbing job title
    #for div in soup.find_all(name='div', attrs={'class':'job_seen_beacon'}):
    for td in soup.find_all(name='td', attrs={'class':'resultContent'}):
        for div in td.find_all(name='div', attrs={'class':'heading4 color-text-primary singleLineTitle tapItem-gutter'}):
            for span in div.find_all(name='span'):
                if span.text.strip() != 'new':
                    jobs11.append(span.text.strip())  

    #grabbing company name
    for td2 in soup.find_all(name='td', attrs={'class':'resultContent'}):
        for div2 in td2.find_all(name='div', attrs={'class':'heading6 company_location tapItem-gutter'}):
            for span2 in div2.find_all(name='span', attrs={'class':'companyName'}):
                companies11.append(span2.text.strip())      

    #grabbing location
    for td3 in soup.find_all(name='td', attrs={'class':'resultContent'}):
        for div3 in td3.find_all(name='div', attrs={'class':'heading6 company_location tapItem-gutter'}):
            for div4 in div3.find_all(name='div'):
                locations11.append(div4.text.strip())   

    #grabbing summary text
    divs = soup.findAll('div', attrs={'class': 'job-snippet'})
    for div5 in divs:
        summaries11.append(div5.text.strip())

browser.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST driver version for 92.0.4515
# Driver [C:\Users\SC\.wdm\drivers\chromedriver\win32\92.0.4515.107\chromedriver.exe] found in cache
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=0
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=10
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=20
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=30
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=40
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=50
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=60
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=70
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=80
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=90
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=100
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=110
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=120
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=130
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=140
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=150
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=160
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=170
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=180
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=190
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=200
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=210
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=220
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=230
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=240
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=250
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=260
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=270
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=280
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=290
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=300
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=310
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=320
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=330
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=340
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=350
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=360
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=370
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=380
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=390
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=400
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=410
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=420
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=430
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=440
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=450
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=460
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=470
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=480
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=490
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=500
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=510
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=520
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=530
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=540
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=550
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=560
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=570
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=580
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=590
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=600
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=610
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=620
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=630
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=640
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=650
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=660

# %%
jobs11
# Out:
# ['Data Analyst - YouTube',
#  'Marketing Data Analyst (REMOTE)',
#  'Entry Level Data Analyst',
#  'Entry Level - Data Engineer / Data Analyst (STEM)',
#  'Data Analyst/Data Engineer',
#  'Data Analyst',
#  'Data Analyst (Full Time) United States',
#  'Consumer Insight Analyst',
#  'Entry Level Data Analyst',
#  'Data Analyst with Tableau',
#  'Senior Data Analyst',
#  'Data Analyst I',
#  '118: Sr Marketing Data/Business Analyst',
#  'Research Data Analyst',
#  'Data & Reporting Specialist',
#  '118: Sr Marketing Data/Business Analyst',
#  'Research Data Analyst',
#  'Data & Reporting Specialist',
#  'Marketing Data Analyst',
#  'Junior Data Analyst',
#  'Jr Data Analyst / Technician',
#  'Business Analyst I',
#  'Sr. Data Analyst',
#  'Management Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Business Data Analyst - Abbott Diabetes Care',
#  'Data Analyst',
#  'Data Modeling Analyst',
#  'Global Operations Data Center Analyst',
#  'Data Analyst',
#  'Business Analyst I',
#  'Data Analyst',
#  'Healthcare Data Analyst',
#  'Associate Analyst, Data Analytics',
#  'Data Analyst',
#  'Trust & Safety Analyst',
#  '120: Sr Marketing Analyst / Data Scientist',
#  'YMCA CSS Research & Data Analyst',
#  'Research Analyst IV',
#  'Healthcare Data Analyst',
#  'Disney: Data Analyst',
#  'Data Analyst - Law Enforcement Response Enablement',
#  'Business Analyst',
#  'IRS Pathways Recent Graduate Program (Management and Program...',
#  'Business Analyst I',
#  'Data Analyst, Operations',
#  'Business Analyst I',
#  'Data Analyst',
#  'TikTok LIVE Data Analyst',
#  'Research Data Analyst 2 (One Year Fixed Term)',
#  'PROGRAM ANALYST',
#  'Data Analyst MONGO DB Required',
#  'Management Analyst I/II',
#  'Data Analyst',
#  'Data Analyst 3 : 21-04964',
#  'Data Science Analyst II',
#  'Data Analyst',
#  'Data Analyst, Reconciliation',
#  'Data Analyst',
#  'Forecasting Analyst',
#  'Sr. Data Analyst',
#  'Business Analyst I',
#  'Assistant Data Analyst- COVID 19 Response (Contract)',
#  'Business Analyst',
#  'Data Analyst',
#  'Sr Clinical Data Analyst',
#  'PRINCIPAL HUMAN RESOURCES ANALYST (H.E.A.R. OFFICE)',
#  'Supply Chain Analyst',
#  'HR Data Analyst',
#  'Marketing Specialist - Data Analyst',
#  'Consulting Data Analyst',
#  'Senior Data Analyst - Revenue Management',
#  'Data Analyst',
#  'Compliance Data Analyst - Work From Home',
#  'Data Analyst',
#  'Compliance Data Analyst - Work From Home',
#  'Business Analyst I',
#  'Staff Analyst, Production Data & Analytics',
#  'Data Analyst, Community Operations',
#  'Business Analyst (Full Time) United States',
#  'Business Analyst - Full Time',
#  'Data Analyst',
#  'Input Data Analyst',
#  'Analyst, Data (Remote)',
#  'Business Intelligence Analyst 4',
#  'Data Analyst (Remote) - 20668',
#  'Data Analyst, Product',
#  'Jr. Data Analyst, ETL',
#  'Data Analyst II - Telecommute',
#  'BI Analyst-SQL ( Power BI)',
#  'Student Success Support Analyst',
#  'Associate Performance Analyst (System)',
#  'Business Analyst I',
#  'Data Entry Analyst',
#  'Business Data Analyst',
#  'Data Analyst',
#  'Research Data Analyst (6256U) 19103',
#  'Junior Analyst',
#  'Data Analytics Associate',
#  'Research Data Analyst',
#  'Entry Level Business Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Business Analyst: Level 1',
#  'Data Analyst',
#  'Management and Program Analyst',
#  'Data Analyst',
#  'DreamWorks Technology - Data Analyst',
#  'Business Data Analyst',
#  'Online Marketing Analyst',
#  'Research Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data / Media Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Science Analyst',
#  'Data Analyst / Data Engineer',
#  'Business/Data/Quality Analyst',
#  'Research Analyst',
#  'Senior Data Analyst (Marketing)',
#  'Data Analyst',
#  'Business Analyst',
#  'Jr. Data Analyst',
#  'Jr. Data Analyst, Strategic Analytics',
#  'Data Analyst, Systems',
#  'Senior Data Analyst-Marketing',
#  'Healthcare Data Analyst I',
#  'IT Data Analyst 2022',
#  'Data Management Analyst',
#  'Data Analyst, Manufacturing Quality',
#  'Data Analyst 3',
#  'Business Analyst',
#  'Business Analyst',
#  'Master Data Analyst',
#  'Analyst, Data Management',
#  'Sr. Data Analyst',
#  'Sr. Data Analyst',
#  'Data Analyst - Talent Operations',
#  'Product Data Analyst',
#  'Analyst, Data & Reporting',
#  'Data Analyst',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'DATA ANALYST',
#  'Data Analyst',
#  'Data Analyst - US',
#  'Research Data Analyst (6256U) 19103',
#  'Data Analyst',
#  'Data Analyst',
#  'E-Commerce Data Analyst',
#  'Sr. BI Data Analyst / Developer',
#  'Data Analyst, Analytics - Community',
#  'Data Analyst',
#  'Product Data Analyst',
#  'Product Data Analyst',
#  'Data Analyst',
#  'Sr. Data Analyst / Architect',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Business Data Analyst',
#  'Senior Data Analyst',
#  'Growth Analyst',
#  'Junior Data Analyst',
#  'Contact Master Data Analyst',
#  'YMCA CSS Research & Data Analyst',
#  'Data Analyst I',
#  'Senior Data Analyst, Product Insights',
#  'Sr Data Analyst',
#  'Data Informatics Analyst',
#  'Game Data Analyst',
#  'Data Analyst, Design Technology',
#  'Visual Data Analyst - Kaiser Permanente Bernard J. Tyson Sch...',
#  'Senior Data Analyst : 21-04928',
#  'Business Analyst',
#  'Senior BI Data Analyst - REMOTE',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Sr Clinical Data Analyst',
#  'Sr. Data Analyst, Services',
#  'Data Analyst',
#  'Data Analyst',
#  'Senior Data Insights Analyst',
#  'Sr. Data Analyst-Product',
#  'Data Analyst, Analytics - Community',
#  'Senior Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Management Analyst',
#  'Data Integrity Analyst I',
#  'Logistics Data Analyst',
#  'Data Analyst',
#  'Data Quality Analyst',
#  'data analyst',
#  'Sr. Data Analyst / Architect',
#  'Senior BI Data Analyst - REMOTE',
#  'Performance Marketing Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst - Precision Medicine',
#  'Data Analyst - Talent Operations',
#  'Sr. Data Analyst',
#  'Sr. Data Analyst, Services',
#  'Data Analyst',
#  'Business Analyst, FACET Project',
#  'Senior Data Analyst',
#  'People Data Analyst',
#  'DreamWorks Technology - Data Analyst',
#  'Sr Clinical Data Analyst',
#  'DATA ANALYST',
#  'Data Conversion Analyst - 32419894',
#  'Data Analyst',
#  'Data Analyst',
#  'Financial Data Analyst',
#  'Data Analyst, Analytics - Community',
#  'BI Analyst',
#  'Sr. Associate Data Analyst',
#  'Senior Data Analyst : 21-04928',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Data Analyst - Law Enforcement Response Enablement',
#  'Data Analyst, Design Technology',
#  'Data Analyst',
#  'Data Analyst',
#  'Quality Master Data Analyst',
#  'data analyst',
#  'Data Analyst/Data Mining Specialist',
#  'Data Analyst',
#  'Data Analyst, Content & Viewership',
#  'Business Analyst',
#  'Data Quality Analyst',
#  'Data Science Analyst',
#  'Clinical Data Analyst II',
#  'Data Analytics Associate',
#  'Data Analyst - MS Access / Excel',
#  'Data Analyst, Analytics - Community',
#  'Sr. Data Analyst',
#  'Assistant Data Analyst- COVID 19 Response (Contract)',
#  'Senior Data Analyst_Marketing',
#  'Data Analyst, Content & Viewership',
#  'Data Quality Analyst',
#  'Sales Data Analyst - Digital Distribution',
#  'Data Analyst, Artist Insights',
#  'Data Consultant',
#  'Senior Data Analyst, Point of Sale & Customers',
#  'Data Analyst',
#  'Data Analyst',
#  'SEM Energy Data Analyst',
#  'Data Analyst',
#  'Online Marketing Analyst',
#  'Data Analyst (SF)',
#  'Assistant Research Data Analyst',
#  'Senior Data Analyst',
#  'Healthcare Data Analyst',
#  'Junior Analyst',
#  'Business Intelligence Analyst 4',
#  'Data Analyst',
#  'Data Analyst, Content & Viewership',
#  'BI Analyst',
#  'Data Analyst',
#  'Data Analyst, current Public Trust Clearance preferred',
#  'Data Analyst / Enginner',
#  'Master Data Analyst',
#  'Analyst, Data Management',
#  'Data Analyst - Strategic Analytics',
#  'Security and Abuse Data Analyst, Safe Browsing',
#  'Data Analyst, current Public Trust Clearance preferred',
#  'Marketing Data Analyst',
#  'Sr. Data Analyst',
#  'Quality Data Analyst',
#  'Senior Data Analyst',
#  'Associate Performance Analyst (System)',
#  'Data Analyst',
#  'Sales Data Analyst - Digital Distribution',
#  'Senior Data Analyst',
#  'Senior Data Analyst, Point of Sale & Customers',
#  'Data Visualization Specialist III - MicroStrategy',
#  'Clinical Data Analyst II',
#  'Data Analyst',
#  'Data Analyst - Remote',
#  'IA5 - Data & Impact Analyst',
#  'Senior BI Data Analyst - REMOTE',
#  'Data Analyst',
#  'MRM Data Science & Reporting Analyst',
#  'IT Jr. Business Analyst',
#  'Data Quality Analyst',
#  'Sr. Data Analyst',
#  'Business Analyst',
#  'Data Analyst - Creator',
#  'Data Analyst - US',
#  'Data Analysts',
#  'Promo & Content Data Analyst, Peacock On-Product Promotion',
#  'Data Analyst',
#  'Data Analyst',
#  'Gift Processing and Data Analytics Specialist, University Ad...',
#  'Data Analyst Norwegian A799',
#  'Data Analyst',
#  'Player Support Analyst',
#  'Data Entry Analyst',
#  'Data Analyst',
#  'Data Management Analyst',
#  'Business Analyst',
#  'Product Data Analyst',
#  'Senior Data Analyst',
#  'Master Data Analyst II',
#  'Business Analyst',
#  'Sr. Data Science Analyst',
#  'Contact Master Data Analyst',
#  'Data Analyst',
#  'MRM Data Science & Reporting Analyst',
#  'Data Analyst, Manufacturing Quality',
#  'Logistics Data Analyst',
#  'DATA ANALYST',
#  'Intermediate Corporate Data Analyst',
#  'Sr. Data Analyst-Product',
#  'Programmer Analyst I/II',
#  'Business Intelligence Analyst 4',
#  'SQL Developer/Data Analyst',
#  'Senior Data Analyst',
#  'Operations Data Analyst',
#  'Business Analyst, Hive Models',
#  'MRM Data Science & Reporting Analyst',
#  'DHM Data Analyst',
#  'Content & Data Analyst',
#  'Data Analyst',
#  'SR Data Analyst',
#  'Creator Operations - Marketplace Operation Business Analyst',
#  'Senior Data Analyst',
#  'Data Operations Analyst — Remote',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Payment Ops & Risk Data Analyst',
#  'Quality Data Analyst',
#  'Data Visualization Specialist III - MicroStrategy',
#  'Sr. Data Analyst',
#  'Data Analyst - 0.8 - Days - Concern: EAP',
#  'Data Analyst- Field Reliability',
#  'Data Analyst',
#  'Data Analyst, current Public Trust Clearance preferred',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Gift Processing and Data Analytics Specialist, University Ad...',
#  'Data Analyst - 0.8 - Days - Concern: EAP',
#  'Data Analyst',
#  'Mobile Growth Analyst/Data scientist : 21-04149',
#  'Player Support Analyst',
#  'Lead Data Analyst',
#  'Data Analyst II',
#  'Associate Data Analyst',
#  'Management Analyst',
#  'Data Analyst - Tiktok Ads',
#  'Quality Master Data Analyst',
#  'Data Analyst, Product',
#  'Senior Data Analyst : 21-04928',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst, Product',
#  'Quality Master Data Analyst',
#  'Data Analyst I',
#  'Data Analyst',
#  'Water Quality Analyst I',
#  'Analyst I',
#  'Data Analyst - Tiktok Ads',
#  'BI Data Analyst',
#  'Financial Data Analyst',
#  'Data Analyst',
#  'Business Insights Analyst',
#  'PROGRAM ANALYST',
#  'Data Analyst - 0.8 - Days - Concern: EAP',
#  'Trauma Data Associate',
#  'Customer Experience Operations Data Analyst',
#  'Data Labeling Analyst - Portuguese/Spanish',
#  'Business Analyst',
#  'Associate Logistics Data Analyst',
#  'Decision Support Analyst, Full Time, Day Shift, Accountable...',
#  'Data Analyst',
#  'Programmer Analyst (5 month limited appointment)',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Data Analyst, US & Canada Analytics & Insights - CommOps',
#  'Senior Data Analyst - Santa Ana, CA or Minnetonka, MN',
#  'Data Analyst',
#  'Management and Program Analyst',
#  'Data and Policy Analyst - Writer/Coordinator',
#  'Data Analyst, US & Canada Analytics & Insights - CommOps',
#  'Associate Data Science Analyst',
#  'Marketing Data Analyst',
#  'Data Analyst, Applied Agronomics',
#  'Business Analyst I/II',
#  'Data Analyst 2',
#  'Senior Data Analyst, Product Insights',
#  'Data Analyst (SQL)• Global Logistics',
#  'Gift Processing and Data Analytics Specialist, University Ad...',
#  'Senior Business Analyst',
#  'Data Conversion Analyst - 32419894',
#  'Data Analyst',
#  'Water Quality Analyst I',
#  'Metrics and Data Analyst',
#  'Master Data Analyst',
#  'Data Analyst, Product',
#  'Trauma Data Associate',
#  'Senior Data Analyst - Santa Ana, CA or Minnetonka, MN',
#  'Business Analyst (DOM)',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Processing Analyst',
#  'Senior Data Analyst, Business Analytics',
#  'Business Analyst/Associate',
#  'Data Analyst',
#  'Business Analyst, Hive Models',
#  'Creator Operations - Marketplace Operation Business Analyst',
#  'Data Analyst',
#  'Gift Processing and Data Analytics Specialist, University Ad...',
#  'Business Analyst (Full Time) United States',
#  'Data Analyst - Strategic Analytics',
#  'Business Analyst I',
#  'Operations Data Analyst',
#  'Data Analyst',
#  'Donor Data Management Analyst (Remote)',
#  'Business Intelligence Analyst',
#  'Student Success Support Analyst',
#  'Entry Level Business Analyst',
#  'Junior Business Analyst',
#  'Data Governance Analyst',
#  'Business Intelligence Analyst - Fully Remote Position',
#  'Jr Business Analyst',
#  'LMS Business Analyst',
#  'Analyst, Data Ops',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst (Ryan White)',
#  'Data Visualization Specialist III - MicroStrategy',
#  'Data Modeling Analyst Sr.',
#  'Data Analyst',
#  'Data Analyst – Automotive Analytics & Advisory',
#  'Business Analyst',
#  'Business Analyst',
#  'Business Analyst, Recent Graduate',
#  'Data Analyst / Senior Data Analyst',
#  'Sr Analyst, Business Insights',
#  'Business Intelligence Analyst',
#  'Data Conversion Analyst - 32419894',
#  'BI Analyst',
#  'BI Data Analyst',
#  'Business Analyst I',
#  'Climate Data Analyst',
#  'Business Analyst',
#  'Associate Data Analyst',
#  'Data Analyst',
#  'Business Analyst',
#  'Research Analyst',
#  'Senior Data Insights Analyst',
#  'Sr. Data Analyst, Services',
#  'Senior Data Analyst, Advanced Analytics',
#  'Senior Data Analyst',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Sr. Data Science Analyst',
#  'Retention and Platform Product Data Analyst (Remote)',
#  'Business Analyst I',
#  'Data/Business Analyst',
#  'Business Analyst - Flexible Location',
#  'HR Data Analyst',
#  'Data Analyst',
#  'Data Analyst (Growth Marketing)',
#  'Machine Learning Data Associate',
#  'Senior Data Analyst',
#  'Data and Reporting Specialist – Remote',
#  'Data Analyst',
#  'Pharma Business Analyst / Process Modeler',
#  'Business Analyst',
#  'RMA Data Analyst',
#  'Sr People Data Analyst',
#  'Business Analyst',
#  'Data Analyst, Basketball Operations',
#  'Analyst',
#  'Data Analyst - Next Generation Sequencing',
#  'Data Analyst',
#  'Senior Data Modeling Analyst',
#  'Business/Data/Quality Analyst',
#  'Data Analyst and Processor - Lead Records Administrator',
#  'Data Analytics Analyst',
#  'Business Data Analyst',
#  'Data Operations Analyst — Remote',
#  'Business Analyst I',
#  'Business Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analytics Analyst',
#  'Data Analyst Level 2 - 21-02033',
#  'Business Analyst',
#  'Lead Data Analyst',
#  'Senior Data Analyst',
#  'Category Analyst - Entry Level',
#  'LMS Business Analyst',
#  'SAP Sr Master Data Functional Analyst',
#  'Associate Logistics Data Analyst',
#  'Quantitative Analyst',
#  'Data & Reporting Analyst',
#  'Senior Data Analyst, Strategic Insights',
#  'Business Analyst (DOM)',
#  'Sr People Data Analyst',
#  'Senior Data Analyst - Santa Ana, CA or Minnetonka, MN',
#  'Business Analyst, Order Management - Opportunity for Working...',
#  'Business Analyst',
#  'Data Operations Analyst — Remote',
#  'Senior Data Analyst',
#  'Data Visualization Specialist',
#  'Category Analyst - Entry Level',
#  'Data Analyst - Customer Quality',
#  'Lead Data Analyst',
#  'Business Intelligence Analyst',
#  'Data Analytics Analyst',
#  'Business Intelligence Analyst III',
#  'Senior Health Data Analyst',
#  'PROGRAM ANALYST',
#  'Business Analyst',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Digital Data Analyst (Must have previous experience as an SQ...',
#  'DEPARTMENTAL ADMINISTRATIVE ANALYST',
#  'Senior Data Analyst, Travel Insights',
#  'Junior Business & Technology Analyst - Data',
#  'Marketing Data Analyst',
#  'Analyst - Western Region',
#  'Business Analyst I',
#  'Data Quality Analyst',
#  'Sr People Data Analyst',
#  'Data Analyst, Hearthstone Analytics',
#  'Human Resources Data Analyst',
#  'Finance Data Analyst, Devices and Services',
#  'Pharma Business Analyst / Process Modeler',
#  'Business Analyst',
#  'Data Analyst/Report Writer, Go to Market',
#  'Business Analyst, Hive Models',
#  'Senior Data Analyst, Growth',
#  'Business Intelligence Analyst I / II',
#  'Quantitative Analyst',
#  'Content & Data Analyst',
#  'Business Analyst - 16354',
#  'Senior Data Analyst, Market Research',
#  'Mobile Growth Analyst/Data scientist : 21-04149',
#  'Principal Data Analyst - Telecommute',
#  'Business Analyst',
#  'Data System Analyst',
#  'Business Analyst (REMOTE)',
#  'Clinical Data Analyst',
#  'Analyst, Data & Lifecycle Marketing Technology',
#  'DATA CONTROL ANALYST',
#  'LMS Business Analyst',
#  'Business Intelligence Analyst',
#  'Senior Data Analyst',
#  'Business Analyst, Data Platform Business Operations',
#  'Client Data Analyst',
#  'Business Analyst',
#  'Business Analyst',
#  'Clinical Data Analyst',
#  'Data Analyst (Informatics)',
#  'Senior Data Analyst',
#  'Media Analyst',
#  'Programmer Analyst (5 month limited appointment)',
#  'Senior Data Analyst',
#  'Business Intelligence Analyst',
#  'Business Analyst',
#  'Machine Learning Data Associate',
#  'BI Analyst',
#  'Sr. Data Analyst-Product',
#  'Business Analyst',
#  'Sr. Data Analyst',
#  'Data Insights Analyst',
#  'Social Media Data Analyst',
#  'Sales Planning Analyst',
#  'Order Processing Analyst',
#  'QC Analyst',
#  'Business Analyst (DOM)',
#  'People Analytics - (Senior Data Analyst)',
#  'IA5 - Data & Impact Analyst - Full Time - 40 Hours/Week - No...',
#  'Senior BI Analyst',
#  'IA5 - Data & Impact Analyst - Full Time - 40 Hours/Week - No...',
#  'Senior BI Analyst',
#  'Analyst I/II (Housing Department) - Eviction Help Center',
#  'Data Analyst/Report Writer',
#  'Operations Data Analyst',
#  'Data Analyst, Product',
#  'Senior Data Analyst',
#  'Supply Chain Data Analyst, Sacramento',
#  'GIS Data Analyst',
#  'Programmer Analyst I/II',
#  'Business Intelligence Analyst III',
#  'Performance Marketing Analyst',
#  'Sr, Data Analyst',
#  'Business Analyst I',
#  'Sr. Data Analyst',
#  'Senior Data Analyst - Santa Ana, CA or Minnetonka, MN',
#  'Business Analyst',
#  'Business Analyst',
#  'Senior BI Data Analyst - REMOTE',
#  'Data Analyst, WW BPR',
#  'Data Analyst / Business Incentives',
#  'Technical Data Analyst (Professional) (RN280)',
#  'Financial Data Analyst',
#  'Data Analyst (Operations Research Analyst)',
#  'Business Analyst',
#  'Business Intelligence Analyst III',
#  'RESEARCH ANALYST II, BEHAVIORAL SCIENCES',
#  'SAP Sr Master Data Functional Analyst',
#  'Data Analyst III',
#  'Business Analyst',
#  'Data Analyst - Associate / Consultant-(Temporary Remote)',
#  'Creator Operations - Marketplace Operation Business Analyst',
#  'User Acquisition Data Analyst',
#  'Healthcare Data Analyst',
#  'eCommerce Senior Data Analyst',
#  'Business Analyst',
#  'Senior Data Management Analyst',
#  'Sr.BI Analyst-remote',
#  'Data Analyst/ BI- Reporting Analyst III : 21-05006',
#  'Business Intelligence Analyst III',
#  'Sr. Business Objects Developer',
#  'Business Analyst',
#  'Junior Data Analyst with Work Life Culture',
#  'Sr. Data Analyst, Marketing',
#  'Program Data Analyst',
#  'Data Analyst - Predictive Data Science',
#  'Business Analyst - Part Time',
#  'Sr. Manager, Data Analytics',
#  'Resolution Analyst',
#  'Associate Data Analyst (temporary)',
#  'Sr Analyst, Data Analytics & Reporting',
#  'Associate Data Analyst',
#  'Senior Data Analyst',
#  'Data Analyst, Account Management',
#  'Technical Business Analyst',
#  'Business Intelligence Analyst III',
#  'Marketing Data Analyst',
#  'Info & Data Systems Analyst',
#  'Operations Data Analyst',
#  'Data Analyst, Web Analytics',
#  'Business Analyst',
#  'Senior Data Analyst, Product Insights',
#  'Donor Data Management Analyst (Remote)',
#  'Digital Business Analyst (Remote)',
#  'Business Data Analyst',
#  'Business Analyst',
#  'Data Informatics Analyst - Remote (Anywhere US)',
#  'Senior People Analyst, Data Foundations',
#  'Healthcare Data Analyst II - Finance Analytics (Remote Optio...',
#  'Development Data Analyst',
#  'Senior Data Analyst, Risk',
#  'Analyst, Research Analytics + Insights',
#  'Senior Data Analyst_Marketing',
#  'Business Intelligence Analyst - Fully Remote Position',
#  'Technical Data Analyst 2 - 1990',
#  'Data Analyst Mandarin Cantonese Language A780',
#  'Associate Data Analyst (temporary)',
#  'Data Analyst - Predictive Data Science',
#  'Senior Data Analyst, Product Insights',
#  'Business Analyst (REMOTE)',
#  'Lead Data Analyst - Core Services',
#  'Business Analyst',
#  'Data Consultant - Jr. SAS Developer',
#  'Sr. Analyst, Data Management',
#  'Human Resources Data Analyst',
#  'Risk Business Analyst',
#  'Business Analyst',
#  'Lead Data Scientist - Analyst',
#  'HR Data Analyst',
#  'Analyst, Paid Search',
#  'Analyst, Paid Search',
#  'Business Analyst',
#  'Business Analyst',
#  'Data Analyst- COVID 19 Response (Contract)',
#  'Payment Ops & Risk Data Analyst',
#  'Senior Business Analyst',
#  'Associate Business Analyst',
#  'Sr Analyst, Data Analytics & Reporting',
#  'Business Intelligence Analyst - Data',
#  'Data and Reporting Specialist – Remote',
#  'Client Data Analyst',
#  'Sr. Business Analyst',
#  'Business Analyst',
#  'Digital Business Analyst (Remote)',
#  'Senior Data Analyst, FCRA',
#  'Senior Data Analytics Analyst',
#  'Development Data Analyst',
#  'Business Intelligence Analyst',
#  'Technical Business Analyst',
#  'Sr. Business Analyst - Data & Reporting, Cupertino',
#  'Data Analyst - Ads Revenue Accounting',
#  'Technical Data Analyst',
#  'Senior Data Analyst_Marketing',
#  'Technical Data Analyst 2 - 1990',
#  'Supply Chain Data Analyst, Sacramento',
#  'Sr. Marketing Data Analyst',
#  'Business Analyst - Temp',
#  'Data Analyst and Processor - Lead Records Administrator',
#  'Program Analyst (Space Operations)',
#  'Business Analyst',
#  'E-Commerce Analyst (FV)',
#  'Business Intelligence Analyst',
#  'Sr. Analyst, Data Management',
#  'Media Analyst',
#  'Business Intelligence Analyst, Broadcast Media Analytics',
#  'Data Analyst, AUM Reporting Operations',
#  'Business Analyst, Sunnyvale Manufacturing',
#  'Business Analyst',
#  'Business Intelligence Analyst',
#  'Health Data Analyst',
#  'Data System Analyst',
#  'Data Quality Analyst',
#  'Data Analyst II',
#  'Senior Data Analyst (Product)',
#  'Mobile Growth Analyst/Data scientist : 21-04149',
#  'Data Conversion Analyst - 32419894',
#  'IAG Data Management Analyst',
#  'Business/Data Analyst',
#  'Sr. Business Analyst - Data & Reporting, Cupertino',
#  'Supply Chain Analyst',
#  'Business Analyst I',
#  'Business Analyst',
#  'Data Analyst',
#  'Lead Data Scientist - Analyst',
#  'Business Intelligence Analyst',
#  'Business Analyst - 16354',
#  'Senior Data Analyst - Product Consumption Analytics',
#  'Business Intelligence Analyst',
#  'Data Analyst/ BI- Reporting Analyst III : 21-05006',
#  'Data Analyst- COVID 19 Response (Contract)',
#  'Sr Analyst, Data Analytics & Reporting',
#  'Market Research Analyst',
#  'Student Success Support Analyst',
#  'Sr. Business Objects Developer',
#  'Business Data Analyst',
#  'BI Business Analyst',
#  'Senior Data Analyst, FCRA',
#  'Business Analyst',
#  'Customer Intelligence Analyst - Opportunity for Working Remo...',
#  'Marketing Technology Data Analyst',
#  'Marketplace Strategy & Operations Analyst (Demand) - Remote',
#  'Business Intelligence Analyst',
#  'Sr. Marketing Data Analyst',
#  'Marketing Data Analyst',
#  'Data Consultant - Jr. SAS Developer',
#  'Sr. Business Objects Developer',
#  'Data Analyst - IT',
#  'Data Analyst Coordinator - Case Management',
#  'Supply Chain Analyst',
#  'Data Analyst 1LOD',
#  'Data Analyst',
#  'CUSTOMER DATA ANALYST',
#  'Sr. Business Analyst',
#  'Senior Financial Data Analyst',
#  'Data Analyst - NO C2C - Only US Citizen/Green Card',
#  'BI Business Analyst',
#  'Data Analyst, Web Analytics',
#  'Data Analyst/Report Developer',
#  'Data Analyst, Product Support Operations',
#  'Preclinical Business Analyst',
#  'Business Intelligence Analyst',
#  'Data Specialist',
#  'Sales Data Analyst',
#  'Senior Business Intelligence Analyst',
#  'Business Analyst',
#  'Sr. Business Analyst',
#  'Senior Data Analyst - Data Governance Tool Analyst, Data Cat...',
#  'Data Analyst- COVID 19 Response (Contract)',
#  'Tableau Analyst, Junior',
#  'Business Analyst',
#  'Lead Data Analyst',
#  'Business Analyst I',
#  'Marketing Operations Data Analyst',
#  'Senior Enterprise Data Governance Analyst',
#  'Business Intelligence Analyst',
#  'CUSTOMER DATA ANALYST',
#  'Sr. Business Objects Developer',
#  'Data Visualization Specialist',
#  'Finance Data Analyst, Devices and Services',
#  'Senior Data Analyst',
#  'Scholarship Analyst',
#  'Digital Business Analyst (Remote)',
#  'Data Analyst - Data Science & Analytics (AX)',
#  'Business Analyst',
#  'Business Analyst (Utilities)',
#  'Sr. Analyst, Data Management',
#  'Data Analyst, Product Support Operations',
#  'Business Analyst I',
#  'Business Intelligence Analyst',
#  'Sales Data Analyst',
#  'Senior Data Analyst',
#  'Business Analyst',
#  'Business Analyst',
#  'Analyst – Digital & Data Analytics Practice (Full Stack',
#  'CRA Data & Reporting Analyst',
#  'GIS Business Analyst',
#  'Healthcare Data Analyst',
#  'Senior Data Analyst (Marketing)',
#  'Marketing Data Analyst III',
#  'Construction Data Analyst',
#  'Business Intelligence Analyst',
#  'Diversity Supplier Spend Data Analyst',
#  'Senior Analyst, Content Analytics',
#  'BUSINESS ANALYST',
#  'SQL Reporting Analyst',
#  'Business Analyst, Trust & Safety, YouTube',
#  'Business Analyst Associate - Irvine, CA Homebuilder Services',
#  'Business Intelligence Analyst',
#  'Business Intelligence Analyst',
#  'Junior Business Analyst (Kyiv, Ukraine)',
#  'Business Analyst',
#  'Junior Business Intelligence Analyst',
#  'Business Intelligence Analyst- CPWS',
#  'Business Intelligence Analyst',
#  'PROGRAM ANALYST',
#  'Sr. Survey Data Analyst',
#  'Senior Data Analyst - Product Consumption Analytics',
#  'BUSINESS ANALYST',
#  'Business Analyst',
#  'Senior Data Analyst (Marketing)',
#  'ERP & BI Lead Business Analyst',
#  'Senior Enterprise Data Governance Analyst',
#  'Associate Data Analyst',
#  'Business Intelligence Analyst',
#  'Senior Data Analyst - Inservice Education',
#  'Data Analyst, Collections',
#  'Data Analyst, Unannounced Project (Mobile)',
#  'Data Analyst',
#  'Business Analyst',
#  'Senior Data Analyst, Trust & Safety',
#  'Data Analyst, Digital Investigations Team - (B4)',
#  'Diversity Supplier Spend Data Analyst',
#  'Data Coordinator- Business Intelligence',
#  'Senior Business Analyst',
#  'Marketplace Strategy & Operations Analyst (Demand) - Remote',
#  'Performance Analyst (System), Marketing, Data Mapping',
#  'Business Analyst',
#  'Business Intelligence Analyst',
#  'Business Research Analyst',
#  'Battery Data Analyst',
#  'Sr. BI Analyst',
#  'Data Analyst',
#  'Data Analyst- COVID 19 Response (Contract)',
#  'Online Data Science Analyst - Apple Retail Online',
#  'Data Analyst / Business Incentives',
#  'Data Analyst, Product Analytics',
#  'MDM Analyst',
#  'Data Analyst - Data Science & Analytics (AX)',
#  'Data Analyst, Risk Operations',
#  'Business Intelligence Analyst',
#  'Consulting Data Analyst - Health Research, Statistics',
#  'Sr Data Analyst, Media Library',
#  'Senior Business Analyst, Games Growth Consultant, Google Pla...',
#  'Technical Data Analyst',
#  'Program Data Analyst',
#  'Senior Data Analyst',
#  'Construction Data Analyst',
#  'Business Analyst',
#  'Data Analyst L3',
#  'Marketing Data Analyst',
#  'Data Analyst (Collaborative Courts)',
#  'Software Business Analyst',
#  'Senior Data Analytics Analyst',
#  'Senior Analyst - Product/Data Insights',
#  'Data Analyst, Risk Operations',
#  'Senior Marketing Data Analyst',
#  'Marketing Data Analyst',
#  'Business Intelligence Analyst',
#  'Business Intelligence Analyst',
#  'PROGRAM ANALYST',
#  'Business Analyst',
#  'Senior Business Analyst with Technical Chops (Fully Remote)',
#  'Sr. Business Objects Developer',
#  'Business Analyst',
#  'Sr Lead Data Analytics Analyst',
#  'Senior Product Data Analyst',
#  'Data Analytics Consultant',
#  'Research Analyst IV',
#  'Senior Data Analyst',
#  'Senior Data Analyst, Risk',
#  'Health Data Analyst',
#  'PRO REFERRAL BUSINESS ANALYST',
#  'Business Analyst',
#  'Info & Data Systems Analyst',
#  'Risk Data Analyst',
#  'Senior Health Data Analyst',
#  'Data Specialist',
#  'Senior Data Analyst (Product)',
#  'Data Analytics Manager, Google Data Center',
#  'Business Intelligence Analyst',
#  'Data Analyst / Business Incentives',
#  'Senior Enterprise Data Governance Analyst',
#  'Healthcare Data Analyst I - Quality Systems',
#  'SAP Sr Master Data Functional Analyst',
#  'Sr. Performance Analyst (System)',
#  'Business Intelligence Analyst I / II',
#  'Quality Data Analyst',
#  'Business-Analyst',
#  'Junior Business Analyst (Kyiv, Ukraine)',
#  'Business Analyst I',
#  'Sr. Performance Analyst (System)',
#  'Senior Business Analyst , IT FT 7:30AM - 4:30PM',
#  'Assistant Staff Analyst, (Housing and Services Data Analyst)...',
#  'Clinical Quality Management Data Analyst – Out-Stationed',
#  'Senior Enterprise Data Governance Analyst',
#  'Database Analyst / SQL',
#  'Construction Data Analyst',
#  'Diversity Supplier Spend Data Analyst',
#  'Marketing Data Analyst',
#  'Business Analyst',
#  'Business Analyst- Search',
#  'Senior Data Analyst',
#  'Technical Data Analyst',
#  'Senior Data Analyst, Risk',
#  'Senior BI Analyst',
#  'Sr. Data Analyst',
#  'Sr. Survey Data Analyst – Nonpartisan Unit',
#  'Business Analyst I',
#  'Sr. Performance Analyst',
#  'Sr. Product Analyst',
#  'Database Analyst / SQL',
#  'Data Analyst, Risk Operations',
#  'BI Analyst IV (MT-2419) - Tableau',
#  'Business Intelligence Analyst - Custom Support Analytics',
#  'Business Analyst',
#  'Sr. Data Analyst',
#  'Business Intelligence Analyst',
#  'Senior Data Analyst - Product Consumption Analytics',
#  'Business Analyst - Nationwide Telecommute',
#  'BI Business Analyst',
#  'Business Analyst I',
#  'Growth Marketing Data Analyst',
#  'Administrative Data Analyst (temporary)',
#  'Data Analyst, Digital Investigations Team - (B4)',
#  'Database Analyst / SQL',
#  'Data Conversion Analyst',
#  'Procurement Analyst',
#  'Sr. Business Data Management Analyst',
#  'DEPARTMENTAL ADMINISTRATIVE ANALYST',
#  'Sr. BI Analyst',
#  'Data Analyst- COVID 19 Response (Contract)',
#  'Senior Analyst - Product/Data Insights',
#  'Business Operations Reporting Analyst',
#  'Senior Data Analyst - Healthline',
#  'Business Analyst I',
#  'Data Analyst, Unannounced Project (Mobile)',
#  '(USA) Staff Data Analyst',
#  'ITSM Junior Analyst - Navy SMIT',
#  'Application Support Analyst 1',
#  'Database Analyst / SQL',
#  'Research Analyst',
#  'Human Resources Data Analyst',
#  'Senior Environmental Sustainability Data Analyst',
#  'Salesforce Data Management and Reporting Analyst',
#  'Risk Data Analyst',
#  'FP&A Analyst',
#  'Public Safety Business Analyst',
#  'Business Analyst : 21-04958',
#  'Business Intelligence Analyst',
#  'IT Systems Analyst (Business Intelligence)',
#  'Site Optimization/Web Analyst',
#  'Business Analyst',
#  'Technical Sr Data Analyst',
#  'Data Analyst',
#  'Senior Data Analyst - Analytics, Tableau, RedShift - REMOTE',
#  'Entry Level Healthcare IT Analyst',
#  'AMP Discovery Fraud & Moderation Business Analyst - Cupertin...',
#  'Business System Analyst',
#  'Sales Data Analyst',
#  'Data Analyst (Customer Events) (JO-2108-128324)',
#  'Business Data Analyst (SIOP)',
#  'Proposal Analyst – Price/Cost Analyst',
#  'Senior Business Analyst',
#  'Retail Process & Sales Satisfaction Analyst',
#  'Medicaid/Calheers BA',
#  'Board Certified Behavior Analyst (BCBA)',
#  'SEO Analyst',
#  'Data Informatics Analyst',
#  'Data Analyst IV',
#  'Business Analyst',
#  'Business Analyst - Anaplan',
#  'Consumer Insights Analyst',
#  'Real Estate Analyst',
#  'Project Coordinator (Data Analyst)',
#  'Risk Analyst Level I - Irvine, CA - In Office Position Only',
#  'Sr. BI Analyst, Monetization (Contract-to-Hire) - Entertainm...',
#  'Performance Analyst - Value Based Care',
#  'JIRA BA',
#  'Financial Analyst Assistant - Logistics Company',
#  'Financial Analyst',
#  'Board Certified Behavior Analyst (BCBA)']

# %%
companies11
# Out:
# ['Webhelp Americas',
#  'Molina Healthcare',
#  'Insight Global',
#  'PCS Global Tech',
#  'MT Global US INC',
#  'Databricks',
#  'Cisco Systems',
#  'Disney Parks, Experiences and Products',
#  'FieldLevel',
#  'Zensar Technologies',
#  'Square',
#  'Tarzana Treatment Centers, Inc',
#  'Dataspace',
#  'Stanford University',
#  'Pearson',
#  'Dataspace',
#  'Stanford University',
#  'Pearson',
#  'Mixbook',
#  'Capgemini',
#  'Tesla',
#  'Insight Global',
#  'Yellow Jacket Inc',
#  'City of Cupertino, CA',
#  'Deckers Brands',
#  'Eisenhower Health',
#  'Abbott Laboratories',
#  'HG Insights',
#  'Experian',
#  'Salesforce',
#  'NCIRE',
#  'Insight Global',
#  'Curative Inc.',
#  'Curative Inc.',
#  'Edwards Lifesciences',
#  'TikTok',
#  'Discord',
#  'Dataspace',
#  'YMCA of San Diego County',
#  'County of Orange',
#  'American Indian Health & Services',
#  'silicon tech solutions',
#  'Snapchat',
#  'Pitney Bowes',
#  'US Internal Revenue Service',
#  'Insight Global',
#  'Trove Recommerce',
#  'Experian',
#  'zb.io',
#  'TikTok',
#  'Stanford University',
#  'US Secretary of the Navy Offices (SECNAV)',
#  'Braintrust',
#  'City of Redding',
#  'Fisher & Phillips LLP',
#  'Akraya Inc.',
#  'Experian',
#  'Ernest Packaging Solutions',
#  'Square',
#  'Shift',
#  'Google',
#  'Cool Minds LLC',
#  'Insight Global',
#  'Brilliant Corners',
#  'Agama Solutions',
#  'Activision',
#  'Cedars-Sinai Medical Center',
#  'Los Angeles County Metropolitan Transportation...',
#  'Tesla',
#  'Niagara Bottling',
#  'Sony Electronics Inc',
#  'Kaiser Permanente',
#  'Public Storage',
#  'Amazon.com Services LLC',
#  'Sutter Health',
#  'Amazon.com Services LLC',
#  'Sutter Health',
#  'Insight Global',
#  'Walt Disney Animation Studios',
#  'Facebook',
#  'Cisco Systems',
#  'Therma',
#  'ActiveVideo',
#  'Beyond Meat',
#  'Molina Healthcare',
#  'Adobe',
#  'Splunk',
#  'Trove Recommerce',
#  'Nuna',
#  'UnitedHealth Group',
#  'Triune Infomatics Inc',
#  'California State University, Long Beach',
#  'Adventist Health Roseville',
#  'Insight Global',
#  'Calbee North America',
#  'USC',
#  'Synergy Companies',
#  'University of California Berkeley',
#  'Golin',
#  'Mathematica Policy Research',
#  'University of California San Francisco',
#  'CapitalPlanHoldings',
#  'Vervent Inc',
#  'Helium 10',
#  'BAYEN GROUP',
#  'LTS',
#  'US Internal Revenue Service',
#  'QuinStreet',
#  'NBCUniversal',
#  'Digital Dhara',
#  'Match',
#  'University of California Santa Cruz',
#  'University of California San Francisco',
#  'OBMedia',
#  'San Antonio Regional Hospital',
#  'Veritone',
#  'Wiser Solutions',
#  'clearAvenue',
#  'REVOLVE',
#  'Alphataraxia',
#  'Precision technologies',
#  'Rancho Santiago Community College District',
#  'Turo',
#  'Incredible Health',
#  "Young's Market Company",
#  'Health Advocates',
#  'Benefit Cosmetics',
#  'Standard Cognition',
#  'Kaiser Permanente',
#  'ApolloMed',
#  'E. & J. Gallo Winery',
#  'KBR',
#  'Tesla',
#  'BD',
#  'American Honda Motor Co., Inc.',
#  'Happiest Baby, Inc.',
#  'Fox Racing',
#  'Edwards Lifesciences',
#  'Workforce Logiq',
#  'Boot Barn',
#  'Veeva Systems',
#  'BOLD',
#  'Disney Streaming Services',
#  'DocuSign',
#  'VIZ Media',
#  'Ginger',
#  'Gaine Technology LLC',
#  'Enjoy Technology',
#  'MOLOCO',
#  'University of California Berkeley',
#  'DocuSign',
#  'Sentry',
#  'TriMark USA',
#  'OSI Digital',
#  'Twitch',
#  'Stanford University',
#  'FocusKPI Inc.',
#  'Cricket Health',
#  'Enjoy Technology',
#  'QuantumBricks',
#  'Frontapp',
#  'Tradesy',
#  'Digital Dhara',
#  'Brightwheel',
#  'Collective Inc',
#  'Capgemini',
#  'Abbvie',
#  'YMCA of San Diego County',
#  'Brain Corp',
#  'Pantheon',
#  'Capgemini',
#  'Amick Brown, LLC',
#  'Bytedance',
#  'Tesla',
#  'Kaiser Permanente',
#  'Akraya Inc.',
#  'Agama Solutions',
#  'Medable',
#  '211 San Diego',
#  'JLL',
#  'Cedars-Sinai Medical Center',
#  'Prealize Health',
#  'Charles R. Drew University',
#  'MICRODENTAL LABORATORIES',
#  'CaaStle',
#  'Weee! Inc',
#  'Twitch',
#  'PAX Labs',
#  'Fisker Inc',
#  'University of California San Francisco',
#  'Prospect Medical Systems',
#  'Sentry',
#  'Aristotle Capital Management',
#  'Diakont',
#  'Lucid Motors',
#  'EasyPay Finance',
#  'Kinect',
#  'Lead5 Media',
#  'QuantumBricks',
#  'Medable',
#  'Iron Horse',
#  'Mac Incorporated',
#  'Insight Global',
#  'Mason Tillman Associates',
#  'City of Hope',
#  'Veeva Systems',
#  'Chairish, Inc.',
#  'Prealize Health',
#  'Sentry',
#  'UCLA',
#  'FocusKPI Inc.',
#  'Facebook',
#  'NBCUniversal',
#  'Cedars-Sinai Medical Center',
#  'Gaine Technology LLC',
#  'Capio Group',
#  'Prospect Medical Systems',
#  'Vaco',
#  'Scale Media',
#  'Twitch Interactive, Inc.',
#  'Golden State Foods',
#  'Amgen',
#  'Akraya Inc.',
#  'Plume',
#  'Brightwheel',
#  'Snapchat',
#  'Tesla',
#  'Mason Tillman Associates',
#  'Sentry',
#  'LaborView',
#  'Lead5 Media',
#  'Xcel Agency',
#  'Vaco',
#  'Crunchyroll',
#  'Happiest Baby, Inc.',
#  'Kinect',
#  'REVOLVE',
#  'L.A. Care Health Plan',
#  'Mathematica Policy Research',
#  'Cenergy International',
#  'Twitch',
#  'Chairish, Inc.',
#  'Brilliant Corners',
#  'WarnerMedia',
#  'Crunchyroll',
#  'Kinect',
#  'Sony Pictures Entertainment, Inc.',
#  'Universal Music Group',
#  'Kaiser Permanente',
#  'Square',
#  'Sentry',
#  'EasyPay Finance',
#  'CLEAResult',
#  'Plume',
#  'Match',
#  'Thrive Global',
#  'Blizzard Entertainment',
#  'DISQO',
#  'American Indian Health & Services',
#  'Golin',
#  'Adobe',
#  'Adyen',
#  'Crunchyroll',
#  'Golden State Foods',
#  'Info Way Solutions',
#  'DeVine Consulting, Inc.',
#  'QuEST Global Engineering',
#  'Fox Racing',
#  'Edwards Lifesciences',
#  'Twitch',
#  'Google',
#  'DeVine Consulting, Inc.',
#  'GoodRx',
#  'Gimbal',
#  'City of Hope',
#  'TitanX',
#  'Adventist Health Roseville',
#  '211 San Diego',
#  'Sony Pictures Entertainment, Inc.',
#  'DISQO',
#  'Square',
#  'AmerisourceBergen',
#  'L.A. Care Health Plan',
#  'VIZ Media',
#  'New Relic',
#  'Episcopal Community Services',
#  'Medable',
#  'VIZ Media',
#  'AIG',
#  'Hollywood Park',
#  'Kinect',
#  'Chairish, Inc.',
#  'Happiest Baby, Inc.',
#  'Twitch',
#  'MOLOCO',
#  'Zoxima',
#  'NBCUniversal',
#  'Stachs LLC',
#  'Whalerock Industries',
#  'California State University San Marcos Corporation',
#  'Anzu Global',
#  'Enterprise Resource Partners',
#  'Activision',
#  'Calbee North America',
#  'Branded Resaerch Inc (BRINC)',
#  'KBR',
#  'PG&E Corporation',
#  'Cricket Health',
#  'Enquero Inc',
#  'Surgalign Spine Technologies Inc',
#  'DEMOSPHERE',
#  'Auto Club of Southern California',
#  'Abbvie',
#  'Avail Medsystems',
#  'AIG',
#  'Tesla',
#  'Lucid Motors',
#  'Gaine Technology LLC',
#  'Health Plan of San Joaquin',
#  'Weee! Inc',
#  'Merced County, CA',
#  'Adobe',
#  'Argen Corporation',
#  'Wild Earth',
#  'ConsejoSano',
#  'Hive',
#  'AIG',
#  'University of California San Francisco',
#  'Capital Group',
#  'Vervent Inc',
#  'Surya Systems',
#  'TikTok',
#  'Metromile',
#  'Tinuiti - 2',
#  'Branded Resaerch Inc (BRINC)',
#  'Kajabi',
#  'Fast AF',
#  'ViaSat',
#  'AmerisourceBergen',
#  'MATRIX Resources',
#  'El Camino Health',
#  'Tesla',
#  'Happiest Baby, Inc.',
#  'DeVine Consulting, Inc.',
#  'The Voleon Group',
#  'Expertise LLC',
#  'California State University',
#  'El Camino Health',
#  'Triune Infomatics Inc',
#  'Akraya Inc.',
#  'Activision',
#  'UCLA Health',
#  'JT4',
#  'The Surplus Line Association of CA',
#  'City of Cupertino, CA',
#  'TikTok',
#  'LaborView',
#  'Jam City',
#  'Akraya Inc.',
#  'ONG HUMAN CAPITAL',
#  'First Republic Bank',
#  'Community Action Partnership of San Luis Obispo',
#  'Sounding Board Inc',
#  'Jam City',
#  'LaborView',
#  'Heritage Provider Network',
#  'ONG HUMAN CAPITAL',
#  'Golden State Water Company',
#  'Nan McKay & Associates',
#  'TikTok',
#  'Credible',
#  'PennyMac',
#  'Triune Infomatics Inc',
#  'Adobe',
#  'US Naval Medical Command',
#  'El Camino Health',
#  'California Hospital Medical Center',
#  'Kajabi',
#  'Ursus',
#  'Agama Solutions',
#  'Flock Freight',
#  'Adventist Health Glendale',
#  'GOAT',
#  'UCLA Health',
#  'Fiserv',
#  'FocusKPI Inc.',
#  'Uber',
#  'UnitedHealth Group',
#  'Stachs LLC',
#  'US Assistant Secretary for Housing-Federal Housing...',
#  'Acumen LLC',
#  'Uber',
#  'LendingClub',
#  'Mediasmith, Inc.',
#  'Sound Agriculture',
#  'City of Escondido',
#  'Natera',
#  'Pantheon',
#  'Recruiting Resources, Inc.',
#  'California State University',
#  'Brightview',
#  'Capio Group',
#  'Whalerock Industries',
#  'Golden State Water Company',
#  'IAP Worldwide Services, Inc',
#  'Fox Racing',
#  'Jam City',
#  'California Hospital Medical Center',
#  'UnitedHealth Group',
#  'Universal Music Group',
#  'Insight Global',
#  'Info Way Solutions',
#  'Stefanini, Inc',
#  'hims & hers',
#  'VentureChoice',
#  'Beshton Software',
#  'Hive',
#  'TikTok',
#  'Stachs LLC',
#  'California State University',
#  'Cisco Systems',
#  'Twitch',
#  'NextEra Energy',
#  'ConsejoSano',
#  'Insight Global',
#  'Adventist Health Roseville',
#  'Change Healthcare',
#  'California State University, Long Beach',
#  'Agama Solutions',
#  'Jerry',
#  'Tekrek Solutions',
#  'Thermo Fisher Scientific',
#  'Netpace, Inc.',
#  'GP Strategies Corporation',
#  'Kharon',
#  'Prospect Medical Systems',
#  'TCS',
#  'AIDS Healthcare Foundation',
#  'AmerisourceBergen',
#  'Experian',
#  'Insight Global',
#  'J.D. Power',
#  'Amazon.com Services LLC',
#  'Agama Solutions',
#  'eBay Inc.',
#  'Allakos',
#  'Nationwide',
#  'REVOLVE',
#  'Capio Group',
#  'Golden State Foods',
#  'Credible',
#  'Clark Street Associates',
#  "Moody's Corporation",
#  'Sprout Mortgage',
#  'The Surplus Line Association of CA',
#  'Insight Global',
#  'Housecall Pro',
#  'Rancho Santiago Community College District',
#  'CaaStle',
#  'Prealize Health',
#  'American Advisors Group',
#  'Enquero Inc',
#  'San Antonio Regional Hospital',
#  'DISQO',
#  'Auto Club of Southern California',
#  'Struum Inc.',
#  'Blend',
#  'WestEd',
#  'PG&E Corporation',
#  'Niagara Bottling',
#  'Insight Global',
#  'thredUP Inc',
#  'Amazon.com Services LLC',
#  'PAX Labs',
#  'Center for Domestic Peace',
#  'Gensler',
#  'Pinnacle Group',
#  'Transom Consulting',
#  'Super Micro Computer, Inc.',
#  'Box',
#  'Specright Inc.',
#  'GSW Sports, LLC',
#  'Nan McKay',
#  'Arc Bio',
#  'Insight Global',
#  'Experian',
#  'Precision technologies',
#  'Deloitte',
#  'Bank of the West',
#  'National Funding',
#  'Tinuiti - 2',
#  'SchoolsFirst FCU',
#  'SESLOC Federal Credit Union',
#  'Change Healthcare',
#  'Alten',
#  'Bank of the West',
#  'Evergreen Technologies, LLC.',
#  'Cedars-Sinai',
#  'Winc',
#  'Tapjoy',
#  'Edgewood Consulting Group',
#  'GP Strategies Corporation',
#  'EGB Systems and Solutions Inc',
#  'Flock Freight',
#  'RAND Corporation',
#  'Coalition for Responsible Community Development',
#  'Pantheon',
#  'Universal Music Group',
#  'Box',
#  'UnitedHealth Group',
#  'VMware',
#  'Ukund',
#  'Tinuiti - 2',
#  'Rockstar Games',
#  'Crunch.io',
#  'Edgewood Consulting Group',
#  'QSC, LLC',
#  'Winc',
#  'Change Healthcare',
#  'Bank of the West',
#  'UCLA Health',
#  'Nuna',
#  'U.S. Pacific Fleet',
#  'DEMOSPHERE',
#  'Albertsons Companies',
#  'Energy Solutions',
#  'Luth Research',
#  'County of Santa Cruz',
#  'Sojern',
#  'Axos Bank',
#  'PUBG Santa Monica',
#  'Avison Young',
#  'NextEra Energy',
#  '1010data',
#  'Box',
#  'Blizzard Entertainment',
#  'Romeo Power',
#  'Google',
#  'Pinnacle Group',
#  "Young's Market Company",
#  '4 Over llc',
#  'Hive',
#  'NorthOne',
#  'Friedmans Home Improvement',
#  'RAND Corporation',
#  'Capital Group',
#  'Infinite Computing Systems',
#  'WarnerMedia',
#  'Akraya Inc.',
#  'UnitedHealth Group',
#  'Cedars-Sinai',
#  'Meggitt',
#  'BD',
#  'Zoll Circulation Inc.',
#  'WarnerMedia',
#  'Simplex Construction Management, Inc. (Simplex)',
#  'GP Strategies Corporation',
#  'REVOLVE',
#  'Paysafe Group',
#  'Visa',
#  'Kinta AI',
#  'Fortinet',
#  'FUSE MEDIA',
#  'ZOLL LifeVest',
#  'Heluna Health',
#  'TikTok',
#  'H&L Partners',
#  'UCLA Health',
#  'Zuora',
#  'RawCubes',
#  'Swinsoft',
#  'Amazon.com Services LLC',
#  'Agilon Health',
#  'Weee! Inc',
#  'TCS',
#  'Marqeta',
#  'Saddleback Church',
#  'First Media',
#  'The Clorox Company',
#  'ServiceNow',
#  'Zoetis',
#  'Universal Music Group',
#  'Blue Shield of California',
#  'Episcopal Community Services Of San Francisco',
#  'Internet Brands',
#  'Episcopal Community Services Of San Francisco',
#  'Internet Brands',
#  'City of San Jose',
#  'Comprehensive Community Health Centers',
#  'ConsejoSano',
#  'Jam City',
#  'First Republic Bank',
#  'Siemens',
#  'InDepth Corporation',
#  'Merced County, CA',
#  'UCLA Health',
#  'Iron Horse',
#  'NetStrive Consulting, LLC',
#  'Blend',
#  'Finix Payments',
#  'UnitedHealth Group',
#  'Inglewood Park Cemetery',
#  'Business Talent Group',
#  'Medable',
#  'Apple',
#  'CTI III LLC',
#  '8-Koi',
#  'PennyMac',
#  'LAs Totally Awesome',
#  'Thumbtack',
#  'UCLA Health',
#  'Los Angeles County Department of Human Resources',
#  'EGB Systems and Solutions Inc',
#  'Bio-Rad Laboratories, Inc.',
#  'STAT Revenue',
#  'Incept Data Solutions, Inc',
#  'TikTok',
#  'VS Media',
#  'West Health',
#  'Callisto Media',
#  'Transom Consulting',
#  'Experian',
#  'Kairos Technologies',
#  'Akraya Inc.',
#  'UCLA Health',
#  'Formac Inc',
#  'APLA Health',
#  'Recruiting for Good',
#  'Good Eggs',
#  'Mathematica Policy Research',
#  'KKCS',
#  'Spartan Technologies',
#  'Internet Brands',
#  'Delta Dental Ins.',
#  'Adventist Health Roseville',
#  'WarnerMedia',
#  'Intrado',
#  'Fashion Nova - Careers',
#  'Booster Fuels',
#  'TCS',
#  'UCLA Health',
#  'System1',
#  'WarnerMedia',
#  'King.com',
#  'Razorfish',
#  'Colsh Consultants',
#  'Pantheon',
#  'Adventist Health Roseville',
#  'Palo Alto Networks',
#  'PUBG Santa Monica',
#  'Xerox',
#  'Change Healthcare',
#  'Airtable',
#  'Inland Empire Health Plans',
#  'Food Bank of Contra Costa and Solano',
#  'Circle',
#  'RPA',
#  'WarnerMedia',
#  'Thermo Fisher Scientific',
#  'Range Generation Next LLC',
#  'Anzu Global',
#  'Adventist Health Roseville',
#  'KKCS',
#  'Pantheon',
#  'BD',
#  'Uber',
#  'productOps',
#  'Luxoft',
#  'Edwards Lifesciences',
#  'Romeo Power',
#  'TikTok',
#  'Lamps Plus',
#  'Sony Corporation of America',
#  'Niagara Bottling',
#  'RPA',
#  'RPA',
#  'Xerox',
#  'AmeriHome Mortgage',
#  'Brilliant Corners',
#  'Fast AF',
#  'Brightview',
#  'Intermedia.net, Inc.',
#  'WarnerMedia',
#  'ConsejoSano',
#  'Center for Domestic Peace',
#  'Kinta AI',
#  'Amazon.com Services LLC',
#  'Thumbtack',
#  'Palo Alto Networks',
#  'WarnerMedia',
#  'SLEEP NUMBER',
#  'Food Bank of Contra Costa and Solano',
#  'Anaheim Ducks',
#  'Elation Health',
#  'Apple',
#  'Facebook',
#  'Facebook',
#  'WarnerMedia',
#  'Range Generation Next LLC',
#  'Siemens',
#  'Scale Media',
#  'Blizzard Entertainment',
#  'Deloitte',
#  'US Headquarters, Air Force Space Command',
#  'TWO NIL',
#  "Chefs' Toys",
#  'TikTok',
#  'Edwards Lifesciences',
#  'H&L Partners',
#  'GoodRx',
#  'First Republic Bank',
#  'Cepheid',
#  'SeaWorld San Diego',
#  'Deliverr Inc',
#  'Nuna',
#  'Meggitt',
#  'MemorialCare Medical Foundation',
#  'JT4',
#  'Hinge Health',
#  'Akraya Inc.',
#  'Capio Group',
#  'BlackRock',
#  'Capgemini',
#  'Apple',
#  'Tesla',
#  'San Joaquin General Hospital',
#  'Lamps Plus',
#  'Insight Global',
#  'Sony Corporation of America',
#  'Carrot Fertility',
#  'Infinite Computing Systems',
#  'DocuSign',
#  'Anaheim Ducks',
#  'Akraya Inc.',
#  'Brilliant Corners',
#  'WarnerMedia',
#  'GEP Administrative Services, LLC',
#  'California State University, Long Beach',
#  'Formac Inc',
#  'Illumina',
#  'Blend',
#  'WarnerMedia',
#  'AmeriHome Mortgage',
#  'VMware',
#  'Take-Two Interactive Software, Inc.',
#  'Getaround',
#  'Instacart',
#  'Scale Media',
#  'PUBG',
#  'Luxoft',
#  'Formac Inc',
#  'Clark Richardson & Biskup Consulting Engineers',
#  'Sharp Healthcare',
#  'Tesla',
#  'City National Bank',
#  'Insight Global',
#  'ScoreData',
#  'Envision',
#  'Central California Alliance for Health',
#  'CG-VAK',
#  'Blend',
#  'Razorfish',
#  'Western Milling',
#  'Facebook',
#  'X2logics',
#  'Community Medical Centers Inc',
#  'Volta Charging',
#  'E. & J. Gallo Winery',
#  'Common Sense Networks',
#  'Specright Inc.',
#  'Envision',
#  'Capgemini',
#  'Brilliant Corners',
#  'Booz Allen Hamilton',
#  'Eurofins USA BioPharma Services',
#  'LeanTaaS',
#  'NextEra Energy',
#  'H&H Group',
#  'Delta Dental Ins.',
#  'The Oncology Institute of Hope and Innovation',
#  'ScoreData',
#  'Formac Inc',
#  'Crunch.io',
#  'Google',
#  'CareRev',
#  'California State University, Sacramento',
#  'Palo Alto Networks',
#  'Criteo',
#  'MRQ SOFT Innovations',
#  'TRC Companies Inc',
#  'Edwards Lifesciences',
#  'Facebook',
#  'Blend',
#  'The Oncology Institute of Hope and Innovation',
#  'Trek Bikes',
#  'New Relic',
#  'Golden Five LLC',
#  'Specright Inc.',
#  'Stout',
#  'Silicon Valley Bank',
#  'Grimmway Farms',
#  'West Health',
#  'NerdWallet',
#  'Albertsons Companies',
#  'Faithful+Gould',
#  'TikTok',
#  'Facebook',
#  'Hulu',
#  'CIPPlanner',
#  'Mutual of Omaha Mortgage',
#  'YouTube',
#  'First American',
#  'Genesis Capital LLC',
#  'Westlake Services, LLC',
#  'signet',
#  'Toll Brothers',
#  'Commerce Casino',
#  'Southern Glazer’s Wine and Spirits',
#  'Internet Brands',
#  'US Naval Air Systems Command',
#  'Change Research',
#  'DocuSign',
#  'Chumash Employee Resource Center',
#  'Joybird',
#  'NerdWallet',
#  'California State University',
#  'Delta Dental Ins.',
#  '605',
#  'Community Medical Centers Inc',
#  'Keck Medical Center of USC',
#  'Afterpay Touch',
#  'Blizzard Entertainment',
#  'Mac Incorporated',
#  'Open Source Integrators',
#  'Instacart',
#  'Applied Materials Inc.',
#  'Facebook',
#  'Public Media Group of Southern California (KCET,...',
#  'Brightview',
#  'Getaround',
#  'Adventist Health Roseville',
#  'TechTrueUP',
#  'National Education Partners',
#  'ProcurementIQ',
#  'Proterra, Inc.',
#  'Vivo',
#  'Mac Incorporated',
#  'Brilliant Corners',
#  'Apple',
#  'CTI III LLC',
#  'Prodege, LLC',
#  'DocuSign',
#  'Criteo',
#  'Facebook',
#  'Deluxe Entertainment',
#  'Kaiser Permanente',
#  'Disney Media & Entertainment Distribution',
#  'Google',
#  'Facebook',
#  'Mathematica Policy Research',
#  'Paysafe Group',
#  'Faithful+Gould',
#  'New-indy Containerboard Llc',
#  'Capgemini',
#  'PUBG',
#  'Waymakers',
#  'TitanX',
#  'SLEEP NUMBER',
#  'Experian',
#  'Facebook',
#  'SoFi',
#  'Verkada',
#  'HERBL',
#  'Recruiter.com',
#  'US Naval Air Systems Command',
#  'Open Source Integrators',
#  'Triskelle Solutions',
#  'Formac Inc',
#  'Bobbie',
#  'Bank of the West',
#  'Tubi',
#  'Public Consulting Group',
#  'County of Orange',
#  'Paysafe Group',
#  'Circle',
#  'Bay Area Community Health',
#  'Home Depot / THD',
#  'TechTrueUP',
#  'WarnerMedia',
#  'Facebook',
#  'Nuna',
#  'KANTAR',
#  'Hinge Health',
#  'Google',
#  'Projas Technologies',
#  'CTI III LLC',
#  'Delta Dental Ins.',
#  'Inland Empire Health Plans',
#  'EGB Systems and Solutions Inc',
#  'Adventist Health Roseville',
#  'Friedmans Home Improvement',
#  'Katalyst Healthcares & Life Sciences',
#  'Celandyne Software Solutions',
#  'signet',
#  'Insight Global',
#  'Adventist Health Roseville',
#  'Beverly Hospital',
#  'Heluna Health',
#  'The San Diego LGBT Community Center',
#  'Delta Dental Ins.',
#  'Kforce',
#  'Faithful+Gould',
#  'Facebook',
#  'Zendesk',
#  'Joybird',
#  'Workday',
#  'Paysafe Group',
#  'Facebook',
#  'Circle',
#  'Internet Brands',
#  'Loyola Marymount University',
#  'Change Research',
#  'Insight Global',
#  'Adventist Health',
#  'Wag Walking',
#  'Kforce',
#  'Facebook',
#  'Kaiser Permanente',
#  'Workday',
#  'LOVEFOODIES INC',
#  'Finix Payments',
#  'Bobit Business Media',
#  'DocuSign',
#  'UnitedHealth Group',
#  'Blend',
#  'Insight Global',
#  'Kabam',
#  'Fruit Growers Supply',
#  'Applied Materials Inc.',
#  'Kforce',
#  'West Advanced Technologies (WATI)',
#  'Good Guard Security Inc.',
#  'Varo Money',
#  'County of Santa Cruz',
#  'Vivo',
#  'Brilliant Corners',
#  'Experian',
#  'Stanford Health Care',
#  'Red Ventures',
#  'Insight Global',
#  'Blizzard Entertainment',
#  'Walmart',
#  'CDW',
#  'BlackLine',
#  'Kforce',
#  'Rancho Santiago Community College District',
#  'Romeo Power',
#  'Tesla',
#  'Eden Housing, Inc.',
#  'Facebook',
#  'Roblox',
#  'California State University',
#  'Akraya Inc.',
#  'Talentry',
#  'California Department of Managed Health Care',
#  'Shutterfly',
#  'Vanir Construction Management, Inc.',
#  'Ursus',
#  'Insight Global',
#  'CyberCoders',
#  'Optimum Healthcare IT',
#  'Apple',
#  'Latitude 36 Foods, LLC',
#  'TEKBERRY',
#  'Ultimate Staffing Services',
#  'Collins Aerospace',
#  'Northrop Grumman',
#  'MATRIX Resources',
#  'Volt Workforce Solutions',
#  'Insight Global',
#  'Victory care',
#  'Ursus',
#  'Acara Solutions',
#  'DISYS',
#  'MATRIX Resources',
#  'Advantage Resourcing',
#  'Robert Half',
#  'Guidehouse',
#  'The Energy Coalition',
#  'Consumer Portfolio Services, Inc.',
#  'Harnham',
#  'SCP Health',
#  'MATRIX Resources',
#  'Wollborg Michelson Recruiting',
#  'Staffmark',
#  'Victory care']

# %%
locations11
# Out:
# ['San Bruno, CA•Temporarily Remote',
#  'Long Beach, CA 90802•Remote',
#  'Carlsbad, CA 92008',
#  'Poway, CA•Temporarily Remote',
#  'Foster City, CA 94404',
#  'California+1 location•Remote',
#  'San Jose, CA',
#  'Anaheim, CA',
#  'California•Remote',
#  'San Jose, CA 95131 (North San Jose area)•Remote',
#  'San Francisco, CA',
#  'Los Angeles, CA 91367+1 location',
#  'Santa Clara, CA•Temporarily Remote',
#  'Stanford, CA',
#  'Sacramento, CA',
#  'Santa Clara, CA•Temporarily Remote',
#  'Stanford, CA',
#  'Sacramento, CA',
#  'Redwood City, CA 94063',
#  'Burbank, CA+1 location',
#  'Fremont, CA',
#  'San Ramon, CA 94583',
#  'Menlo Park, CA•Temporarily Remote',
#  'Cupertino, CA (South Blaney area)',
#  'Goleta, CA 93117',
#  'Rancho Mirage, CA 92270',
#  'Alameda, CA',
#  'California•Remote',
#  'Costa Mesa, CA 92626',
#  'San Francisco, CA 94105 (South Beach area)',
#  'San Francisco, CA',
#  'San Ramon, CA 94583',
#  'San Dimas, CA 91773',
#  'San Dimas, CA 91773',
#  'Irvine, CA',
#  'Mountain View, CA+1 location',
#  'San Francisco, CA',
#  'Santa Clara, CA•Temporarily Remote',
#  'San Diego, CA',
#  'Santa Ana, CA',
#  'Santa Barbara, CA 93110',
#  'Los Angeles, CA',
#  'Los Angeles, CA 90291 (Venice area)',
#  'California•Remote',
#  'Oakland, CA•Temporarily Remote',
#  'San Ramon, CA 94583',
#  'Brisbane, CA',
#  'Costa Mesa, CA 92626',
#  'San Francisco, CA•Remote',
#  'Los Angeles, CA',
#  'Stanford, CA',
#  'Marine Corps Air Station Miramar, CA•Remote',
#  'San Francisco, CA 94147 (Marina area)•Remote',
#  'Redding, CA',
#  'Irvine, CA 92614 (Business District area)',
#  'San Jose, CA 95110 (Downtown area)',
#  'Costa Mesa, CA 92626',
#  'Commerce, CA 90040',
#  'San Francisco, CA',
#  'California•Remote',
#  'Mountain View, CA',
#  'Milpitas, CA 95035•Temporarily Remote',
#  'San Ramon, CA 94583',
#  'Los Angeles, CA 90014 (Downtown area)•Temporarily Remote',
#  'Sacramento, CA+3 locations•Remote',
#  'Santa Monica, CA',
#  'Los Angeles, CA 90048',
#  'Los Angeles County, CA',
#  'Palo Alto, CA',
#  'Diamond Bar, CA 91765',
#  'San Diego, CA 92127 (Rancho Bernardo area)',
#  'Santa Clara, CA+2 locations',
#  'Glendale, CA',
#  'Beaumont, CA',
#  'Sacramento, CA•Remote',
#  'Beaumont, CA',
#  'Sacramento, CA•Remote',
#  'San Ramon, CA 94583',
#  'Burbank, CA',
#  'Sunnyvale, CA 94089 (Lakewood area)+1 location',
#  'San Jose, CA',
#  'San Francisco, CA',
#  'San Jose, CA 95110 (Downtown area)',
#  'El Segundo, CA',
#  'Long Beach, CA 90802•Remote',
#  'San Jose, CA+1 location',
#  'San Jose, CA 95131 (North Valley area)+2 locations•Remote',
#  'California•Remote',
#  'California•Remote',
#  'Irvine, CA 92603•Remote',
#  'Oakland, CA',
#  'Long Beach, CA 90840 (State College Area area)',
#  'Roseville, CA',
#  'San Ramon, CA 94583',
#  'Madera, CA•Remote',
#  'Los Angeles, CA',
#  'Perris, CA 92571',
#  'Berkeley, CA 94720',
#  'California•Remote',
#  'Oakland, CA 94612 (Downtown area)',
#  'San Francisco, CA 94143 (Haight-Ashbury area)+2 locations',
#  'San Francisco, CA',
#  'San Diego, CA 92121',
#  'California•Remote',
#  'Torrance, CA 90502',
#  'Newark, CA 94560',
#  'Fresno, CA',
#  'Foster City, CA 94404•Temporarily Remote',
#  'Glendale, CA',
#  'Santa Clara, CA•Temporarily Remote',
#  'West Hollywood, CA',
#  'Santa Clara, CA 95054',
#  'Richmond, CA+1 location',
#  'Los Angeles, CA•Remote',
#  'Upland, CA 91786',
#  'California•Remote',
#  'San Mateo, CA 94402 (Beresford area)',
#  'Seaside, CA',
#  'Cerritos, CA 90703',
#  'Newport Beach, CA',
#  'California City, CA•Temporarily Remote',
#  'Santa Ana, CA 92706',
#  'San Francisco, CA (Mission Terrace area)',
#  'California•Remote',
#  'Tustin, CA 92780',
#  'Chatsworth, CA 91311',
#  'San Francisco, CA 94104 (Financial District area)',
#  'San Francisco, CA•Remote',
#  'Oakland, CA•Remote',
#  'Alhambra, CA•Remote',
#  'Modesto, CA',
#  'China Lake, CA',
#  'Fremont, CA',
#  'San Diego, CA 92130 (Carmel Valley area)',
#  'Chino, CA 91710',
#  'Los Angeles, CA 90016',
#  'Irvine, CA 92606 (Business District area)',
#  'Irvine, CA',
#  'Santa Clara, CA',
#  'Irvine, CA 92618 (Irvine Health and Science Complex area)',
#  'Pleasanton, CA 94588•Remote',
#  'California•Remote',
#  'Burbank, CA',
#  'San Francisco, CA 94105 (South Beach area)',
#  'San Francisco, CA 94103 (South Of Market area)',
#  'San Francisco, CA',
#  'San Luis Obispo, CA 93401',
#  'California•Remote',
#  'Redwood City, CA',
#  'Berkeley, CA 94720',
#  'San Francisco, CA 94105 (South Beach area)',
#  'San Francisco, CA',
#  'Fountain Valley, CA 92708',
#  'Irvine, CA•Remote',
#  'San Francisco, CA',
#  'Stanford, CA',
#  'Mountain View, CA',
#  'San Francisco, CA•Remote',
#  'California•Remote',
#  'Milpitas, CA•Temporarily Remote',
#  'San Francisco, CA',
#  'California•Remote',
#  'Santa Clara, CA•Temporarily Remote',
#  'San Francisco, CA•Remote',
#  'California•Remote',
#  'Burbank, CA+1 location',
#  'Irvine, CA',
#  'San Diego, CA',
#  'San Diego, CA',
#  'California•Remote',
#  'Universal City, CA',
#  'Sunnyvale, CA',
#  'Los Angeles, CA',
#  'Palo Alto, CA',
#  'Pasadena, CA',
#  'Foster City, CA 94404',
#  'Sacramento, CA+3 locations•Remote',
#  'Palo Alto, CA•Remote',
#  'San Diego, CA 92123',
#  'San Francisco, CA',
#  'Los Angeles, CA 90048',
#  'Palo Alto, CA 94301 (Professorville area)',
#  'Los Angeles, CA 90059',
#  'Livermore, CA 94551',
#  'Mountain View, CA 94043',
#  'Fremont, CA',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'Manhattan Beach, CA 90266',
#  'Richmond, CA+1 location',
#  'Orange, CA',
#  'San Francisco, CA',
#  'Los Angeles, CA 90025 (West Los Angeles area)',
#  'Carlsbad, CA',
#  'Newark, CA 94560',
#  'Vista, CA',
#  'Santa Monica, CA',
#  'Newark, CA',
#  'Milpitas, CA•Temporarily Remote',
#  'Palo Alto, CA•Remote',
#  'San Ramon, CA•Remote',
#  'San Leandro, CA',
#  'San Francisco, CA',
#  'Oakland, CA 94612 (Lakewide area)',
#  'Duarte, CA 91010',
#  'Pleasanton, CA 94588•Remote',
#  'San Francisco, CA 94104 (Financial District area)•Remote',
#  'Palo Alto, CA 94301 (Professorville area)',
#  'San Francisco, CA',
#  'Los Angeles, CA',
#  'San Francisco Bay Area, CA',
#  'Menlo Park, CA 94025+1 location',
#  'Glendale, CA',
#  'Los Angeles, CA 90048',
#  'San Luis Obispo, CA 93401',
#  'Sacramento, CA 95814 (Mansion Flats area)',
#  'Orange, CA',
#  'Los Angeles, CA',
#  'Sherman Oaks, CA 91403',
#  'San Francisco, CA',
#  'Irvine, CA 92612 (Business District area)•Remote',
#  'Thousand Oaks, CA',
#  'Foster City, CA 94404',
#  'Palo Alto, CA 94306 (Evergreen Park area)',
#  'San Francisco, CA•Remote',
#  'Los Angeles, CA 90291 (Venice area)',
#  'Palo Alto, CA',
#  'Oakland, CA 94612 (Lakewide area)',
#  'San Francisco, CA',
#  'Carlsbad, CA',
#  'Newark, CA',
#  'San Francisco, CA 94114 (Eureka Valley - Dolores Heights - Castro area)',
#  'Los Angeles, CA',
#  'San Francisco, CA•Temporarily Remote',
#  'Los Angeles, CA 90016',
#  'Santa Monica, CA',
#  'Cerritos, CA 90703',
#  'Los Angeles, CA 90017 (Westlake area)',
#  'Oakland, CA 94612 (Downtown area)',
#  'Rosemead, CA',
#  'San Francisco, CA',
#  'San Francisco, CA 94104 (Financial District area)•Remote',
#  'Los Angeles, CA 90014 (Downtown area)•Temporarily Remote',
#  'Burbank, CA 91505',
#  'San Francisco, CA•Temporarily Remote',
#  'Santa Monica, CA',
#  'Culver City, CA 90232 (Washington Culver area)',
#  'Los Angeles, CA 90028',
#  'Riverside, CA+5 locations',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'Vista, CA',
#  'Oakland, CA',
#  'Palo Alto, CA 94306 (Evergreen Park area)',
#  'West Hollywood, CA',
#  'San Francisco, CA',
#  'Irvine, CA 92618•Temporarily Remote',
#  'Glendale, CA',
#  'Santa Barbara, CA 93110',
#  'California•Remote',
#  'San Jose, CA+1 location',
#  'San Francisco, CA',
#  'San Francisco, CA•Temporarily Remote',
#  'Irvine, CA 92612 (Business District area)•Remote',
#  'Santa Clara, CA 95054•Temporarily Remote',
#  'Monterey, CA 93940',
#  'Sunnyvale, CA',
#  'Irvine, CA 92606 (Business District area)',
#  'Irvine, CA',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'Monterey, CA 93940',
#  'Santa Monica, CA 90401 (Wilshire/Montana area)',
#  'Los Angeles, CA',
#  'Duarte, CA 91010',
#  'Los Angeles, CA•Temporarily Remote',
#  'Roseville, CA',
#  'San Diego, CA 92123',
#  'Culver City, CA 90232 (Washington Culver area)',
#  'Glendale, CA',
#  'San Francisco, CA',
#  'Orange, CA',
#  'Los Angeles, CA 90017 (Westlake area)',
#  'San Francisco, CA 94103 (South Of Market area)',
#  'San Francisco, CA 94105 (South Beach area)•Remote',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Palo Alto, CA•Remote',
#  'San Francisco, CA 94103 (South Of Market area)',
#  'Woodland Hills, CA',
#  'Inglewood, CA',
#  'Santa Monica, CA',
#  'San Francisco, CA 94104 (Financial District area)•Remote',
#  'Los Angeles, CA 90016',
#  'San Francisco, CA',
#  'Redwood City, CA',
#  'Fremont, CA',
#  'Los Angeles, CA',
#  'Baldwin Park, CA 91706',
#  'West Hollywood, CA 90069',
#  'San Marcos, CA 92096',
#  'Cupertino, CA',
#  'El Dorado Hills, CA',
#  'El Segundo, CA',
#  'Madera, CA•Remote',
#  'San Diego, CA',
#  'China Lake, CA',
#  'Antioch, CA 94509',
#  'San Francisco, CA•Remote',
#  'Milpitas, CA 95035•Remote',
#  'San Diego, CA 92131•Remote',
#  'Universal City, CA',
#  'Costa Mesa, CA 92626',
#  'Irvine, CA',
#  'California•Remote',
#  'Woodland Hills, CA',
#  'Fremont, CA',
#  'Newark, CA 94560',
#  'San Luis Obispo, CA 93401',
#  'French Camp, CA',
#  'Fremont, CA',
#  'Merced, CA 95340',
#  'San Jose, CA+1 location',
#  'San Diego, CA 92126',
#  'Berkeley, CA•Remote',
#  'Los Angeles, CA',
#  'San Francisco, CA',
#  'Woodland Hills, CA',
#  'San Francisco, CA 94143 (Haight-Ashbury area)',
#  'Los Angeles, CA 90071•Temporarily Remote',
#  'San Diego, CA 92121',
#  'San Francisco, CA•Temporarily Remote',
#  'Los Angeles, CA',
#  'San Francisco, CA 94107 (Yerba Buena area)',
#  'California•Remote',
#  'San Diego, CA',
#  'California•Remote',
#  'San Francisco, CA•Remote',
#  'Carlsbad, CA',
#  'Orange, CA',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Mountain View, CA 94040 (Old Mountain View area)',
#  'Palo Alto, CA',
#  'Los Angeles, CA 90016',
#  'Monterey, CA 93940',
#  'Berkeley, CA 94704•Temporarily Remote',
#  'Los Angeles, CA 90043',
#  'San Marcos, CA 92096',
#  'Mountain View, CA 94040 (Old Mountain View area)',
#  'Oakland, CA',
#  'San Jose, CA 95110 (Downtown area)',
#  'El Segundo, CA',
#  'Los Angeles, CA 90095•Temporarily Remote',
#  'Edwards, CA 93523',
#  'San Ramon, CA 94583',
#  'Cupertino, CA (South Blaney area)',
#  'Mountain View, CA',
#  'Carlsbad, CA',
#  'San Francisco, CA+1 location',
#  'Foster City, CA 94404',
#  'San Gabriel Valley, CA',
#  'San Francisco, CA 94111 (Financial District area)',
#  'San Luis Obispo, CA 93401',
#  'Los Angeles, CA 90001•Remote',
#  'San Francisco, CA+1 location',
#  'Carlsbad, CA',
#  'Lancaster, CA 93534',
#  'San Gabriel Valley, CA',
#  'Gardena, CA',
#  'San Francisco, CA 94124 (Bayview area)',
#  'Mountain View, CA',
#  'San Francisco, CA 94102 (Van Ness - Civic Center area)',
#  'Westlake Village, CA 91362',
#  'Oakland, CA',
#  'San Jose, CA',
#  'Naval Medical Center San Diego, CA•Remote',
#  'Mountain View, CA 94040 (Old Mountain View area)',
#  'Los Angeles, CA 90015 (Downtown area)',
#  'California•Remote',
#  'Mountain View, CA 94041',
#  'Sacramento, CA+3 locations•Remote',
#  'San Diego, CA',
#  'Glendale, CA',
#  'Los Angeles, CA',
#  'Los Angeles, CA 90095',
#  'Sunnyvale, CA 94087',
#  'San Francisco Bay Area, CA',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Santa Ana, CA 92702',
#  'Baldwin Park, CA 91706',
#  'Santa Ana, CA',
#  'Los Angeles, CA 90064 (Sawtelle area)+1 location',
#  'San Francisco, CA 94103 (South of Market area)',
#  'San Francisco, CA',
#  'Oakland, CA',
#  'California•Remote',
#  'Escondido, CA 92025',
#  'San Carlos, CA 94070',
#  'California•Remote',
#  'Los Angeles, CA 90064•Temporarily Remote',
#  'San Marcos, CA 92096',
#  'Calabasas, CA 91302',
#  'Sacramento, CA 95814 (Mansion Flats area)',
#  'West Hollywood, CA 90069',
#  'Gardena, CA',
#  'San Diego, CA',
#  'Irvine, CA 92606 (Business District area)',
#  'San Francisco, CA+1 location',
#  'Los Angeles, CA 90015 (Downtown area)',
#  'Santa Ana, CA 92702',
#  'Santa Monica, CA 90404 (Mid-City area)',
#  'San Francisco, CA',
#  'Santa Clara, CA 95054•Temporarily Remote',
#  'San Francisco, CA',
#  'California•Remote',
#  'Palo Alto, CA',
#  'San Francisco Bay Area, CA',
#  'San Francisco, CA',
#  'Los Angeles, CA',
#  'Baldwin Park, CA 91706',
#  'San Marcos, CA 92096',
#  'San Jose, CA',
#  'San Francisco, CA',
#  'San Francisco, CA 94108 (Financial District area)',
#  'Los Angeles, CA',
#  'San Francisco, CA',
#  'Roseville, CA•Remote',
#  'California',
#  'Long Beach, CA 90840 (State College Area area)',
#  'Fremont, CA 94538 (Downtown area)',
#  'San Francisco Bay Area, CA',
#  'Santa Clara, CA•Remote',
#  'Los Angeles, CA 90001•Remote',
#  'Foster City, CA 94404',
#  'California',
#  'United States',
#  'Orange, CA',
#  'Beverly Hills, CA•Temporarily Remote',
#  'Los Angeles, CA 90028 (Hollywood area)',
#  'Orange, CA',
#  'Costa Mesa, CA 92626',
#  'San Francisco, CA',
#  'California•Remote',
#  'Santa Barbara, CA',
#  'Sacramento, CA+3 locations•Remote',
#  'San Jose, CA',
#  'Redwood City, CA',
#  'Brea, CA•Remote',
#  'Cerritos, CA 90703',
#  'Sacramento, CA 95814 (Mansion Flats area)',
#  'Irvine, CA 92612 (Business District area)•Remote',
#  'San Francisco, CA 94102 (Van Ness - Civic Center area)',
#  'Mountain View, CA 94040',
#  'Berkeley, CA',
#  'California•Remote',
#  'San Ramon, CA 94583',
#  'San Francisco, CA',
#  'San Diego, CA',
#  'Santa Ana, CA 92706',
#  'Mountain View, CA 94043',
#  'Palo Alto, CA 94301 (Professorville area)',
#  'Irvine, CA 92612 (Business District area)',
#  'Milpitas, CA 95035•Remote',
#  'Upland, CA 91786',
#  'Glendale, CA',
#  'Costa Mesa, CA 92626',
#  'Los Angeles, CA•Remote',
#  'California•Remote',
#  'Los Alamitos, CA 90720•Temporarily Remote',
#  'Eureka, CA 95501',
#  'Diamond Bar, CA 91765',
#  'San Francisco, CA',
#  'Oakland, CA',
#  'Santa Barbara, CA',
#  'San Francisco, CA',
#  'San Rafael, CA 94901 (Downtown area)•Remote',
#  'Los Angeles, CA 90071 (Downtown area)',
#  'Redwood City, CA',
#  'Los Angeles, CA',
#  'San Jose, CA 95131 (North Valley area)',
#  'California',
#  'California•Remote',
#  'San Francisco, CA',
#  'San Francisco, CA 94124 (Bayview area)',
#  'Scotts Valley, CA',
#  'San Francisco, CA',
#  'Costa Mesa, CA 92626',
#  'California City, CA•Temporarily Remote',
#  'Costa Mesa, CA 92626+1 location',
#  'San Ramon, CA',
#  'San Diego, CA 92121 (University City area)',
#  'California•Remote',
#  'Tustin, CA 92780',
#  'San Luis Obispo, CA 93401',
#  'California',
#  'San Francisco, CA 94134 (Portola area)',
#  'San Ramon, CA',
#  'Los Angeles, CA•Remote',
#  'Los Angeles, CA',
#  'Los Angeles, CA 90066 (Del Rey area)',
#  'San Francisco, CA 94104 (Financial District area)',
#  'Cypress, CA 90630•Temporarily Remote',
#  'California',
#  'Santa Clara, CA 95050',
#  'San Diego, CA',
#  'Los Angeles, CA',
#  'Los Angeles, CA 90011 (Central City area)',
#  'California•Remote',
#  'Santa Monica, CA 90404 (Mid-City area)',
#  'California',
#  'Santa Ana, CA 92702',
#  'Palo Alto, CA+1 location•Remote',
#  'Sacramento, CA•Temporarily Remote',
#  'California•Remote',
#  'San Diego, CA',
#  'San Francisco Bay Area, CA•Remote',
#  'Cypress, CA 90630•Temporarily Remote',
#  'Costa Mesa, CA 92626',
#  'Los Angeles, CA 90066 (Del Rey area)',
#  'California',
#  'San Ramon, CA',
#  'Los Angeles, CA 90095',
#  'San Francisco, CA',
#  'Seal Beach, CA',
#  'Universal City, CA',
#  'Pleasanton, CA 94588',
#  'Oakland, CA 94612 (Downtown area)',
#  'San Diego, CA 92101 (Core-Columbia area)',
#  'Santa Cruz County, CA',
#  'San Francisco, CA 94111 (Financial District area)',
#  'San Diego, CA 92122 (University City area)',
#  'Santa Monica, CA',
#  'San Francisco, CA 94104 (Financial District area)',
#  'San Francisco, CA 94108 (Financial District area)',
#  'San Diego, CA',
#  'California',
#  'Irvine, CA 92618•Temporarily Remote',
#  'Los Angeles, CA',
#  'Mountain View, CA',
#  'Redwood City, CA',
#  'Tustin, CA 92780',
#  'Glendale, CA 91204 (Tropico area)',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'Petaluma, CA 94954',
#  'Los Angeles, CA',
#  'Los Angeles, CA 90071•Temporarily Remote',
#  'Sylmar, CA',
#  'Burbank, CA 91505',
#  'San Jose, CA 95110 (Downtown area)',
#  'Santa Ana, CA 92702•Remote',
#  'Los Angeles, CA',
#  'San Diego, CA 92121',
#  'San Diego, CA 92130 (Carmel Valley area)•Remote',
#  'San Jose, CA 95131 (North Valley area)',
#  'Culver City, CA',
#  'Anaheim, CA 92807 (Anaheim Hills area)',
#  'California',
#  'Cerritos, CA 90703',
#  'Irvine, CA',
#  'Palo Alto, CA (Evergreen Park area)',
#  'San Francisco, CA•Temporarily Remote',
#  'Sunnyvale, CA 94086 (East Murphy area)',
#  'Glendale, CA 91203 (City Center area)•Temporarily Remote',
#  'San Jose, CA',
#  'Richmond, CA',
#  'Los Angeles, CA',
#  'San Francisco Bay Area, CA+1 location',
#  'Los Angeles, CA 90095',
#  'California•Remote',
#  'Irvine, CA•Remote',
#  'Folsom, CA 95630',
#  'Santa Barbara, CA',
#  'California•Remote',
#  'Fremont, CA',
#  'Sunnyvale, CA',
#  'Oakland, CA',
#  'Lake Forest, CA 92630',
#  'Los Angeles, CA 90010',
#  'Pleasanton, CA',
#  'San Diego, CA 92121 (University City area)',
#  'Union City, CA',
#  'Santa Monica, CA 90404 (Mid-City area)',
#  'Oakland, CA',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Los Angeles, CA',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Los Angeles, CA',
#  'San Jose, CA',
#  'Glendale, CA 91205 (Mariposa area)',
#  'Los Angeles, CA',
#  'San Francisco, CA+1 location',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Sacramento, CA 95828•Remote',
#  'San Diego, CA 92127 (Rancho Bernardo area)',
#  'Merced, CA 95340',
#  'Los Angeles, CA 90095',
#  'San Ramon, CA•Remote',
#  'San Mateo, CA',
#  'California•Remote',
#  'San Francisco, CA',
#  'Santa Ana, CA 92702',
#  'Inglewood, CA 90301',
#  'Los Angeles, CA 90064 (West Los Angeles area)•Remote',
#  'Palo Alto, CA•Remote',
#  'Santa Clara Valley, CA 95014',
#  'Rancho Cordova, CA 95670',
#  'Vandenberg AFB, CA',
#  'Westlake Village, CA 91362',
#  'Buena Park, CA 90620',
#  'California•Remote',
#  'Los Angeles, CA 90095',
#  'Los Angeles County, CA',
#  'Santa Clara, CA 95050',
#  'Hercules, CA',
#  'Emeryville, CA 94608',
#  'San Jose, CA•Temporarily Remote',
#  'Los Angeles, CA',
#  'Westlake Village, CA 91361',
#  'San Diego, CA',
#  'Emeryville, CA',
#  'Los Angeles, CA',
#  'Costa Mesa, CA 92626',
#  'San Francisco, CA•Remote',
#  'Mountain View, CA 94043•Remote',
#  'Los Angeles, CA 90095',
#  'Sunnyvale, CA•Temporarily Remote',
#  'Los Angeles, CA 90005 (Koreatown area)',
#  'San Diego, CA',
#  'San Francisco Bay Area, CA•Remote',
#  'Oakland, CA 94612 (Downtown area)',
#  'Los Angeles, CA 90017 (Downtown area)',
#  'Palo Alto, CA',
#  'Los Angeles, CA',
#  'Rancho Cordova, CA',
#  'Roseville, CA',
#  'Burbank, CA 91505',
#  'Roseville, CA',
#  'Vernon, CA',
#  'San Mateo, CA',
#  'Costa Mesa, CA 92626',
#  'Los Angeles, CA 90095',
#  'Los Angeles, CA•Temporarily Remote',
#  'Burbank, CA 91505',
#  'Foster City, CA',
#  'San Luis Obispo, CA 93401',
#  'Santa Clara, CA',
#  'California•Remote',
#  'Roseville, CA•Remote',
#  'Santa Clara, CA•Remote',
#  'Santa Monica, CA',
#  'Palo Alto, CA',
#  'California•Remote',
#  'San Francisco, CA',
#  'Rancho Cucamonga, CA•Remote',
#  'Concord, CA 94520',
#  'California•Remote',
#  'Santa Monica, CA•Remote',
#  'Burbank, CA 91505',
#  'Los Angeles, CA 90001•Remote',
#  'Vandenberg AFB, CA 93437',
#  'Cupertino, CA',
#  'Roseville, CA',
#  'Los Angeles, CA 90017 (Downtown area)',
#  'California•Remote',
#  'San Diego, CA 92130 (Carmel Valley area)•Remote',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Santa Cruz, CA 95060',
#  'Pasadena, CA',
#  'Irvine, CA',
#  'Los Angeles, CA',
#  'Los Angeles, CA',
#  'Chatsworth, CA 91311•Remote',
#  'San Jose, CA',
#  'Diamond Bar, CA 91765',
#  'Santa Monica, CA 90403 (Wilshire/Montana area)•Remote',
#  'Santa Monica, CA 90403 (Wilshire/Montana area)•Remote',
#  'Palo Alto, CA',
#  'Irvine, CA',
#  'Los Angeles, CA 90014 (Downtown area)•Remote',
#  'San Francisco, CA•Remote',
#  'Calabasas, CA 91302',
#  'Sunnyvale, CA 94086',
#  'Burbank, CA 91505',
#  'Los Angeles, CA•Remote',
#  'San Rafael, CA 94901 (Downtown area)•Remote',
#  'San Francisco, CA•Temporarily Remote',
#  'Sunnyvale, CA',
#  'California•Remote',
#  'Santa Clara, CA•Remote',
#  'Burbank, CA 91505',
#  'San Jose, CA',
#  'Concord, CA 94520',
#  'Anaheim, CA',
#  'California•Remote',
#  'Santa Clara Valley, CA 95014',
#  'Fremont, CA 94555 (Northgate area)+1 location',
#  'Menlo Park, CA 94025',
#  'Burbank, CA 91505',
#  'Vandenberg AFB, CA 93437',
#  'Sacramento, CA 95828•Remote',
#  'Los Angeles, CA 90048 (Mid City West area)',
#  'Irvine, CA 92618•Temporarily Remote',
#  'Costa Mesa, CA 92626+1 location',
#  'Vandenberg AFB, CA',
#  'Los Angeles, CA',
#  'Fountain Valley, CA',
#  'San Francisco, CA',
#  'Irvine, CA',
#  'San Francisco Bay Area, CA+1 location',
#  'California',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Sunnyvale, CA 94089 (Lakewood area)',
#  'San Diego, CA 92109',
#  'California•Remote',
#  'San Francisco, CA',
#  'San Diego, CA 92121',
#  'Fountain Valley, CA 92708',
#  'Edwards, CA 93523',
#  'San Francisco, CA',
#  'San Jose, CA 95110 (Downtown area)',
#  'Sacramento, CA 95814 (Mansion Flats area)',
#  'San Francisco, CA 94109 (Van Ness - Civic Center area)',
#  'San Francisco, CA',
#  'Santa Clara Valley, CA 95014',
#  'Palo Alto, CA',
#  'French Camp, CA 95231',
#  'Chatsworth, CA 91311•Remote',
#  'San Francisco, CA',
#  'San Jose, CA',
#  'California•Remote',
#  'Sylmar, CA',
#  'San Francisco, CA 94105 (South Beach area)',
#  'Anaheim, CA',
#  'Mountain View, CA 94043•Remote',
#  'Los Angeles, CA 90014 (Downtown area)•Remote',
#  'Burbank, CA 91505',
#  'Burbank, CA 91504',
#  'Long Beach, CA 90840 (State College Area area)',
#  'Sunnyvale, CA•Temporarily Remote',
#  'San Diego, CA',
#  'San Francisco, CA',
#  'Burbank, CA 91505',
#  'Irvine, CA',
#  'Palo Alto, CA+2 locations•Remote',
#  'Novato, CA',
#  'San Francisco, CA•Remote',
#  'San Francisco, CA•Remote',
#  'Los Angeles, CA 90048 (Mid City West area)',
#  'Santa Monica, CA',
#  'Pasadena, CA',
#  'Sunnyvale, CA•Temporarily Remote',
#  'Carlsbad, CA 92010+2 locations',
#  'La Mesa, CA',
#  'Palo Alto, CA',
#  'Los Angeles, CA',
#  'San Francisco, CA',
#  'Palo Alto, CA 94306 (Evergreen Park area)',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Scotts Valley, CA 95066+3 locations•Temporarily Remote',
#  'Sacramento, CA 95825•Remote',
#  'San Francisco, CA',
#  'San Luis Obispo, CA 93401',
#  'California•Remote',
#  'Sunnyvale, CA 94089 (Lakewood area)',
#  'San Francisco, CA',
#  "Stockton, CA (Tam O'Shanter area)",
#  'San Francisco, CA',
#  'Modesto, CA',
#  'Los Angeles, CA 90027•Temporarily Remote',
#  'California•Remote',
#  'San Francisco, CA 94111 (Financial District area)',
#  'San Francisco, CA',
#  'Los Angeles, CA 90014 (Downtown area)•Remote',
#  'Port Hueneme, CA',
#  'Fremont, CA',
#  'Santa Clara, CA',
#  'San Francisco, CA 94108 (Financial District area)',
#  'Culver City, CA 90232 (Downtown area)•Temporarily Remote',
#  'San Francisco, CA',
#  'Cerritos, CA 90703•Temporarily Remote',
#  'Palo Alto, CA 94306 (Evergreen Park area)',
#  'Sunnyvale, CA•Temporarily Remote',
#  'San Francisco Bay Area, CA•Remote',
#  'Mountain View, CA',
#  'Los Angeles, CA•Remote',
#  'Sacramento, CA 95819 (CSUS area)',
#  'Santa Clara, CA•Remote',
#  'Los Angeles, CA',
#  'San Francisco, CA•Temporarily Remote',
#  'San Ramon, CA 94583•Remote',
#  'Irvine, CA',
#  'Sunnyvale, CA 94089 (Lakewood area)',
#  'California•Remote',
#  'Cerritos, CA 90703•Temporarily Remote',
#  'Encinitas, CA',
#  'San Francisco, CA 94105 (South Beach area)',
#  'Santa Clara, CA',
#  'California•Remote',
#  'Los Angeles, CA•Temporarily Remote',
#  'San Francisco, CA',
#  'Bakersfield, CA',
#  'San Diego, CA',
#  'California•Remote',
#  'Pleasanton, CA 94588•Remote',
#  'Long Beach, CA',
#  'San Francisco, CA',
#  'Sunnyvale, CA 94089 (Lakewood area)',
#  'Santa Monica, CA',
#  'San Ramon, CA',
#  'Irvine, CA 92618',
#  'San Bruno, CA',
#  'Irvine, CA 92612',
#  'Los Angeles, CA',
#  'Los Angeles, CA 90010',
#  'Silicon Valley, CA',
#  'Folsom, CA',
#  'Commerce, CA 90040',
#  'Union City, CA',
#  'Los Angeles, CA',
#  'Edwards AFB, CA',
#  'San Francisco, CA',
#  'San Francisco, CA 94105 (South Beach area)',
#  'Santa Ynez, CA 93460',
#  'Los Angeles, CA',
#  'California•Remote',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'Pasadena, CA 91101 (West Central area)',
#  "Stockton, CA (Tam O'Shanter area)",
#  'Los Angeles, CA 90015 (Downtown area)',
#  'San Francisco, CA•Temporarily Remote',
#  'Irvine, CA 92618•Temporarily Remote',
#  'San Leandro, CA',
#  'Redlands, CA 92373',
#  'San Francisco, CA•Remote',
#  'Santa Clara, CA',
#  'Sunnyvale, CA 94089 (Lakewood area)',
#  'Burbank, CA 91505 (Media area)•Temporarily Remote',
#  'Calabasas, CA 91302',
#  'San Francisco, CA•Remote',
#  'Roseville, CA',
#  'Thousand Oaks, CA',
#  'Los Angeles, CA 90057+1 location',
#  'Los Angeles, CA 90025 (Brentwood area)•Temporarily Remote',
#  'Burlingame, CA',
#  'San Jose, CA',
#  'San Leandro, CA',
#  'Los Angeles, CA 90014 (Downtown area)•Remote',
#  'Santa Clara Valley, CA 95014',
#  'Rancho Cordova, CA 95670',
#  'El Segundo, CA 90245',
#  'San Francisco, CA 94105 (South Beach area)•Remote',
#  'Los Angeles, CA',
#  'Sunnyvale, CA 94089 (Lakewood area)',
#  'Burbank, CA',
#  'Oakland, CA',
#  'Burbank, CA',
#  'Mountain View, CA',
#  'Menlo Park, CA 94025',
#  'Oakland, CA 94612 (Downtown area)',
#  'Irvine, CA',
#  'Long Beach, CA',
#  'Ontario, CA 91764•Remote',
#  'Monterey Park, CA',
#  'Santa Monica, CA',
#  'Santa Ana, CA 92705',
#  'Los Angeles, CA•Temporarily Remote',
#  'San Jose, CA',
#  'Costa Mesa, CA 92627',
#  'Sunnyvale, CA 94089 (Lakewood area)',
#  'San Francisco, CA 94129 (Presidio area)',
#  'San Mateo, CA',
#  'Santa Rosa, CA',
#  'Los Angeles, CA',
#  'Edwards AFB, CA',
#  'Redlands, CA 92373',
#  'United States•Remote',
#  'Sunnyvale, CA•Temporarily Remote',
#  'California•Remote',
#  'San Francisco, CA',
#  'California•Remote',
#  'Sacramento, CA•Remote',
#  'Santa Ana, CA',
#  'Irvine, CA',
#  'California•Remote',
#  'Fremont, CA 94538 (Downtown area)',
#  'Dublin, CA 94568',
#  'Thousand Oaks, CA',
#  'Burbank, CA 91505',
#  'Sunnyvale, CA 94089 (Lakewood area)',
#  'San Francisco, CA',
#  'Los Angeles, CA 90068 (Hollywood Hills area)•Remote',
#  'San Francisco, CA',
#  'Sunnyvale, CA (Lakewood area)',
#  'San Francisco, CA 94104 (Financial District area)•Temporarily Remote',
#  'Rancho Cordova, CA 95670',
#  'San Francisco, CA',
#  'Rancho Cucamonga, CA',
#  'Santa Clara, CA 95050',
#  'Roseville, CA',
#  'Petaluma, CA 94954',
#  'San Diego, CA 92108',
#  'Santa Clara, CA 95050',
#  'Silicon Valley, CA',
#  'San Ramon, CA 94583',
#  'Roseville, CA',
#  'Montebello, CA 90640',
#  'Los Angeles, CA',
#  'San Diego, CA 92103 (Hillcrest area)',
#  'San Francisco, CA',
#  'Agoura Hills, CA 91301•Remote',
#  'Long Beach, CA',
#  'Sunnyvale, CA 94089 (Lakewood area)',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Los Angeles, CA',
#  'Pleasanton, CA',
#  'Irvine, CA',
#  'Menlo Park, CA 94025',
#  'California•Remote',
#  'Los Angeles, CA',
#  'Los Angeles, CA 90045 (Westchester area)',
#  'San Francisco, CA',
#  'San Ramon, CA 94583',
#  'Roseville, CA 95661 (Stoneridge area)',
#  'San Francisco, CA 94133 (Russian Hill area)•Temporarily Remote',
#  'Agoura Hills, CA 91301•Remote',
#  'Sunnyvale, CA 94089 (Lakewood area)',
#  'Downey, CA',
#  'San Francisco Bay Area, CA',
#  'Fremont, CA•Temporarily Remote',
#  'San Francisco, CA',
#  'Torrance, CA',
#  'San Francisco, CA 94105 (South Beach area)',
#  'West Hills, CA 91304•Temporarily Remote',
#  'San Francisco, CA',
#  'San Ramon, CA 94583',
#  'San Francisco, CA',
#  'Valencia, CA 91355',
#  'Santa Clara, CA',
#  'Agoura Hills, CA 91301•Remote',
#  'West Sacramento, CA',
#  'Chatsworth, CA 91311',
#  'San Francisco, CA',
#  'Santa Cruz County, CA',
#  'San Jose, CA',
#  'Los Angeles, CA 90014 (Downtown area)•Remote',
#  'Costa Mesa, CA 92627',
#  'Palo Alto, CA 94305',
#  'California•Remote',
#  'San Ramon, CA 94583',
#  'Irvine, CA 92618•Temporarily Remote',
#  'Sunnyvale, CA 94087',
#  'Los Angeles, CA 90001+7 locations',
#  'Woodland Hills, CA 91367',
#  'Agoura Hills, CA 91301•Remote',
#  'Santa Ana, CA 92706',
#  'Los Angeles, CA',
#  'Fremont, CA',
#  'Hayward, CA 94541 (Burbank area)',
#  'Sunnyvale, CA 94089 (Lakewood area)',
#  'San Mateo, CA',
#  'San Luis Obispo, CA',
#  'San Bruno, CA 94066+1 location',
#  'San Ramon, CA•Remote',
#  'Sacramento, CA 95814 (Downtown area)•Temporarily Remote',
#  'Redwood City, CA 94065 (Westport area)',
#  'Los Angeles, CA 90017 (Downtown area)',
#  'Rancho Cordova, CA 95670•Remote',
#  'San Francisco, CA',
#  'San Francisco, CA 94107 (South Of Market area)•Remote',
#  'United States',
#  'Santa Clara Valley, CA 95014',
#  'Corona, CA',
#  'Sunnyvale, CA',
#  'Santa Clara, CA 95050•Remote',
#  'Chula Vista, CA 91911',
#  'Redondo Beach, CA 90278•Remote',
#  'San Francisco, CA 94105 (Financial District area)',
#  'Fountain Valley, CA',
#  'Roseville, CA 95747 (Industrial Area West area)•Temporarily Remote',
#  'Los Angeles, CA•Temporarily Remote',
#  'Rancho Cordova, CA 95670•Remote',
#  'Sunnyvale, CA',
#  'Menlo Park, CA•Temporarily Remote',
#  'San Francisco, CA 94105 (Financial District area)•Remote',
#  'Sunnyvale, CA 94086',
#  'Vista, CA 92081',
#  'Los Angeles, CA 90071',
#  'Los Angeles, CA',
#  'Irvine, CA 92612 (Business District area)',
#  'Los Angeles, CA•Temporarily Remote',
#  'United States',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Irvine, CA•Temporarily Remote',
#  'Carson, CA 90810',
#  'Los Angeles, CA•Temporarily Remote']

# %%
summaries11
# Out:
# ['Strong grasp on data structure and data integrity issues.\nAttention to detail and work ethic for dealing with a variety of data issues.',
#  'Designs and implements processes and solutions associated with a wide variety of data sets used for data/text mining, analysis, modeling, and predicting to…',
#  'They will be responsible for data administration tasks such as pulling data from internal systems to scrub and sort.\n1+ years of Data Administration experience.',
#  'Provides plan with data, reporting, and analyses that enable data-driven decision-making.\nExperience with other relational databases, BI reporting and data…',
#  '\\* Owner of the core company data pipeline, responsible for scaling up data processing flow to meet the rapid data growth;\n目前急招 Full-time.',
#  'Establish best practices around data model governance, data sharing, and scalable reporting in partnership with Finance, Sales Operations, and Data Science.',
#  'Assess the effectiveness and accuracy of new data sources and data gathering techniques.\nPartner and lead cross-functional teams to realize data relationships…',
#  'Put Your Skills to the Test – Analyze data to test hypotheses and answer business questions.\nThe Consumer Insights, Measurement, and Analytics (CIMA)…',
#  "As an entry level data analyst you'll get hands on experience using data to build better software.\nThe job of the entry level data analyst requires a breadth of…",
#  'Strong at data analysis – SQL, Snowflake.\nMoreover, the offices have been designed to foster creativity and communication, bringing a little bit of home into…',
#  'Great attention to detail; experience delivering exceptional quality in reports and data analysis.\nAbility to bring data to life for any audience via written…',
#  'Responds to data requests for grant/proposal preparation and other needs of the agency 6.\nDesigns data collection instruments, including forms and fields in…',
#  'To support that mission, they are now looking for a strong data / business analyst to help drive their marketing efforts.\nData Science Tools (Python, R, etc.).',
#  'Determine additional data collection and reporting requirements.\nUse system reports and analyses to identify potentially problematic data, make corrections, and…',
#  'This individual will also manipulate data and create new data fields to enhance our ability to use data for informed decision making.',
#  'To support that mission, they are now looking for a strong data / business analyst to help drive their marketing efforts.\nData Science Tools (Python, R, etc.).',
#  'Determine additional data collection and reporting requirements.\nUse system reports and analyses to identify potentially problematic data, make corrections, and…',
#  'This individual will also manipulate data and create new data fields to enhance our ability to use data for informed decision making.',
#  'Experience visualizing data and creating reports.\nExperience identifying and adapting to imperfect data.\nLeverage a combination of internal and external data…',
#  '3-5 years exp with SQL, and working with multiple datasets.\nExperience working with/on data warehouses, including data architecture, ETL tools/workflows, a plus…',
#  'Work with additional data analysts/technicians to identify trends in data and service technician areas of improvement.',
#  'Advanced Excel skills and experience working with large data sets.\nAsset Failure Data Manipulation– Investigate asset failure via field reports and collect…',
#  'Experience building out large data sets and pipelines.\nData pipelines: 6 years (Preferred).\nExperience problem solving and providing business insights and…',
#  'Analyze, interpret, summarize, and present administrative and technical information and data in an effective manner.\nRecord keeping principles and procedures.',
#  'Analyze data to derive insights and develop data visualizations to cultivate decision making.\nCreate data sources in Tableau to support reporting for internal…',
#  'Maintains enterprise dataset data dictionaries and definitions.\nThe person in this role will be required to work with the BI team to identify the data needs,…',
#  'Attention to detail and accuracy, sound judgment.\nThe Business Data Analyst should have a passion for working with the Commercial Team and customers, as well as…',
#  'Data Quality: Perform general data quality control tasks.\nOne to three years of data industry experience (preferred).\nStrong Individual and team work ethics.',
#  "Perform exploratory data analysis to confirm data integrity and to derive appropriate analytical attributes.\nExperian's Decision Analytics team is looking for a…",
#  'Support initiatives related to data hygiene and integrity.\nIdentify, analyze, and interpret trends, alarms, events or patterns in complex data sets within the…',
#  'Create SAS and/or Stata datasets from raw data and write data analysis programs.\nAdhere to data security requirements.\nPerforming programming and data analyses.',
#  'Advanced Excel skills and experience working with large data sets.\nAsset Failure Data Manipulation– Investigate asset failure via field reports and collect…',
#  "The data analyst will work on our data team alongside data scientists and software engineers.\nThe objective is to increase the data team's capacity for…",
#  'Collect and aggregate data from published medical literature and appendices.\nThe ideal candidate will be a motivated, communicative and collaborative data…',
#  'Good knowledge and understanding of Edwards policies, procedures and guidelines relevant to data analytics.\nThis is a new position on our growing Data Analytics…',
#  'Conduct data analysis and insightful visualizations.\nExperience with data mining and machine learning will be a plus.\nFamiliar with Python or SQL.',
#  'Analyze data, propose and implement programmatic rules to handle abuse at scale.\nWe’re looking for a Protector of the Realm whose sworn duty is to defend our…',
#  'To support that mission, they are now looking for a strong data analyst / data scientist who understands B2C marketing and can drive analytics in this space.',
#  'Develop and maintain data dictionaries and other data management documents (fidelity check lists, data plans and specifications, etc.) to support teams with…',
#  'This recruitment is open to the public for a minimum of five (5) business days and will remain open on a continuous basis until 11:59 p.m. (PST) on the day the…',
#  'Experience with analytic reporting, data interpretation, and effective communication of findings to varied audiences.\nRead on to learn more….',
#  'Experience extracting data from RDBMS system.\nExperience with Microsoft Excel and experience performing data cleansing activities in an excel.',
#  'Apply your expertise in quantitative analysis and data presentation to identify, analyze and provide insights into large data sets.',
#  'Being detail-oriented and capable of delivering a high level of accuracy.\nAt Pitney Bowes, we do the right thing, the right way.',
#  'Pathways is an Excepted Service Appointment, Schedule D, 5 CFR Part 362, and may NOT be combined with other Excepted Service Appointments (e.g., Schedule A).',
#  'Advanced Excel skills and experience working with large data sets.\nAsset Failure Data Manipulation– Investigate asset failure via field reports and collect…',
#  'Experience framing business questions with data and translating business needs into actionable data deliverables - processes, analyses, reports, and datasets.',
#  'Act as a data steward to monitor and improve overall data quality.\nDocumenting data flows and processes.\nExperience profiling data, including data discovery,…',
#  'Digital marketing: 2 years (Required).',
#  'Assist in creating data best practices and documentation to help streamline data operations.\nAdvanced proficiency in data manipulation including SQL, python or…',
#  'Expertise in SQL for data management and data analysis.\nDetermine additional data collection and reporting requirements.',
#  'You will apply functional knowledge of data analysis, data visualization, report writing, data integration, and Cloud environments in order to perform the…',
#  'Gathering data from across various data sources, cleaning that data, and working with the CTO to help craft the story for our Series A round later in the year.',
#  'If you are a current City of Redding Employee and took and passed the Management Analyst examination within the last 5 years, you are not required to retest and…',
#  '1 to 3 years data analyst experience.\nThe analyst designs, creates and analyzes data reports for results, trends and variations.',
#  'Build new data assets by merging data from multiple data sources.\nDeliver business insights by building dashboards, reports and analyst views.',
#  'You should be comfortable doing both exploratory evaluations of data in a big data environment and identifying new cutting-edge data sources to drive commercial…',
#  'Assist with software deployments and data integration projects.\nAnalyze data / systems and develop detailed specifications for implementation.',
#  'Translate requirements into applicable data requirements.\n4+ years of experience solving complex data problems.\nExperience with Linux/OSX command line and git.',
#  'Passion for data, technology and people.\nAdvanced ability to perform exploratory data analysis.\nStrong analytical capabilities to translate business problems…',
#  '2 years of experience in data modeling, data retrieval and gathering, transforming and manipulating data.\n4 years of experience manipulating data sets using SQL…',
#  'Solid organizational skills including attention to detail and multitasking skills.\nCommunicate and liaison with senior stakeholders on key changes and ensure to…',
#  'Advanced Excel skills and experience working with large data sets.\nAsset Failure Data Manipulation– Investigate asset failure via field reports and collect…',
#  'Comfort working with data systems and learning new data systems.\nThe Assistant Data Analyst works within the HFH Policy & Procurement data team and supports the…',
#  'Must have familiarity with Public pension systems.',
#  'The user acquisition analytics role is building the foundation that will shape analytics and automation for user acquisition across Activision.',
#  'A master of healthcare data, data quality management, systems analysis, and statistical analysis including: health system information systems and data flow and…',
#  'Gathers data and identifies and forecasts program costs.\nLeads the employee data auditing process and generates complex reports.',
#  '1-3 years of experience required in data analysis, research, visualization, and communication.\nRespond promptly, accurately and efficiently to data requests and…',
#  'Develops and automates data and analytics solutions, iteratively builds dashboards to provide data insights on demand.\n4 Years – Experience working in Position.',
#  'Must have at least 2 years of related experience, including preparing, analyzing and reporting on market and sales data.\nRight to Work (English/Spanish).',
#  'Tests and maintains data integrity.\nUnder close supervision, this position exists to assist the organization in making strategic data-related decisions by…',
#  'Work with other analysts to process large data to transform to usable information.\nMinimum 6 years prior business analytics and data analysis experience.',
#  'Development of data collection processes and data management systems.\nInitiative to develop tools, data collection processes, and data management systems.',
#  'Must have a strong background in statistical analysis, including developing data models, preparing reports, and data presentation.\nShift Hours:8 Hour Shift.',
#  'Development of data collection processes and data management systems.\nInitiative to develop tools, data collection processes, and data management systems.',
#  'Must have a strong background in statistical analysis, including developing data models, preparing reports, and data presentation.\nShift Hours:8 Hour Shift.',
#  'Advanced Excel skills and experience working with large data sets.\nAsset Failure Data Manipulation– Investigate asset failure via field reports and collect…',
#  'The Studio Analytics team is responsible for developing a strategy and vision for cross-functional and complex data analysis projects.',
#  'Partner with analytics and data engineering teams to identify and close gaps in logging and data infrastructure.',
#  'You will analyze internal processes, data, and problems and identify benefits from enabling new capabilities within the business.',
#  'Advanced proficiency with analytics, data manipulation and primary research.\nYou will analyze market trends, cold chain product innovations, and climate…',
#  'Monitor data quality and drive issues to resolution.\nAs a Data Analyst at ActiveVideo, you will play a key technical role in driving our success by providing…',
#  'Daily analysis of all data is necessary in order to complete weekly reporting to internal team, manager, and cross-functional teams.',
#  'Designs and implements processes and solutions associated with a wide variety of data sets used for data/text mining, analysis, modeling, and predicting to…',
#  'Leverage global reporting, analysis, and business modeling to translate data into insights to proactively drive action.',
#  'Understand the requirements of partners and map them with the data sources/data warehouse.\nPartner with Data Governance and engineering teams to define the data…',
#  "Empower the Product team to access data independently by training them on Trove's data, self-service tools, and analytical methodologies.",
#  'Experience with data quality processes, data quality checks, validations, data quality metrics definition and measurement.',
#  'Analyze raw data sources and data transformation requirements.\nWork collaboratively with business teams including data scientists, business intelligence…',
#  'Collect and extract data from data warehouse.\nPerforms comprehensive data profiling, analysis, predictive analysis or forecasting.\nM, DAX, R a plus.',
#  'Updates and maintains college data tracking spreadsheets and file records.\nAbility to prepare questionnaires, gather and analyze research data, and compile data…',
#  "Performs forecasting and reconciliation of internal data.\nCompiles and analyzes data to support organization's strategic initiatives.",
#  'Advanced Excel skills and experience working with large data sets.\nAsset Failure Data Manipulation– Investigate asset failure via field reports and collect…',
#  'Analyze data and produce report as required.\nThe primary responsibility of this position is to enter data and provide oversight to the inventory System.',
#  'Ability to manage and analyze data.\nKnowledge of business statistics and data analyses techniques.\nProvides recommendations and conclusions gained from…',
#  'For example, the morning hours from 8 to 12 would be dedicated to specific needs pertaining to Synergy’s SoCal Division and the hours from 1 to 5 would be…',
#  'Collects and generates original data sets for the purpose of complementing existing data sets and identify errors.\nInvolves draft editing of Economics papers.',
#  'Comfort interpreting a variety of different data sources from qualitative research to primary survey data to secondary data sources and creating one cohesive…',
#  'Perform descriptive and inferential analysis of data.\nPrepare tables, graphs and other data visualizations to present results.',
#  'The individual will work with quantitative data including basic data analysis, data validation, data cleaning, and analysis and interpretation of research…',
#  'Convert information gathered into details including data sources, data and user type.\nCapitalPlanHoldings is looking for a Business Analyst, who will be…',
#  'Attention to detail and with strong data analysis and problem-solving skills.\nWorking knowledge of SQL, ETL, data cleansing, and various data visualization…',
#  'Understanding of data warehousing concepts, design, modeling and data engineering.\nCollaborate with data scientists, engineers, and business partners to solve…',
#  'Offering both full-time and internships positions.\nAs our primary in-house client advocate, the Business Analyst works closely with the client stakeholders and…',
#  'Conduct data processing, data fusion and statistical analysis by applying database tools.\nApply data mining principles to perform data analysis of the…',
#  'OR Three (3) full years of progressively higher level graduate education leading to a Ph.D. or equivalent doctoral degree in a related field of study OR LL.M.…',
#  '1-3 years of work experience in data analytics/science.\nStrong analytical mindset with a drive toward actionable insights from data.',
#  'Present data analysis findings and/or translate data into an understandable document or dashboard.\nStrong SQL with experience in querying large, complex data…',
#  'Data analytics: 5 years (Preferred).\nThe in depth data analysis is must as customer is looking for possible business solution that helps the BI part to be more…',
#  'You will research, collect, and analyze data, leverage internal and external resources, and data sources to report on successes and actionable opportunities for…',
#  'Analyzes the interrelationships of data and defines logical aspects of data sets.\nMay supervise data entry, database management and research analysis of…',
#  'The Data Analyst will conduct data analytics using CAIR data to identify gaps and disparities in immunization coverage from over 11,000 participating clinical…',
#  'You will have contributed to ongoing company efforts to manage our massive, often noisy, and continuously changing, data streams.',
#  'Research analyst for data integration in support of financial, operating, and productivity reporting processes.',
#  'Extract, Transform and Blend data from various and disparate internal/external data sources.\nKnowledge of account services and data analytics.',
#  'Exceptional analytical skills, comfortable working with large amounts of data and communicating data findings.',
#  'Acquire data from primary or secondary data sources and maintain databases/data systems.\nTechnical expertise, regarding data models, database design development…',
#  'Advanced SQL experience, query optimization, data extract.\nConduct complex analysis and build models to uncover key learning form data, leading to appropriate…',
#  'Ensure robust data handling data of new and existing resources.\nDefining goals for data management and strategizing how to use data resources most effectively.',
#  'Job Types: Full-time, Contract.\nTemporarily due to COVID-19.',
#  'Good Knowledge of: Statistics, data processing software; data collection instrument development; community college programs.',
#  'Experience using data visualization tools (i.e., Domo, Tableau, Looker); comfortable transforming data into actionable insights.',
#  'As the first data analyst on our Analytics team, you will help shape and guide the understanding of our marketplace and customer experience through insights,…',
#  'If you are a current employee, please STOP and apply through the Careers Application in Workday Job Description Summary: Job Description: Enjoy a career…',
#  'Job responsibilities include: preparing daily, weekly, monthly, and quarterly reports via Excel and SQL, interpreting and analyzing data from primary and…',
#  'Work with BI engineers to ensure data accuracy and develop efficient processes for data retrieval.\nCollaborate with regional sales teams to ensure quality of…',
#  'Data is central to decision-making at Standard, and an analyst plays a critical role in informing and evangelizing data-driven decision making across all of our…',
#  'These positions function both as a consultant and as a high-level data analyst.\nThe Data Analytic Consultant provides support in making strategic data-related…',
#  'Ability to manipulate and analyze data to produce accurate results and tell a story of those results in data visualizations, dashboards, and reports.',
#  'Mining data to identify patterns for predictive insights.\nCapable of working with data in Python, R and SQL.\nUnderstand and document inputs and outputs of data…',
#  'The Data Management Analyst responsibilities include the collection and preparation of test data from test facilities for data analysis; provide technical…',
#  'Write SQL to aggregate and process data across multiple data source.\nThe manufacturing quality data engineering team is responsible for performing advanced…',
#  'Minimum of one years experience as an analyst, developer, data scientist, business analyst, or quality assurance specialist.',
#  'The Business Analyst primary goal is to provide support as needed to the Contact Center for Automobile, Power Equipment, and Powersports personnel.',
#  'Strong ability to model data to meet reporting requirements.\nPerform complex analysis of datasets and conduct regular data validation and governance.',
#  'Identify areas for data quality improvements and help to resolve data quality problems and communicate updates to stakeholders at multiple levels.',
#  "Bachelor's Degree and 3 years of related experience in data management.\nDevelop insights and analytics by applying expertise in data analysis and data mining…",
#  '4+ years of work into data analytics.\nComfortable with both structured and unstructured data.\nYou will create data driven attribution statistical models of…',
#  '5+ years of experience in a data analyst role working directly with databases.\nStrong understanding of data warehouse concepts.',
#  'Experience with data visualization and storytelling.\nAnalytics and data accuracy go hand-in-hand with this role.\nHands on experience with Domo.',
#  'Collaborate with Engineering to advance data infrastructure and governance.\nWork closely with business partners to extract meaningful insights using a variety…',
#  '1-3 years of equivalent experience as an analyst in a data and analytics domain, in a professional or academic setting.',
#  'Experience with data lakes, ETL, Data pipelining and data warehousing.\nManage data requests in JIRA and summarizes data findings and processes in JIRA and…',
#  '2-4 years of experience in a data analysis role.\nExperience with data warehousing (e.g. AWS Redshift or similar).\n8 Weeks of Parental Leave.',
#  'Foster a culture of broad access to data and autonomy in obtaining answers by implementing dashboards and other tools that helps your data customers extract,…',
#  'Filter and “clean” data by reviewing customer data sets.\nAcquire data from primary or secondary data sources, utilizing internal ETL tools.',
#  'Problems not solutions - engineers focus on solving problems, not building solutions handed to them.',
#  "2+ years of experience in data analytics.\nExcellence in logical thinking, problem solving and proven familiarity with big data.\nBachelor's degree is required.",
#  'Collects and generates original data sets for the purpose of complementing existing data sets and identify errors.\nInvolves draft editing of Economics papers.',
#  'Experience with data lakes, ETL, Data pipelining and data warehousing.\nManage data requests in JIRA and summarizes data findings and processes in JIRA and…',
#  "Interface with data consumers to understand organization's data needs.\nWe own the data pipelines that brings data together from different sources and help…",
#  'Manage product and inventory data via ecommerce platforms and combine data from multiple sources.\nExpert understanding of large datasets; proficiency and strong…',
#  'Knowledge of data architecture, data modeling, data mapping, data analysis, and data visualization.\nExcellent analytical skills to forecast and predict trends…',
#  'Expert fluency in SQL-based data manipulation.\nOur ideal candidate is a "full-stack" data powerhouse who uses data to drive decision-making to make the best…',
#  'Devising, implementing and documenting comprehensive data quality checks to ensure data are clean and ready for analysis.\nStrong writing and analytical skills.',
#  'Ability to pull data writing complex SQL queries in different data sources.\nPerform data segmentation and aggregation from scratch.',
#  'Prior Amplitude experience and at least 2–5 years experience working with product analytics data.\nBeing an excellent analyst: Uncover business questions.',
#  'Problems not solutions - engineers focus on solving problems, not building solutions handed to them.',
#  'Solid organizational skills including attention to detail and multitasking skills.\n*Proven experience working with data process mapping, order to cash,…',
#  'Build internal tools that support the analytical needs of functional data analysts.\nSupport internal data automation and enablement efforts in partnership with…',
#  '4-8 years experience in an analytics or data related role.\nExperience with SQL and large data sets (terabyte scale) is a must.',
#  'Data analytics: 5 years (Preferred).\nThe in depth data analysis is must as customer is looking for possible business solution that helps the BI part to be more…',
#  '3 - 5 years of work experience in analytics in technology, financial services, management consulting, or other similar industries.\nDegree in a STEM area.',
#  "Analyze data across our marketing channels and internal systems to understand and strategize around our user base.\nBachelor's degree, or equivalent experience.",
#  '3-5 years exp with SQL, and working with multiple datasets.\nExperience working with/on data warehouses, including data architecture, ETL tools/workflows, a plus…',
#  'Hands on experience managing data quality and master data.\nThis role will require existing knowledge of master data management tools and processes and the…',
#  'Develop and maintain data dictionaries and other data management documents (fidelity check lists, data plans and specifications, etc.) to support teams with…',
#  'Experience with NetSuite data or Salesforce data.\nPassion for data quality and delivering effective data to impact the business.',
#  'Collaborate with cross-functional partners to tackle challenges where product data and broader business data intersect.\nUnlimited time off and sick days.',
#  'Experience working with/on data warehouses, including data architecture, ETL tools/workflows, a plus.\nExperience with one or more data visualization business…',
#  'Experience working with data, querying, and analyzing data.\nProgramming skills and experience, especially for data exploration and presentation to management…',
#  'Monitoring games through data to identify data anomalies and risks- Follow up these problems in time;\nMore than 2 years of experience in data analysis and data…',
#  'Familiarity with Directed Acyclic Graph data.\n2+ years of experience data analytics in an enterprise setting.\nHigh proficiency with Microsoft Windows and Office…',
#  'Minimum five (5) years of related analytical or consulting in technology/data science experience.\nCollaborate with other analysts on assigned components of…',
#  '7+ years data analyst or related experience, including proficiency with analytical software or equivalent related education.',
#  'Must have familiarity with Public pension systems.',
#  'BI governance including data dictionary, report integrity, data quality and data audits.\nExperience with querying and exploring data stored in data warehouses.',
#  'The Data Analyst strategically supports the Informatics team as well as internal business units to analyze key data to encourage data-driven decisions.',
#  'Guide and monitor data management processes to ensure data quality and consistency in support of business initiatives, including acquiring new data sources and…',
#  'A master of healthcare data, data quality management, systems analysis, and statistical analysis including: health system information systems and data flow and…',
#  'Have extensive experience working with health care claims data (large datasets, millions of records) (required).\nHave expert knowledge of Tableau (required).',
#  'Monitors data collection activities and quality of data.\nDevelops and maintains data collection and data management systems.',
#  'Develop automated applications surrounding database data extracts and data cleansing routines.\nWide experience with programming, data mining, network security,…',
#  'Build scalable data products, self-service tools, data cubes to analyze and present data associated with acquisition, retention, product performance, operations…',
#  '3-5 years of relevant experience working with Product teams.\nPartner with Data Engineering to craft our data infrastructure investments in support of BI needs…',
#  'Expert fluency in SQL-based data manipulation.\nOur ideal candidate is a "full-stack" data powerhouse who uses data to drive decision-making to make the best…',
#  'Identify data, metrics and analyses needs for business partners; Initiate, develop and maintain data pipelines and data models that powers dashboards and data…',
#  'You have 3-5 years of experience in data analysis.\nMonitor data streams, collect and record marketing data in dashboards and scorecards.',
#  'The Data Analyst will conduct data analytics using CAIR data to identify gaps and disparities in immunization coverage from over 11,000 participating clinical…',
#  'Identifies key capitation data shifts and presents findings.\nCompiles capitation payments data for analysis and trending purposes.',
#  "Interface with data consumers to understand organization's data needs.\nWe own the data pipelines that brings data together from different sources and help…",
#  'Minimum 3 years’ experience in a similar data management role.\nDevelop subject matter expertise for enterprise data, including understanding system dependencies…',
#  'They will be responsible for NDT method validation, data collection techniques, data manipulation, data analysis, report processing, and employee certification…',
#  'Update PFEP data on regular cadence.\nProvide data and support lineside & replenishment market calculations.\nWe are currently seeking a Logistics Data Analyst.',
#  'You will leverage technical and analytical skills to mine data for delivering business insights.\nPerforms regular audits of reported information to verify…',
#  'Provide ad hoc analysis to support data team, business units, and key stakeholders for complex data quality questions.\nSQL, DQ tools, Data Engineering.',
#  'Perform data modeling, data analysis, and development of key performance indicators.\n2-3 years of experience in data mapping and/or integration documentation…',
#  'Solid organizational skills including attention to detail and multitasking skills.\n*Proven experience working with data process mapping, order to cash,…',
#  'BI governance including data dictionary, report integrity, data quality and data audits.\nExperience with querying and exploring data stored in data warehouses.',
#  'Experience with Tableau, Power BI or similar data visualization tool.\nLeveraging data to identify ways to grow revenue, customer engagement and conversion.',
#  'Provide analysis of the data.\nManage intake of data from internal and external sources.\nPrimary duty will be to accept data from multiple sources, both internal…',
#  'Build automated data quality check using combination of advanced SQL and Tableau, to ensure that data refreshes meet quality thresholds.',
#  '" button above or please send your resume and a cover letter to jobs@mtaltd.com. Include “Data Analyst” in the email heading. Equal Opportunity Employer…',
#  'Identify innovative techniques and ideas regarding routine processes used to gather and analyze data and maintenance of data in databases that will increase…',
#  'Experience with data visualization and storytelling.\nAnalytics and data accuracy go hand-in-hand with this role.\nHands on experience with Domo.',
#  'Familiarity with data engineering, data design and ETL.\nPartner closely with business stakeholders and other data teams to improve platform capabilities around…',
#  'Have extensive experience working with health care claims data (large datasets, millions of records) (required).\nHave expert knowledge of Tableau (required).',
#  "Interface with data consumers to understand organization's data needs.\nWe own the data pipelines that brings data together from different sources and help…",
#  'Three of more years of experience as a business or systems analyst using structured methods to elicit functional or technical requirements for systems…',
#  'The ideal candidate is an intelligent, sharp, detail-oriented, and highly quantitative individual who loves working with and analyzing data.',
#  'Experience with data management, specifically with building data systems and validating reports from disparate systems.\nExperience with R or Python.',
#  'Present data analysis findings and/or translate data into an understandable document or dashboard.\nStrong SQL with experience in querying large, complex data…',
#  'A master of healthcare data, data quality management, systems analysis, and statistical analysis including: health system information systems and data flow and…',
#  'Filter and “clean” data by reviewing customer data sets.\nAcquire data from primary or secondary data sources, utilizing internal ETL tools.',
#  'At least five (5) years of experience designing, developing, debugging and supporting complex data conversion processes using SQL Server.',
#  'Identifies key capitation data shifts and presents findings.\nCompiles capitation payments data for analysis and trending purposes.',
#  'Basic Qualifications:* 2-3 years of month-end close, general ledger accounting, and reporting experience.\nEffective in managing competing priorities with high…',
#  'Expertise in building Excel-based financial models, with an emphasis on aggregating and analyzing data to provide actionable insights.',
#  'Expert fluency in SQL-based data manipulation.\nOur ideal candidate is a "full-stack" data powerhouse who uses data to drive decision-making to make the best…',
#  '1-4 years data analyst experience using business intelligence reporting tools.\nAnalyze business unit existing systems and flows of data.',
#  'Assist with data discovery for enhancing reports and designing efficient data stores.\nCollaborate cross-functionally with analysts, engineers, to identify &…',
#  '7+ years data analyst or related experience, including proficiency with analytical software or equivalent related education.',
#  'Build analytics to collect, process, and analyze huge sets of data.\nHave the ability to write ETL jobs to extract data for the analytics.',
#  '3 - 5 years of work experience in analytics in technology, financial services, management consulting, or other similar industries.\nDegree in a STEM area.',
#  'Apply your expertise in quantitative analysis and data presentation to identify, analyze and provide insights into large data sets.',
#  'Familiarity with Directed Acyclic Graph data.\n2+ years of experience data analytics in an enterprise setting.\nHigh proficiency with Microsoft Windows and Office…',
#  '" button above or please send your resume and a cover letter to jobs@mtaltd.com. Include “Data Analyst” in the email heading. Equal Opportunity Employer…',
#  "Interface with data consumers to understand organization's data needs.\nWe own the data pipelines that brings data together from different sources and help…",
#  'Support planned and ad-hoc data analysis efforts and issue resolution for master data topics.\n2+ years in a highly accurate and data-driven environment where…',
#  'Perform data modeling, data analysis, and development of key performance indicators.\n2-3 years of experience in data mapping and/or integration documentation…',
#  'Experience working in a data driven digital marketing environment.\nPassion for leveraging and interpreting data to drive significant business impact.',
#  'Basic Qualifications:* 2-3 years of month-end close, general ledger accounting, and reporting experience.\nEffective in managing competing priorities with high…',
#  'Partner with the data engineering team to drive the development of our data infrastructure, including data warehousing, reporting, and analytics platforms.',
#  'Strong ability to model data to meet reporting requirements.\nPerform complex analysis of datasets and conduct regular data validation and governance.',
#  'Provide ad hoc analysis to support data team, business units, and key stakeholders for complex data quality questions.\nSQL, DQ tools, Data Engineering.',
#  'Advanced SQL experience, query optimization, data extract.\nConduct complex analysis and build models to uncover key learning form data, leading to appropriate…',
#  'At least 3-5 years of experience in designing, developing, and generating ad hoc/production reports.\nAnalytic skills include the ability to identify data…',
#  'Perform descriptive and inferential analysis of data.\nPrepare tables, graphs and other data visualizations to present results.',
#  'The candidate will oversee and manage all data entry into various tracking tools and provide continuous maintenance and support to ensure data accuracy.',
#  'Expert fluency in SQL-based data manipulation.\nOur ideal candidate is a "full-stack" data powerhouse who uses data to drive decision-making to make the best…',
#  'Familiarity with data engineering, data design and ETL.\nPartner closely with business stakeholders and other data teams to improve platform capabilities around…',
#  'Comfort working with data systems and learning new data systems.\nThe Assistant Data Analyst works within the HFH Policy & Procurement data team and supports the…',
#  '3-5 years employment with focused concentration on conducting, analyzing and reporting survey market research studies preferred, either at a full-service…',
#  'Partner with the data engineering team to drive the development of our data infrastructure, including data warehousing, reporting, and analytics platforms.',
#  'Provide ad hoc analysis to support data team, business units, and key stakeholders for complex data quality questions.\nSQL, DQ tools, Data Engineering.',
#  'Be an expert in digital data; understand data sources and nuances of each account.\nExperience with analytical data systems used to pull and analyze sales data…',
#  'Good database analytics and data extraction (SQL) skills are essential, ideally gained in a large data warehouse environment.',
#  'Under general supervision, this position exists to assist the organization in making strategic data-related decisions by analyzing, manipulating, tracking,…',
#  'Proficiency with data, analytics, and visualization technologies (we use SQL and Looker).\nUse data to drive analysis and actionable recommendations to shape…',
#  "Interface with data consumers to understand organization's data needs.\nWe own the data pipelines that brings data together from different sources and help…",
#  'You will leverage technical and analytical skills to mine data for delivering business insights.\nPerforms regular audits of reported information to verify…',
#  'Production data manipulation and formatting.\nData analysts will perform the pre- and post-modeling data review and manipulation for the Statistical Analysts.',
#  'Build analytics to collect, process, and analyze huge sets of data.\nHave the ability to write ETL jobs to extract data for the analytics.',
#  'You will research, collect, and analyze data, leverage internal and external resources, and data sources to report on successes and actionable opportunities for…',
#  'Implement best practices in our data analytics and full lifecycle of data.\nKnowledge of data-gathering tools (i.e. Google Analytics, Parse.ly, Segment) and…',
#  'Collaborate with other teams across Blizzard ensuring the improvement of data tools, and the correct use and interpretation of data.',
#  'If you are curious about data driven companies, have problem solving skill sets, detail oriented and love analysis we’d love to talk to you.',
#  'Experience with analytic reporting, data interpretation, and effective communication of findings to varied audiences.\nRead on to learn more….',
#  'Comfort interpreting a variety of different data sources from qualitative research to primary survey data to secondary data sources and creating one cohesive…',
#  'Leverage global reporting, analysis, and business modeling to translate data into insights to proactively drive action.',
#  'Data Analysis - Determine the necessary data required to solve a wide variety of business problems; extract required data, and draw conclusions and…',
#  'Partner with the data engineering team to drive the development of our data infrastructure, including data warehousing, reporting, and analytics platforms.',
#  '1-4 years data analyst experience using business intelligence reporting tools.\nAnalyze business unit existing systems and flows of data.',
#  '(data warehouses/SQL, unstructured data: 5 years (Preferred).\nStrong desire and experience with data in various forms (data warehouses/SQL, unstructured data).',
#  'Working experience with data analysis and data reporting.\nWorking experience with data analysis and data reporting.\nExperience in SQL (ANSI or Oracle).',
#  'Data analyst with Support experience.\nMonitoring data pipeline and Integrity is complete.\nRun machine learning algorithms to find data anomalies.',
#  'Identify areas for data quality improvements and help to resolve data quality problems and communicate updates to stakeholders at multiple levels.',
#  "Bachelor's Degree and 3 years of related experience in data management.\nDevelop insights and analytics by applying expertise in data analysis and data mining…",
#  'Experience summarizing complex data down to the "so what", especially for a non-data savvy audience.\nWork alongside other data staff in guiding and defining…',
#  'You will demonstrate analytical thinking and make data-driven decisions.\nImprove tools or systems by influencing key stakeholders with data and analysis.',
#  'Working experience with data analysis and data reporting.\nWorking experience with data analysis and data reporting.\nExperience in SQL (ANSI or Oracle).',
#  'Aptitude for interpreting data to find insights to drive recommendations.\nAbility to influence cross-functional partners by leveraging data and insights.',
#  'Democratize our data by proposing and developing new data products, data pipelines and tools and provide documentation and training to stakeholders.',
#  'Participate in enterprise-level metadata, master data management and data governance initiatives.\nPreferably experience in data visualization.',
#  '3+ years of experience visualizing and analyzing data as a data analyst/ data scientist.\nExperience with data lakes and data warehouse.',
#  "Performs forecasting and reconciliation of internal data.\nCompiles and analyzes data to support organization's strategic initiatives.",
#  'The Data Analyst strategically supports the Informatics team as well as internal business units to analyze key data to encourage data-driven decisions.',
#  'Be an expert in digital data; understand data sources and nuances of each account.\nExperience with analytical data systems used to pull and analyze sales data…',
#  'Design metrics with the help of the senior data analysts, build reports and dashboards that help the product and marketing teams and all the stakeholders better…',
#  'Proficiency with data, analytics, and visualization technologies (we use SQL and Looker).\nUse data to drive analysis and actionable recommendations to shape…',
#  '5-10 Years of experience with data visualization/BI tools, such as Qlik or Tableau, SQL and semantic data access mechanisms.',
#  'At least 3-5 years of experience in designing, developing, and generating ad hoc/production reports.\nAnalytic skills include the ability to identify data…',
#  '2-4 years of experience in a data analysis role.\nExperience with data warehousing (e.g. AWS Redshift or similar).\n8 Weeks of Parental Leave.',
#  'Work closely with data engineers/scientists to automate the collection/analysis of raw data for models;\nAssist in extracting and analyzing data from large data…',
#  'Monitor the quality and timeliness of program data across data systems.\nPerform data entry, cleaning, and validation in both ECS-run and external data systems.',
#  'BI governance including data dictionary, report integrity, data quality and data audits.\nExperience with querying and exploring data stored in data warehouses.',
#  '2-4 years of experience in a data analysis role.\nExperience with data warehousing (e.g. AWS Redshift or similar).\n8 Weeks of Parental Leave.',
#  'The MRM Data Science & Reporting Team produces financial management reports , quantifies asset/liability P/L changes and communicates results to senior…',
#  'Experience in analyzing data to draw business-relevant conclusions.\nSoFi Stadium and Hollywood Park is seeking a business analyst who can assist with analyzing…',
#  'Provide ad hoc analysis to support data team, business units, and key stakeholders for complex data quality questions.\nSQL, DQ tools, Data Engineering.',
#  'Familiarity with data engineering, data design and ETL.\nPartner closely with business stakeholders and other data teams to improve platform capabilities around…',
#  'Strong ability to model data to meet reporting requirements.\nPerform complex analysis of datasets and conduct regular data validation and governance.',
#  'Experience building aggregates and optimizing data workstreams.\nExpert fluency in SQL-based data manipulation.\nYou will report to the Head of Creator Products.',
#  "2+ years of experience in data analytics.\nExcellence in logical thinking, problem solving and proven familiarity with big data.\nBachelor's degree is required.",
#  'Use statistical methods to analyse data and generate useful business reports.\nVery good programming skills, preferably in ‘R’ language.',
#  'Analyze promo delivery data and provide relevant and actionable insights to optimize campaign performance.\nThe successful candidate has a passion for leveraging…',
#  '2+ years data analyst experience.\nIdentify needs, delegate internally, and take initiative as needed to maintain data compliance.',
#  'Experience with user behavior data.\nStrong Excel skills and the ability to manage and analyze large sets of data.\nComfortable with advanced SQL queries.',
#  'The Specialist is also responsible for assisting the Database Administrator with data requests and reporting.\nReporting to the Director of Advancement Services,…',
#  'Acquire data from primary or secondary data sources and maintain databases/data systems.\nStrong data and analytic skills, knowledge of excel, numbers and data…',
#  'Perform routine and ad hoc data maintenance.\nWork experience in data extraction from multiple databases.\nEvaluate and confirm incoming/outgoing data sets meet…',
#  'You have a passion for numbers, data visualization and turning massive amounts of data into digestible and actionable content.',
#  'Analyze data and produce report as required.\nThe primary responsibility of this position is to enter data and provide oversight to the inventory System.',
#  'Comfortable in a complex data environment and understanding of data structures.\nKnowledge of data visualization software like Tableau.',
#  'The Data Management Analyst responsibilities include the collection and preparation of test data from test facilities for data analysis; provide technical…',
#  'Determines data needs, collects and validates data, selects from different analytical techniques to achieve desired data outcomes.',
#  'Prior Amplitude experience and at least 2–5 years experience working with product analytics data.\nBeing an excellent analyst: Uncover business questions.',
#  'Should have hands on experience in any ETL, data modelling concepts and implementation.\nFollow standard practices and procedures in analyzing situations or data…',
#  '5-7 years minimum work experience in master data in SAP.\nTroubleshoot issues related to master data and identify opportunities for improving data management…',
# ...
#  'Once the data is captured, building ETL tools to update data warehouse.\nDatabase design / data warehouse experience.\nData warehouse: 8 years (Required).',
#  'Support various projects through research, data analysis, data mining, identification, and potential implementation of tax credit programs.',
#  'Strong functional understanding of data and analytics architecture, platforms, and frameworks; including data modeling, data ingestion, data pipelines (ETL).',
#  '3-5 years of relevant experience - Will accept Master’s Degree in lieu of experience Preferred Experience.\nExercises timely and accurate data mining techniques…',
#  'Leads and performs Master data analysis, data cleansing through the review process.\nUnderstands Customer /Vendor/Material master data from the business and…',
#  'Experience working with healthcare data.\nWorking understanding of data warehousing concepts.\nDevelop complex SQL queries to manipulate data into required…',
#  'Bachelor’s Degree or equivalent experience solving analytical problems involving data, business process and/or data analysis with focus in a retail or wholesale…',
#  'Conducts data collection, data mining, analysis and reporting of data requests/reports.\nTrack and trends NCMRs and production data and follows escalation plan…',
#  'Thorough understanding of CPG value chain.\nAbility to work with business teams and understand their challenges and pain points.',
#  'Evaluate and analyze data, propose and facilitate solutions in order to satisfy project’s needs.\nHealth insurance after 3 months of employment.',
#  'Advanced Excel skills and experience working with large data sets.\nAsset Failure Data Manipulation– Investigate asset failure via field reports and collect…',
#  'Experience working with healthcare data.\nWorking understanding of data warehousing concepts.\nDevelop complex SQL queries to manipulate data into required…',
#  '5 - 10 years practical experience in implementing and providing support and maintenance for business/financial applications.\nSchedule: FT 7:30 AM - 4:30 PM.',
#  'Comfort working with data systems and learning new data systems.\nFrequently (2 - 5 hrs/day).\nA desire to learn and gain technical expertise in new systems and…',
#  'Coordinate data reporting from ARIES to support contractors, including data required to develop and submit monthly progress reports.',
#  'Strong functional understanding of data and analytics architecture, platforms, and frameworks; including data modeling, data ingestion, data pipelines (ETL).',
#  'To do well in this role, you need a very fine eye for detail, experience as a data analyst, and deep understanding of the popular data analysis tools and…',
#  'Experience including data management, data analytics, economics or statistical background preferred.\nExperience working with databases (SQL) and advanced data…',
#  'Experience processing and analyzing data sets.\n3+ years working in data and analytics.\nProject manage data and process improvements with third parties.',
#  'Experience with SQL and data warehouses (e.g. BigQuery, MySQL).\nA knack for identifying and investigating anomalies in data and operations.',
#  'You have the analytical firepower to take advantage of rich data and answer important questions.\nCreate output that tells the story behind the data to non…',
#  '3-5 years working with modern Search technology such as Coveo, Elasticsearch, Solr, etc.\n3-5 years demonstrated experience with KCS, or other Knowledge…',
#  'Perform ad hoc data analysis request and support the various Risk stakeholders.\nBecome the Subject Matter Expert (SME) for all data related to the Risk…',
#  '5+ years of experience in data and analytical problem solving.\nExperience with data visualization software (Tableau, etc.).',
#  "Drive the enhancement of data tools available to data analysts at Circle.\n3+ years' experience as Data Analyst in a data intensive environment, working with…",
#  '3-5 years’ experience in a hands-on analytical role with a focus on analyzing business problems.\nSupport the business with time-critical data analyses.',
#  'Review the provided data for load/formatting errors, utilize data loader, and collaborate with the Gifts and Records team to verify and test for data issues or…',
#  'Able to explain data and numbers in plain English.\nWell versed in the language of data and persuasive communications.\nProficient with SQL and Excel.',
#  'Advanced Excel skills and experience working with large data sets.\nAsset Failure Data Manipulation– Investigate asset failure via field reports and collect…',
#  'Experience working with healthcare data.\nWorking understanding of data warehousing concepts.\nDevelop complex SQL queries to manipulate data into required…',
#  'Excellent SQL and data warehouse skills.\nExperience writing complex queries on large data sets.\nPlan and optimize marketing channels & campaigns using…',
#  'To do well in this role, you need a very fine eye for detail, experience as a data analyst, and deep understanding of the popular data analysis tools and…',
#  'Experience manipulating large data sets in SQL or equivalent, and drawing actionable insights from data.\nOversee data and metric governance for fraud, system,…',
#  'Prepares data for analytic efforts by integrating and consolidating data; ensuring data quality and accuracy; profiling data inaccuracies and recommending…',
#  'Partner with data engineering partners to facilitate access to key data and ensure data quality.\nSQL and ad hoc data analysis experience.',
#  '3 +years experience with report/dashboard development, data/report automation, self-service capabilities, data design and integration, and data quality and…',
#  'Enable our operations team to make data-driven decisions based on timely, consistent, complete, and correct data, reports, and analytics.',
#  'The Analyst will collaborate with various departments to execute our data strategy by leading initiatives that ingest, harmonize, and expose data across…',
#  'Extreme attention to detail with focus on data quality, data consistency and criticality of compensation metrics.',
#  'Perform data validation to ensure accuracy and quality.\n1+ years of business or data analysis experience.\nResponsible for conducting and documenting moderate to…',
#  'Test data/report changes and approve prior to sending to users for approval.\nSubject matter expert with a focus on gathering and documenting data and report…',
#  'Advanced Excel skills and experience working with large data sets.\nAsset Failure Data Manipulation– Investigate asset failure via field reports and collect…',
#  'Finding answers to business questions via hands-on exploration of data sets using SQL, dashboards, statistical analysis, and data visualizations.',
#  'Acquire data from primary or secondary data sources and maintain databases/data systems.\nAdministrative Data analysts will develop analysis and reporting…',
#  'Creates and manages procedures regarding IP enforcement and litigation.\nManages and delivers IP support to customers.\nYes, 20% of the Time.',
#  'To do well in this role, you need a very fine eye for detail, experience as a data analyst, and deep understanding of the popular data analysis tools and…',
#  'At least five (5) years of experience designing, developing, debugging, and supporting complex data conversion processes using SQL Server.',
#  'Compiles and analyzes data to identify trends and recommends and implements improvements in the acquisition process; works with potential vendors to develop a…',
#  'Advocate for use of trusted data and sound data governance practices, contributing towards increasing data literacy across the organization.',
#  'BEREAVEMENT LEAVE - 3 days paid in California, 5 days paid out-of-state.\nThe candidate will be part of a BA team that includes developers and analysts who will…',
#  'Perform detailed data analysis (i.e. determine the structure, content, and quality of the data through examination of source systems and data samples).',
#  'Comfort working with data systems and learning new data systems.\nComfort working with data systems and learning new data systems.',
#  'Squash data silos by instrumenting (with engineering) data ingestion into our data lake.\nAnd you’ll be joining a group with diverse skills in data science,…',
#  'Analyzes quantitative and qualitative data as necessary throughout the course of the project, including the development of data collection strategies.',
#  'At least 5 years of experience in a highly-analytical role, where you help solve problems and improve business outcomes using data and analysis; experience in…',
#  'Advanced Excel skills and experience working with large data sets.\nAsset Failure Data Manipulation– Investigate asset failure via field reports and collect…',
#  'Demonstrated experience with some or all of the following: data modeling, statistics, experimental design, predictive modeling, data engineering, or workflow…',
#  "Option 3: 5 years' experience in data analysis, data science, statistics, or related field.\nEnsure accuracy of data capture strategy.",
#  '3 to 5 years of work experience in an analytical position.\n3 years experience leveraging ITSM tools to identify and document business needs and specifications…',
#  'Analyze data in support of proposed projects, business cases, and system requirements.\nCoordinate with customer to determine functional requirements and…',
#  'To do well in this role, you need a very fine eye for detail, experience as a data analyst, and deep understanding of the popular data analysis tools and…',
#  'Good Knowledge of: Statistics, data processing software; data collection instrument development; community college programs.',
#  '5+ years of experience in data analytics.\nConduct research, quantitative analysis, data modeling, data mining, and the presentation of data to see beyond the…',
#  'Collaborate with Tesla BI and data engineering teams to identify opportunities to improve and automate data collection processes and connect to data sources to…',
#  'Lead data migration activities of data into the primary data repository, includes performing ETL as applicable.\nFamiliarity with APEX coding language.',
#  '2+ years experience in investigative, data analysis, or technical systems work.\nUse data and internal tools to identify and investigate potential risk areas and…',
#  'Advanced skills for using Excel to analyze data and create financial and operational models plus PowerPoint to communicate analysis effectively.',
#  'Strong working knowledge of information systems, reporting software, and multiple complex database practices, including an understanding of system tables, data…',
#  'Our team endeavors to improve site performance with actionable data backed insights.\nManagement consulting background is a plus (with project work focused on…',
#  'Provide support for data extracts as required.\nCross-train other business analysts and project team members.\nAbility to retrieve and report data using BI tools…',
#  'This includes developing requirements and design documentation, use cases and test cases that define complex and advanced data projects supporting…',
#  "Proven analytical skills demonstrated by the ability to collect and analyze data, and make recommendations based on that analysis.\nThe skills you'll bring.",
#  'Analyze campus WSCH distributions to accurately reflect data from the previous fall semester and revise data if necessary.',
#  'Works independently to improve data quality, data collection and analysis processes; develops data modeling methodologies and report design to meet diverse and…',
#  'Build automated data quality check using combination of advanced SQL and Tableau, to ensure that data refreshes meet quality thresholds.',
#  'You will be responsible for building SQL Queries as well as synthesizing data and working collaboratively in a team environment!',
#  "The Data Analyst will combine clinical knowledge, data and information retrieval skills to actively address client's need for business and clinical insights…",
#  'Suggest scalable solutions by use of data.\nAnalytical and capable of telling stories using data.\n4+ years of professional experience in fraud investigation/data…',
#  "Analyze data and develop solutions.\nEnsure efficiency of reporting and data tools for supported business area use.\nBachelor's Degree in a related field.",
#  'Bachelors in Business/Economics/Information Technology (concentration in Business Analytics a plus) 3-5 years of experience in a similar business environment e…',
#  'Structure complex problems, develop hypotheses, conduct analyses and suggest recommendations through a data driven process.',
#  'Ability to analyze large sets of data with attention to detail.\nExperience with Tableau or any other data visualization tool.\nMust be a U.S. Citizen.',
#  'Ability to evaluate supplier proposals with large sets of supporting data.\nMaintains all records and supporting data used and provided in support of proposals.',
#  'Demonstrated strong analytical skills analyzing data fields up and down stream for implications; and data dictionaries.\nExperience leading Scrum stand-ups.',
#  'Support management decisions through data aggregation & analysis.\nPosition will start remote and may require hybrid (2-3 day a week) come September.',
#  'CA government/state project: 3 years (Required).\n4+ years experience as an Analyst (Business/Medicaid/Eligibility/Enrollment/Government/State).',
#  'Analyze data and develop effective data collection systems for clients.\nKeeps data up to date.\nEnsures data is up to date.\nLead team meetings and trainings.',
#  'Demonstrated experience in developing information solutions in a data warehouse environment.\nCollect, maintain, and analyze data for business, product and…',
#  'Experience working with data, querying, and analyzing data.\nProgramming skills and experience, especially for data exploration and presentation to management…',
#  '5+ years’ experience with advanced data and analytics.\nAdvanced Data Analytics: 5 years (Required).\nDemonstrated problem solving ability with experience…',
#  '7-10+ years’ experience in internet/ intranet-based business systems or e-business consulting.\nActs as liaison between client area, technical organization, and…',
#  '2-5 years business analyst experience with requirements gathering, requirements analysis, and documenting functional requirements.',
#  'This role will analyze data; conduct surveys, focus groups, and interviews; and help build a pipeline of new products while also recommending changes to…',
#  'Bachelor’s degree from an accredited school and 1-3 years’ work experience; Or a Master’s degree from an accredited school and 1+ year work experience.',
#  'Interest in data engineering, architecture and data ecosystem design as it relates to allowing data to flow between platforms via integrations and APIs.',
#  'Demonstrate critical thinking, discretion, and independent judgment in the context of risk analysis and problem solving.\nRisk Analyst Level I - Irvine, CA *.',
#  'Working with large sets of 1st-party, in-house data for Ad Monetization.\n6 Month Contract-to-Hire.\nExpertise in complex SQL querying in Snowflake and/or…',
#  'Develops and analyzes business performance reports (e.g. for claims data, provider data, utilization data) and provides notations of performance deviations and…',
#  '5-15 projects a month, they can be 2 weeks -8 weeks candidate will run with the project end to end from kickoff thru testing including developing specs,…',
#  'Ability to analyze data and interpret inconsistencies.\nRate and Contracting support for new and existing Customers.\nHigh School Diploma is Required*.',
#  '3-5 years of experience in finance, compliance or other related field.\nReconcile transactions by comparing and correcting data.',
#  'Analyze data and develop effective data collection systems for clients.\nKeeps data up to date.\nEnsures data is up to date.\nLead team meetings and trainings.']

# %%
summaries11_noreturn = [word.replace('\n',' ') for word in summaries11]

# %%
job_list_max_df = pd.DataFrame(list(zip(jobs11, companies11, locations11, summaries11_noreturn)),
               columns = ['job_title', 'company_name', 'location', 'summary'])
job_list_max_df
# Out:
#                                              job_title  \
# 0                               Data Analyst - YouTube
# 1                      Marketing Data Analyst (REMOTE)
# 2                             Entry Level Data Analyst
# 3    Entry Level - Data Engineer / Data Analyst (STEM)
# 4                           Data Analyst/Data Engineer
# ..                                                 ...
# 991             Performance Analyst - Value Based Care
# 992                                            JIRA BA
# 993    Financial Analyst Assistant - Logistics Company
# 994                                  Financial Analyst
# 995            Board Certified Behavior Analyst (BCBA)
#
#                       company_name  \
# 0                 Webhelp Americas
# 1                Molina Healthcare
# 2                   Insight Global
# 3                  PCS Global Tech
# 4                 MT Global US INC
# ..                             ...
# 991                     SCP Health
# 992               MATRIX Resources
# 993  Wollborg Michelson Recruiting
# 994                      Staffmark
# 995                   Victory care
#
#                                               location  \
# 0                     San Bruno, CA•Temporarily Remote
# 1                          Long Beach, CA 90802•Remote
# 2                                   Carlsbad, CA 92008
# 3                         Poway, CA•Temporarily Remote
# 4                                Foster City, CA 94404
# ..                                                 ...
# 991                                      United States
# 992  San Francisco, CA 94111 (Financial District area)
# 993                      Irvine, CA•Temporarily Remote
# 994                                   Carson, CA 90810
# 995                 Los Angeles, CA•Temporarily Remote
#
#                                                summary
# 0    Strong grasp on data structure and data integr...
# 1    Designs and implements processes and solutions...
# 2    They will be responsible for data administrati...
# 3    Provides plan with data, reporting, and analys...
# 4    \* Owner of the core company data pipeline, re...
# ..                                                 ...
# 991  Develops and analyzes business performance rep...
# 992  5-15 projects a month, they can be 2 weeks -8 ...
# 993  Ability to analyze data and interpret inconsis...
# 994  3-5 years of experience in finance, compliance...
# 995  Analyze data and develop effective data collec...
#
# [996 rows x 4 columns]

# %%
job_list_max_df.to_csv('job_list_analyst.csv', index=False)
