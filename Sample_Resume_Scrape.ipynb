# %%
import pandas as pd

import os

# %%
file = open('data_engineer_resume.txt', mode = 'r')
lines = file.readlines()
file.close()
my_dict = {}
my_list = []
words = []

# for line in lines:
#     line = line.split('\n')
#     line = [i.strip() for i in line]
#     words = line.split(" ") 
#     my_list.append(words)
for line in lines:
    words = line.split(' ')
    my_list.append(words)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-133-bcba3bc46d7d> in <module>
#       9     line = line.split('\n')
#      10     line = [i.strip() for i in line]
# ---> 11     words = line.split(" ")
#      12     my_list.append(words)
#      13 # for line in lines:
#
# AttributeError: 'list' object has no attribute 'split'

# %%
my_list[45]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-123-4b47918c2d41> in <module>
# ----> 1 my_list[45]
#
# IndexError: list index out of range

# %%
combined_list = []
combined_list.extend(my_list[2])
combined_list.extend(my_list[4])
combined_list.extend(my_list[5])
combined_list.extend(my_list[6])
combined_list.extend(my_list[7])
combined_list.extend(my_list[8])
combined_list.extend(my_list[9])
combined_list.extend(my_list[10])
combined_list.extend(my_list[12])
combined_list.extend(my_list[14])
combined_list.extend(my_list[15])
combined_list.extend(my_list[16])
combined_list.extend(my_list[17])
combined_list.extend(my_list[18])
combined_list.extend(my_list[19])
combined_list.extend(my_list[20])
combined_list.extend(my_list[22])
combined_list.extend(my_list[24])
combined_list.extend(my_list[25])
combined_list.extend(my_list[26])
combined_list.extend(my_list[27])
combined_list.extend(my_list[28])
combined_list.extend(my_list[29])
combined_list.extend(my_list[30])
combined_list.extend(my_list[32])
combined_list.extend(my_list[35])
combined_list.extend(my_list[36])
combined_list.extend(my_list[37])
combined_list.extend(my_list[38])
combined_list.extend(my_list[39])
combined_list.extend(my_list[40])
combined_list.extend(my_list[41])
combined_list.extend(my_list[42])
combined_list.extend(my_list[43])
combined_list.extend(my_list[44])
combined_list
# Out:
# ['SENIOR',
#  'MANAGER,',
#  'DATA',
#  'ENGINEERING\n',
#  'Provide',
#  'inputs',
#  'to',
#  'define',
#  'and',
#  'execute',
#  'strategic',
#  'roadmap',
#  'for',
#  'enterprise',
#  'data',
#  'architecture',
#  'by',
#  'identifying',
#  'the',
#  'current',
#  'landscape',
#  'and',
#  'future',
#  'business',
#  'goals\n',
#  'Help',
#  'establish',
#  'best',
#  'practice',
#  'like',
#  'standards',
#  'and',
#  'guidelines',
#  'for',
#  'design',
#  '&',
#  'development,',
#  'deployment,',
#  'support',
#  'and',
#  'analytics',
#  'and',
#  'mining\n',
#  'Data',
#  'Storage',
#  'and',
#  'Computation',
#  'Frameworks,',
#  'Performance',
#  'Optimizations\n',
#  'Help',
#  'establish',
#  'best',
#  'practice',
#  'in',
#  'acquiring,',
#  'storing',
#  'and',
#  'analyzing',
#  'structured,',
#  'semi-structured',
#  'and',
#  'un-structured',
#  'data',
#  'from',
#  'the',
#  'enterprise',
#  'and',
#  'outside',
#  'like',
#  'social\n',
#  'Provide',
# ...

# %%
list=pd.DataFrame(combined_list)
list
# Out:
#                  0
# 0           SENIOR
# 1         MANAGER,
# 2             DATA
# 3    ENGINEERING\n
# 4          Provide
# ..             ...
# 504             to
# 505           work
# 506             in
# 507              a
# 508           team
#
# [509 rows x 1 columns]

# %%
list.to_csv('Resume_Words')
