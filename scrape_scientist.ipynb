# %%
import requests
import bs4
from bs4 import BeautifulSoup as bs
import pandas as pd
from splinter import Browser
import os
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

max_page = 710

jobs12 = []
companies12 = []
locations12 = []
summaries12 = []

for start in range(0, max_page, 10):
    indeed_url = 'http://www.indeed.com/jobs?q=data%20scientist&l=California&start=' + str(start)
    browser.visit(indeed_url)
    time.sleep(5)  
    html = browser.html
    soup = bs(html, "html.parser")
    print(indeed_url)  
    
    #grabbing job title
    #for div in soup.find_all(name='div', attrs={'class':'job_seen_beacon'}):
    for td in soup.find_all(name='td', attrs={'class':'resultContent'}):
        for div in td.find_all(name='div', attrs={'class':'heading4 color-text-primary singleLineTitle tapItem-gutter'}):
            for span in div.find_all(name='span'):
                if span.text.strip() != 'new':
                    jobs12.append(span.text.strip())  

    #grabbing company name
    for td2 in soup.find_all(name='td', attrs={'class':'resultContent'}):
        for div2 in td2.find_all(name='div', attrs={'class':'heading6 company_location tapItem-gutter'}):
            for span2 in div2.find_all(name='span', attrs={'class':'companyName'}):
                companies12.append(span2.text.strip())      

    #grabbing location
    for td3 in soup.find_all(name='td', attrs={'class':'resultContent'}):
        for div3 in td3.find_all(name='div', attrs={'class':'heading6 company_location tapItem-gutter'}):
            for div4 in div3.find_all(name='div'):
                locations12.append(div4.text.strip())   

    #grabbing summary text
    divs = soup.findAll('div', attrs={'class': 'job-snippet'})
    for div5 in divs:
        summaries12.append(div5.text.strip())

browser.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST driver version for 92.0.4515
# Driver [C:\Users\SC\.wdm\drivers\chromedriver\win32\92.0.4515.107\chromedriver.exe] found in cache
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=0
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=10
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=20
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=30
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=40
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=50
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=60
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=70
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=80
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=90
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=100
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=110
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=120
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=130
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=140
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=150
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=160
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=170
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=180
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=190
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=200
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=210
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=220
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=230
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=240
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=250
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=260
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=270
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=280
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=290
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=300
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=310
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=320
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=330
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=340
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=350
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=360
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=370
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=380
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=390
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=400
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=410
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=420
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=430
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=440
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=450
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=460
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=470
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=480
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=490
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=500
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=510
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=520
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=530
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=540
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=550
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=560
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=570
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=580
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=590
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=600
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=610
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=620
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=630
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=640
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=650
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=660
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=670
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=680
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=690
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=700

# %%
jobs12
# Out:
# ['Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Annotation Specialist (part-time)',
#  'Data Scientist, Machine Learning',
#  'Data Scientist, Networking',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist (Recent M.S./Ph.D. Graduates)',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Associate Data Scientist',
#  'Data Scientist',
#  'People Analytics - (Senior Data Analyst)',
#  'Data Scientist',
#  '119: Sr Growth Data Scientist',
#  'Data Scientist, Analytics',
#  'Data Scientist / Software Engineer (Prognostics)',
#  'Senior Data Scientist',
#  'Machine Learning Infra Engineer, Tiktok Creator Marketplace',
#  'Senior Data Analyst',
#  'Associate/Intermediate Data Scientist',
#  'Data Scientist',
#  '120: Sr Marketing Analyst / Data Scientist',
#  'Data Scientist (Full Time) United States',
#  'Data scientist',
#  'Data Scientist, Machine Learning',
#  'Machine Learning Engineer, Autopilot Simulation',
#  'Product Data Scientist, Spotlight',
#  'Data Scientist',
#  'Data Scientist- Tiktok Ads',
#  'Sr. Data Scientist - ZWS',
#  'Data Scientist - Econ',
#  'Senior Data Analyst',
#  'Data Scientist - Strategy & Analytics',
#  'Machine Learning Engineer',
#  'Data Scientist',
#  'Data Scientist - Avatar',
#  'Data Scientist, Podcasts (The Ringer)',
#  'Data Scientist',
#  'Senior Data Analyst',
#  'Data Scientist',
#  'Data Scientist',
#  'Machine Learning Engineer',
#  'Data Scientist',
#  'Data Scientist, Experimentation-Data Platform',
#  'Staff Data Scientist, Machine Learning',
#  'Data Science Associate',
#  'Machine Learning Engineer (Recommendation) - 2021 Start',
#  'Data Scientist',
#  'Administrative Assistant, Data Science & Engineering',
#  'Data Scientist-Cognitive Analytics',
#  'Data Scientist',
#  'Machine Learning Engineer, TikTok Creator Marketplace',
#  'Data Scientist',
#  'Data Scientist - ML Ops',
#  'Sr. Data Scientist - Homebase',
#  'Data Scientist',
#  'Analyst, Data Science and Analytics',
#  'Data Scientist',
#  'Data Scientist',
#  'Sr. Data Scientist',
#  'Data Scientist, In-Market',
#  'Data Scientist',
#  'Data Scientist, International Payments',
#  'Sr. Staff Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Analyst / Data Scientist - Alteryx',
#  'Data Scientist - Sensing & Shaping',
#  'Data Scientist, Dolby.io',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Machine Learning Engineer',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist - Analytics, TikTok Ecosystem',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Sr. Staff Data Scientist',
#  'Data Scientist',
#  'Data Scientist - International Safety (Product Analytics)',
#  'Decision Scientist',
#  'Sr. Data Scientist',
#  'Senior Data Scientist',
#  'Data Analyst',
#  'Head of Analytics and Data Science, Monetization',
#  'Sr. Data Analyst',
#  'Data Scientist, Analytics',
#  'Data Scientist',
#  'Data Scientist - Entry Level',
#  'Data Scientist',
#  'Data Science Analyst',
#  'Sr. Data Science',
#  'Associate Data Scientist',
#  'Senior Data Scientist',
#  'Head of Data Science',
#  'Data Scientist',
#  'Data Scientist - Alogrithms',
#  'Data Scientist',
#  'Data Scientist (remote available)- Search & Analytics',
#  'Senior Data Scientist',
#  'Data Scientist - Product Analytics',
#  'Executive Assistant, Research & Data Science',
#  'Lead Data Scientist',
#  'Data Scientist 1',
#  'Data Scientist/ Engineer - R Expertise',
#  'Data Scientist - Instagram Shopping',
#  'Sr. Data Analyst',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist - Tiktok Ads Growth',
#  'Data Scientist - System',
#  'Product Data Scientist, Growth',
#  'Data Scientist',
#  'Data Scientist, Reliability Engineering',
#  'Data Scientist, Operations Analytics',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist for GRMDS.org',
#  'Data Scientist, Risk Data Mining',
#  'Staff Data Scientist - Ads Measurement',
#  'Data Scientist, Monetization Strategy & Analytics',
#  'Data Scientist',
#  'Machine Learning Engineer',
#  'Data Scientist',
#  'Sr. Data Scientist',
#  'Data Scientist',
#  'Data & Applied Scientist 2',
#  'Data Scientist, Networking',
#  'Data Scientist',
#  'DATA SCIENTIST',
#  'Data Scientist',
#  'Data Scientist, Mid',
#  'Software Engineer, Risk Data Mining',
#  'Lead Data Scientist',
#  'Data Scientist',
#  'Product Data Scientist, Core',
#  'Return to Work - Data Scientist, Product',
#  'Data Scientist',
#  'Data Science & Analytics Specialist',
#  'Data Scientist',
#  'Data Scientist',
#  'Decision Scientist',
#  'Sr. Statistical Programmer, Early Oncology',
#  'Data Scientist',
#  'Data Scientist',
#  'Administrative Assistant, Data Science & Engineering',
#  'Sr. Data Scientist (SP-Q3-08)',
#  'Machine Learning Scientist',
#  'Sr. Data Scientist',
#  'Data Scientist for GRMDS.org',
#  'Data Scientist - Research and Economics, Policy Economics',
#  'Data Scientist',
#  'AI Engineer II',
#  'Data Scientist',
#  'Data Scientist - Instagram Shopping',
#  'Data Scientist',
#  'Data Scientist - Instagram Shopping',
#  'Data Scientist - International Safety (Product Analytics)',
#  'Data Science Associate',
#  'Executive Assistant, Research & Data Science',
#  'Applied Data Scientist - Monetization',
#  'Data Scientist - ML Ops',
#  'Data Scientist',
#  'Machine Learning Engineer - TnS, TikTok-US-Tech Services',
#  'Principal Data Scientist',
#  'Machine Learning Engineer',
#  'Applied Data Scientist',
#  'Data Scientist — Apple Cloud Services (R & Shiny)',
#  'Data Scientist',
#  'Staff Machine Learning Engineer',
#  'Decision Scientist',
#  'Data Scientist, Triage - McD Tech Labs',
#  'Data Scientist, Analytics (University Grad)',
#  'SQL Data Analyst',
#  'Staff Engineer - Machine Learning',
#  'Data Scientist',
#  'Executive Assistant, Research & Data Science',
#  'Data Scientist',
#  'Data Scientist, Operations Data Science',
#  'Research Scientist in NLP',
#  'Analyst, Data Science and Analytics',
#  'Forensic Data Scientist',
#  'Data Scientist, Monetization Strategy & Analytics',
#  'Senior Data Scientist',
#  'Machine Learning DevOps Engineer',
#  'Administrative Assistant, Data Science & Engineering',
#  'Data Scientist 3/Adaptive Intelligence',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'SQL Data Analyst',
#  'Jr. Data Analysis Scientist',
#  'Entry Level Data Scientist',
#  'Lead Data Scientist, Risk Data Mining',
#  'Data Scientist - ML Ops',
#  'Data Scientist',
#  'Data Scientist II (Remote)',
#  'Product Data Scientist, Core',
#  'Data Scientist: Real-time Credit & Insights',
#  'Data Scientist - Risk Data Mining',
#  'Data Scientist (Recent M.S./Ph.D. Graduates)',
#  'Staff Machine Learning Engineer',
#  'Data Scientist, Product Analytics',
#  'Manager, Marketing Analytics & Data Science',
#  'Data Scientist',
#  'Sr. Data Scientist',
#  'Research Scientist in NLP',
#  'Senior Data Scientist, Individualized Therapies',
#  'Research Data Analyst',
#  'Real Estate Data Scientist - Remote',
#  'Data Scientist (Associate, Academic, and Institutional Studi...',
#  'Data Scientist, Machine Learning',
#  'Data Scientist',
#  'Sr. Staff Data Scientist',
#  'Data Scientist',
#  'Forensic Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Product Data Scientist, Core',
#  'Machine Learning Engineer',
#  'Forensic Data Scientist',
#  'Data Scientist - CSG Analytics [Remote - US]',
#  'Sr. Data Scientist - Deep Learning',
#  'Data Scientist (Advisor)',
#  'Data Scientist',
#  'Data Scientist - Tiktok Ads/Onsite Commerce',
#  'R50006 Bioinformatics Data Scientist',
#  'Data Scientist',
#  'Machine Learning Engineer - TnS, TikTok-US-Tech Services',
#  'Data Scientist',
#  'Data Analyst',
#  'Return to Work - Data Scientist, Product Analytics',
#  'Statistical Analyst',
#  'Machine Learning Engineer',
#  'Senior Applied Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist, Ads Machine Learning',
#  'Machine Learning Engineer',
#  'Data Analyst',
#  'Data Scientist',
#  'Data Scientist, Operations Data Science',
#  'Data Scientist, Monetization Strategy & Analytics',
#  'Data Scientist',
#  'Data Science Manager - Notifications & Friending',
#  'Forensic Data Scientist',
#  'Data Scientist - Lumedic',
#  'Machine Learning Engineer - TnS, TikTok-US-Tech Services',
#  'Data Science Manager - Core Product',
#  'Research Data Analyst',
#  'Machine Learning Engineer',
#  'Applied Data Scientist',
#  'Staff Data Scientist - Deep Learning',
#  'Statistical Research Programmer, Entry Level',
#  'Data & Applied Scientist 2',
#  'Machine Learning Scientist',
#  'Manager, Marketing Analytics & Data Science',
#  'Data Scientist',
#  'Data Scientist',
#  'Staff Data Scientist',
#  'Product Analytics Data Scientist, Matcha',
#  'Data Science Manager - Core Product',
#  'Staff Software Engineer, Machine Learning',
#  'Machine Learning Engineer',
#  'AI/ML Scientist, Integrative Biology',
#  'Data Scientist, Machine Learning Evaluation',
#  'Data Scientist',
#  'Sr. Staff Data Scientist',
#  'Manager, Marketing Analytics & Data Science',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Return to Work - Research Data Scientist, Infrastructure',
#  'Data Scientist (Remote)',
#  'Data Scientist / Data Engineer',
#  'Staff Data Scientist - Deep Learning',
#  'Data Scientist : 21-04959',
#  'Machine Learning Engineer',
#  'Data Scientist',
#  'Staff Data Scientist',
#  'Machine Learning Data Engineer',
#  'Product Data Scientist, New Products (Banking)',
#  'Machine Learning Scientist',
#  'Professional, Data Scientist',
#  'Data Science - Analytics Engineer',
#  'Data Scientist - Stylist & CX Algorithms',
#  'Statistician I',
#  'Sr. Data Scientist (SP-Q3-08)',
#  'Data Scientist',
#  'Data Scientist',
#  'MRM Data Science & Reporting Analyst',
#  'Sr. Data Scientist - Deep Learning',
#  'Data Scientist 2',
#  'Customer Data Analyst, Senior',
#  'Data Scientist',
#  'AI/ML Scientist, Integrative Biology',
#  'Product, Markets, & User Data Scientist',
#  'Data Scientist',
#  'Data Scientist - System',
#  'Sr. Statistical Programmer, Early Oncology',
#  'Developer Technology Engineer, Data Analytics - New College...',
#  'Product Data Scientist, New Products (Banking)',
#  'Data Scientist',
#  'Data Scientist, Global Supply Chain Management',
#  'Software Engineer (Machine Learning)',
#  'Return to Work - Research Data Scientist, Infrastructure',
#  'Data Scientist - Lumedic',
#  'Data Scientist',
#  'Data Scientist - Universal Content',
#  'Data Scientist, Game Analytics',
#  'Staff Data Scientist',
#  'Machine Learning DevOps Engineer',
#  'Data Scientist, Machine Learning Evaluation',
#  'Data Scientist, System Analytics',
#  'Data Scientist',
#  'Product Analytics Data Scientist, Matcha',
#  'Senior Data Analyst',
#  'Machine Learning Platform Engineer',
#  'Data Scientist',
#  'QCT Applications Engineer - Machine Learning SW',
#  'AI/ML Scientist, Integrative Biology',
#  'Sr. Statistical Programmer, Early Oncology',
#  'Data Scientist - International Safety (Product Analytics)',
#  'Data Scientist, Game Analytics',
#  'Data Scientist',
#  'Data Scientist',
#  'Staff, Data Scientist',
#  'Machine Learning Modeler, Payment Platform',
#  'Data Scientist',
#  'Data Scientist - #1342 (Remote)',
#  'Data Scientist, Machine Learning Evaluation',
#  'Machine Learning Modeler, Growth',
#  'Data Scientist, System Analytics',
#  'Senior Data Scientist',
#  'Statistical Research Programmer, Entry Level',
#  'QCT Applications Engineer - Machine Learning SW',
#  'Senior Data Analyst',
#  'Data Scientist',
#  'Data Scientist',
#  'Principal Data Analyst - Telecommute',
#  'Associate, Data Scientist, Simulation & Optimization',
#  'Data Scientist',
#  'Data Scientist, Honey Product Analytics',
#  'Data Scientist',
#  'Data Science Manager - TikTok Ads',
#  'Data Scientist',
#  'Product, Markets, & User Data Scientist',
#  'Machine Learning DevOps Engineer',
#  'Data Scientist/Machine Learning Engineer',
#  'Research Data Scientist',
#  'Staff Data Scientist, Ads Marketplace Analytics',
#  'Associate Data Science Analyst',
#  'GCP Cloud Consultant - Analytics & Cognitive',
#  'Data Scientist',
#  'Data Strategy Data Scientist',
#  'Statistical Data Scientist',
#  'Data Science Engineer',
#  'Data Scientist, Capacity Engineering - Location Flexible',
#  'Data Scientist/Machine Learning Engineer',
#  'Data Scientist',
#  'SQL Data Analyst',
#  'Data Scientist',
#  'Data Scientist - Marketplace Product',
#  'Staff, Data Scientist',
#  'Principal Data Analyst - Telecommute',
#  'Data Scientist - Developer Services',
#  'Lead (Health) Data Scientist',
#  'Senior Data Scientist, Machine Learning',
#  'Product, Markets, & User Data Scientist',
#  'Machine Learning Software Engineer',
#  'Machine Learning Engineer - Consultant',
#  'Data Scientist',
#  'Machine Learning Software Engineer – Compilers',
#  'Forensics, Data Scientist',
#  'Machine Learning Engineer, 21-04725',
#  'Staff Data Scientist, Ads Marketplace Analytics',
#  'Research Data Scientist',
#  'Data Scientist',
#  'Artificial Intelligence, Consultant - Applied Artificial Int...',
#  'Data Scientist',
#  'AI/ML Scientist, Integrative Biology',
#  'Data Analyst',
#  'Machine Learning Engineer, Data',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'Machine Learning Engineer - Consultant',
#  'Data Engineer, Machine Learning',
#  'Ad Relevance and Ranking, Machine Learning Engineer (Staff/S...',
#  'Research Data Scientist',
#  'Data Analyst',
#  'Lead (Health) Data Scientist',
#  'Backend Engineer, Machine Learning',
#  'Data Science Manager - TikTok Ads',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist - #1342 (Remote)',
#  'Senior Statistician I',
#  'Analytics Strategy Consultant',
#  'Lead (Health) Data Scientist',
#  'Machine Learning Engineer, 21-04725',
#  'Machine Learning Operations Engineer (Remote)',
#  'Senior Data Scientist - ZDX',
#  'Data Scientist',
#  'Layout Hardware Engineer, Quantum AI',
#  'Machine Learning Engineer',
#  'Machine Learning Engineer',
#  'Data Strategy Data Scientist',
#  'Web Security Engineer - Risk Data Mining',
#  'Senior Machine Learning Engineer',
#  'Machine Learning Engineer',
#  'Machine Learning Operations Engineer',
#  'Forensics, Data Scientist',
#  'Machine Learning Engineer',
#  'Data Scientist - Manager',
#  'Data Analyst',
#  'Staff Software Engineer, Machine Learning',
#  'Data Science Engineer',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Machine Learning Engineer',
#  'Sr. Data Scientist, Reliability & Test',
#  'Associate Data Science Analyst',
#  'Data Scientist (Advisor)',
#  'Data Science Manager - Notifications & Friending',
#  'Data Scientist - AdTech',
#  'Data Scientist',
#  'Sr. Data Scientist, Performance - Data Science',
#  'Machine Learning Engineer',
#  'AVP, Data Science - Reinforcement Learning Expert',
#  'Data Scientist',
#  'Associate Data Science Analyst',
#  'Senior Data Scientist',
#  'Entry Level Data Scientist',
#  'Associate Legal Counsel - Data/Design',
#  'Machine Learning Engineer',
#  'Product, Markets, & User Data Scientist',
#  'Senior Data Science',
#  'Data Scientist',
#  'Sr. Data Scientist',
#  'Machine Learning Research Engineer',
#  'AI/ML Scientist, Integrative Biology',
#  'Stat Programmer II ( Data visualization)',
#  'Software Engineer (Machine Learning)',
#  'Staff/Sr. Data Scientist',
#  'Software Engineer, Machine Learning',
#  'Machine Learning Data Analysis/Scientist',
#  'Senior Data Scientist',
#  'AVP, Data Science - Reinforcement Learning Expert',
#  'Machine Learning Software Platform Architect',
#  'Senior Data Engineer, Machine Learning',
#  'Senior Data Scientist',
#  'Distinguished Data Scientist',
#  'Machine Learning Engineer',
#  'Data Scientist, Machine Learning',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist - Developer Services',
#  'Statistical Programmer II',
#  'Research Scientist, Optimization Research (Core Data Science...',
#  'Marketing Analytics Data Scientist',
#  'Research Statistician I or II - Cottage Health Research Inst...',
#  'Genomics Data Scientist',
#  'Senior Data Scientist',
#  'Deep Learning Software Engineer',
#  'Machine Learning Scientist',
#  'Deep Learning Engineer/Scientist, Autopilot',
#  'Staff Data Scientist, Media Mix Modeling',
#  'Machine Learning Data Scientist - Personalization',
#  'Machine Learning Engineer',
#  'Machine Learning Data Scientist - Personalization',
#  'Machine Learning Engineer',
#  'Sr. Data Scientist, Reliability & Test',
#  'SQL Data Analyst',
#  'Machine Learning Engineer, 21-04725',
#  'Machine Learning Engineer',
#  'Data Scientist, Product Analytics (Remote)',
#  'Sr. Data Scientist - Deep Learning',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Senior Data Scientist - ZDX',
#  'Senior Data Science',
#  'Data Scientist',
#  'Research Statistician - Research Administration',
#  'Research Statistician - Research Administration',
#  'Entry Level Data Scientist',
#  'Data Scientist - ML Ops',
#  'AI Engineer - Hux',
#  'Sales Engineer, Machine Learning, Google Cloud',
#  'Web Security Engineer - Risk Data Mining',
#  'Senior Associate Data Sciences',
#  'Staff Data Scientist, Core',
#  'Machine Learning Manager, Viewership',
#  'Senior Machine Learning Scientist',
#  'Staff Data Scientist',
#  'Data Scientist',
#  'Machine Learning Engineer',
#  'Sr. Data Scientist',
#  'Data Analyst',
#  'Senior Data Scientist I',
#  'Data Scientist, Honey Product Analytics',
#  'Machine Learning Engineer',
#  'Engineering: Machine Learning Engineer',
#  'Lead Machine Learning Engineer - Opportunity for Working Rem...',
#  'Data Analyst',
#  'Data Scientist III - Digital Commerce',
#  'Machine Learning Engineer - Trust & Safety',
#  'Game Mathematician Consultant',
#  'Statistical Analyst',
#  'Machine Learning Engineer, Cash App',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Real Estate Data Scientist - Remote',
#  'Senior Data Scientist',
#  'Real Estate Data Scientist - Remote',
#  'Senior Data Scientist',
#  'Principal Data Analyst - Telecommute',
#  'Software Engineer II - Data & AI',
#  'SQL Data Analyst',
#  'Data Scientist',
#  'Software Engineer, Machine Learning',
#  'Data Scientist - Marketing',
#  'Data Assimilation Scientist',
#  'Data Scientist (Remote)',
#  'Senior Machine Learning Engineer',
#  'Data Scientist - Intermediate',
#  'Data Scientist (Marketing)',
#  'Data Scientist',
#  'Machine Learning Engineer',
#  'Distinguished Data Scientist',
#  'SQL Data Analyst',
#  'Machine Learning Research Engineer',
#  'Sr. Data Engineer / Data Analyst, Tesla Product Engineering',
#  'Staff Machine Learning Engineer',
#  'Sr. Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'Senior Data Scientist (Remote)',
#  'Software Engineer (Machine Learning)',
#  'Data Scientist (Demand Conversion)',
#  'Product Manager - Data & Visualization',
#  'Senior Data Scientist',
#  'Data Scientist - Manager',
#  'Staff Data Scientist',
#  'Staff Data Scientist',
#  'Data Scientist III - Central Player Dynamics',
#  'Software Engineer, PyTorch - Deep Learning',
#  'AVP, Data Science - Reinforcement Learning Expert',
#  'Sr. Data Scientist',
#  'Senior Machine Learning Engineer',
#  'Staff Data Scientist, R&D',
#  'Machine Learning Engineer',
#  'Assistant Regional Planner - Data Science',
#  'Senior Data Analyst',
#  'Multivariate Analysis - Data Scientist - Project Delivery Sp...',
#  'Staff Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'Software Engineer in Machine Learning Systems',
#  'Data Scientist / Senior Data Scientist',
#  'Economist - Machine Learning Engineer, Senior',
#  'Sr. Data Scientist, Expansion - Data Science',
#  'HR Data Scientist',
#  'SQL Data Analyst',
#  'Data Scientist',
#  'Data Engineer',
#  'Sr. Data Scientist',
#  'Research Professional _ Machine Learning [Fixed Term]',
#  'Senior Data Scientist',
#  'Technical Product Manager, Data Science & Analytics, Apple M...',
#  'Mathematical Scientist',
#  'Statistical Analyst',
#  'Head of Data Science (Remote)',
#  'Sr. Data Scientist',
#  'Senior Data Scientist',
#  'Lead Data Scientist, Tableau',
#  'Sr. Data Analyst',
#  'Expert Data Scientist - Life Science Analytics (Remote)',
#  'RTL Engineer - Autopilot AI',
#  'Senior Data Scientist',
#  'Machine Learning Performance Software Engineer, Autopilot AI...',
#  'Data Scientist, Triage - McD Tech Labs',
#  'Online Data Science Analyst - Apple Retail Online',
#  'Mobile Security Engineer, Risk Data Mining',
#  'Senior Data Scientist',
#  'Backend Engineer, Machine Learning',
#  'Data Scientist',
#  'Data Scientist - Analytics',
#  'Senior Data Scientist-Analytics',
#  'Data Scientist, Networking',
#  'Ad Relevance and Ranking, Machine Learning Engineer (Staff/S...',
#  'Senior Data Analyst_Marketing',
#  'Deep Learning Software Engineer - NCG 2021',
#  'Software Engineer - Risk Data Mining',
#  'Machine Learning Engineer',
#  'Machine Learning Software Engineer (Causality Researcher), E...',
#  'Machine Learning Software Engineer – Compilers',
#  'Product Manager-Machine Learning',
#  'Senior Machine Learning Engineer',
#  'Staff Machine Learning Engineer, Perception',
#  'Data Scientist',
#  'Data Scientist (Commercial)',
#  'Associate Data Scientist',
#  'Machine learning engineer',
#  'Associate Data Scientist',
#  'Machine learning engineer',
#  'Data Scientist (A/B Test)',
#  'Data Science and Engineering Manager, Studio Production',
#  'Senior Deep Learning Engineer/Scientist, Autopilot',
#  'Data Scientist - Analytics, Trust & Safety',
#  'Decision Scientist, Facebook Reality Labs',
#  'Associate Scientist - Machine Learning',
#  'Data Engineer',
#  'Applied Scientist',
#  'Layout Hardware Engineer, Quantum AI',
#  'Senior Data Scientist',
#  'Associate Data Scientist',
#  'Research Scientist, Machine Learning',
#  'Staff Data Scientist, CGM Analytics',
#  'Data Scientist, Data & Visualization (Contract)',
#  'Staff Statistician',
#  'Staff Imaging and Data Scientist',
#  'Applied Scientist II',
#  'Sr. Data Scientist',
#  'Technical Program Manager, Data Analytics, Google Research',
#  'Senior Machine Learning Engineer, TikTok Business Integrity',
#  'Data Scientist',
#  'Business Analyst/Data Scientist',
#  'Data Scientist',
#  'Machine Learning Researcher',
#  'Machine Learning Software Engineer - RFR 68499',
#  'Internal Audit Data Scientist',
#  'Sr Data Science Engineer',
#  'Data Science Manager',
#  'Computational Biologist / Data Scientist Research Associate',
#  'Principal Data Scientist',
#  'Manager, Data Science',
#  'Data Analyst',
#  'Machine Learning Engineer',
#  'Staff Machine Learning Engineer',
#  'Machine Learning Engineer',
#  'Machine Learning Scientist, Cell Imaging',
#  'Senior SDET - Data Science',
#  'Sr. Data Scientist - Wearables',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'Staff Data Scientist & TLM - Search & Recommendation, Machin...',
#  'Sr Machine Learning Engineer II - Help Intelligence',
#  'Data Analyst - Data Science & Analytics (AX)',
#  'Sr Machine Learning Engineer II - Help Intelligence',
#  'Data Analyst - Data Science & Analytics (AX)',
#  'Data Science Manager',
#  'Data Scientist, Machine Learning',
#  'SQL Data Analyst',
#  'Data Engineer - Machine Learning and Tracking',
#  'Senior Data Scientist',
#  'Machine Learning Fellow',
#  'Machine Learning Engineer / Software Engineer',
#  'Data Scientist',
#  'Data Scientist - Analytics',
#  'Machine Learning Software Engineer',
#  'Product Manager, Machine Learning Platform',
#  'AI/ML Engineer - Cell Imaging (Computer Vision)',
#  'Senior Data Scientist',
#  'Applied Machine Learning Engineer',
#  'Product Data Scientist',
#  'Medicare Business Analytics Data Scientist Consultant',
#  'Mass Spectrometry and Data Analysis Scientist',
#  'Machine Learning Engineer',
#  'Machine Learning Engineer',
#  'SQL Data Analyst',
#  'Quantitative Researcher',
#  'Data Scientist, Clinical & Genomics',
#  'Senior Data Scientist',
#  'Staff Data Scientist',
#  'Manager, Pricing and Decision Science',
#  'Product Data Scientist, New Products (Banking)',
#  'Data Scientist, Marketing',
#  'Machine Learning Software Engineer',
#  'Data Engineer',
#  'Sr. Data Scientist - Homebase',
#  'Staff Data Scientist',
#  'VP of Content Data Science & Engineering',
#  'Data Scientist',
#  'Artificial Intelligence (AI) Trainer',
#  'Machine Learning Engineer',
#  'Data Science Manager (100% Remote)',
#  'Principal Data Scientist',
#  'Senior Solutions Engineer, Data Science',
#  'Statistical Analyst',
#  'Sr. Data Analyst, Marketing',
#  'Head of Data Science',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Data Science Manager (100% Remote)',
#  'Senior Machine Learning Engineer',
#  'Senior Machine Learning Engineer',
#  'Data Scientist- LGC',
#  'Senior Data Scientist, Intelligent Services',
#  'Business Analyst - Part Time',
#  'Statistician',
#  'Data Scientist',
#  'Senior Product Data Scientist',
#  'Data Scientist (Mid-Level/Senior)',
#  'Manager, Machine Learning Engineer',
#  'Software Engineer - Machine Learning, Metrics (Python)',
#  'Data Scientist',
#  'Senior Machine Learning Engineer',
#  'Machine Learning Engineer, JLL Technologies',
#  'Software Engineer - Machine Learning, Metrics (Python)',
#  'Data Scientist',
#  'Data Scientist',
#  'Associate Data Scientist',
#  'Machine Learning Software Engineer – Compilers',
#  'Data Scientist Consultant',
#  'Research Data Scientist',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Manager, Machine Learning Engineer',
#  'Senior Data Scientist',
#  'Sr Machine Learning Engineer II - Help Intelligence',
#  'Senior Scientist, Machine Learning',
#  'Staff Data Scientist (Remote)',
#  'Senior Machine Learning Engineer',
#  'Data Analyst',
#  'Principal Data Scientist',
#  'Business Analyst - Part Time',
#  'Principal Data Scientist - People Insights (Americas)',
#  'Chief Data Scientist',
#  'Data Scientist, Marketing',
#  'Sr. Machine Learning Engineer',
#  'Software Engineer (Machine Learning) - Freight',
#  'Statistical Programming Lead- Oncology',
#  'Data Scientist',
#  'Machine Learning Software Engineer',
#  'Senior Data Scientist',
#  'Deep Learning Manager, Self-Driving',
#  'Full Stack Data Scientist, WishX',
#  'Machine Learning Scientist',
#  'Senior Data Scientist, Membership Programs',
#  'Sr. Data Scientist',
#  'Data Scientist',
#  'Machine Learning Engineer',
#  'Machine Learning Engineer - Ads Signal, Identity, Measuremen...',
#  'Senior SDET - Data Science',
#  'Sr. Data Analyst, Marketing',
#  'Data Scientist',
#  'Data Scientist (Geo-spatial Data)',
#  'Data Scientist, Clinical & Genomics',
#  'Staff Machine Learning Engineer',
#  'Statistician Programmer (Modeling Team)',
#  'Senior Solutions Engineer, Data Science',
#  'Senior Machine Learning Modeler, Cash App',
#  'Head of Data Science',
#  'Head of Data Science',
#  'Principal Applied Scientist (Machine Learning) - US Remote -...',
#  'Machine Learning Software Engineer',
#  'Senior Machine Learning Engineer',
#  'Data Scientist-III (Senior)',
#  'Machine Learning Engineer- Applied ML',
#  'Sr. Data Scientist (Remote)',
#  'Data Scientist - Operations',
#  'Applied Scientist',
#  'Machine Learning Engineer, Applied ML',
#  'Statistician',
#  'Senior Data Scientist - Marketplace Optimization',
#  'Data Scientist, Machine Learning',
#  'Applied Scientist - Salesforce Research',
#  'Data Science Manager, Facebook Reality Labs - Growth',
#  'Programmer Writer - AI/ML, Quantum Computing',
#  'Senior Strategy Data Scientist - Analytics',
#  'Senior Machine Learning Engineer',
#  'Mathematical Scientist',
#  'Media Insights Analyst - Savage X Fenty',
#  'Staff Data Scientist (Remote)',
#  'Full Stack Deep Learning Infrastructure Engineer, Autopilot',
#  'Data Scientist - Operations',
#  'Staff Machine Learning Engineer',
#  'Machine Learning Scientist',
#  'Machine Learning Engineer - Ads Signal, Identity, Measuremen...',
#  'Staff Data Scientist',
#  'Data Scientist (Geo-spatial Data)',
#  'Lead Software Engineer, Risk Data Mining',
#  'Software Engineer - Machine Learning',
#  'Staff Data Scientist',
#  'Data Scientist (Geo-spatial Data)',
#  'Lead Software Engineer, Risk Data Mining',
#  'Software Engineer - Machine Learning',
#  'Principal Data Scientist, Real World Evidence',
#  'Sr. Data Scientist, Supply',
#  'Health Advocate E2H Data Scientist',
#  'Staff Machine Learning Engineer - ATG',
#  'Senior Data Scientist',
#  'Data Science Manager, Facebook Reality Labs - Growth',
#  'Data Scientist',
#  'Data Scientist',
#  'Senior Software Engineer - Machine Learning',
#  'Manager, Pricing and Decision Science',
#  'Senior SDET - Data Science',
#  'Senior Data Scientist (Remote U.S.)',
#  'Software Engineer, Machine Learning - Hardware',
#  'Sr. Data Scientist (Remote)',
#  'Data Scientist, Analytics - Facebook Reality Labs, XROS',
#  'Research Product Manager - Amazon AI Labs',
#  'Machine Learning Engineer - Quality Assurance',
#  'Staff Machine Learning Engineer',
#  'Senior Machine Learning Engineer',
#  'Computational Data Science Research Specialist',
#  'Data Scientist (Mid-Level/Senior)',
#  'Senior Data Scientist, Catalog, NLP',
#  'Data Engineer',
#  'Software Engineer, Machine Learning',
#  'Staff Data Scientist',
#  'Product Data Scientist, New Products (Banking)',
#  'Product Data Scientist, New Products (Banking)',
#  'Senior Machine Learning Scientist',
#  'Monetization Strategy & Analytics Associate',
#  'Manager, Decision Science Analytics',
#  'Data Scientist, Clinical & Genomics',
#  'Lead Data Scientist - Biology',
#  'Machine Learning Data Engineer',
#  'Machine Learning Engineer II',
#  'Senior Data Scientist (Remote Work / Work from home)',
#  'Product Analytics Lead, Data Science',
#  'Quantum Machine Learning Researcher, Research Scientist, Qua...',
#  'Machine Learning Engineer',
#  'Developer of Data Science Tools',
#  'Machine Learning Scientist, Cell Imaging',
#  'Lead Data Scientist',
#  'Lead Data Scientist',
#  'Data Scientist',
#  'Senior Data Analyst [Remote]',
#  'Data Scientist, Analytics - WhatsApp Monetization',
#  'Data Scientist, In-Market',
#  'Senior Data Scientist',
#  'Data Scientist - Utility Industry - Machine Learning, Consul...',
#  '[Machine Learning/AI] Learning and Control Research',
#  'Computational and Data Science Research Specialist',
#  'Head of AI, Machine Learning, Data Science projects delivery...',
#  'Statistician',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Scientist/Machine Learning Engineer',
#  'Data Scientist II - Feature Science and Engineering',
#  '[Machine Learning/AI] Machine Learning for Novel Gas Sensors',
#  'Frontend Engineer - Machine Learning Platform',
#  'Data Science Senior Consultant',
#  'Data Scientist (Remote)',
#  'Senior Data and Applied Scientist',
#  'Machine Learning Engineer, JLL Technologies',
#  'Data Scientist/Senior Data Scientist',
#  'Data Scientist',
#  'Business Data Scientist',
#  'Senior Data Scientist, Used Cars',
#  'Staff Data Scientist OR Senior Staff Data Scientist',
#  'Machine Learning Engineer - Search Ads',
#  'Sr. Associate Data Analyst',
#  'Machine Learning Engineer',
#  'Senior Data Scientist',
#  'Forward Deployed Senior Data Scientist',
#  'Senior Principal Machine Learning/Data Scientist',
#  'Machine Learning Engineer, Ads Targeting',
#  'Lead Data Scientist, Recommendations at Pandora',
#  'Machine Learning Data Engineer',
#  'Senior Data Scientist',
#  'Senior Data Analyst-Marketing',
#  'Senior Data Scientist',
#  'Statistician I',
#  'IC Packaging Engineer, Autopilot AI (Dojo)',
#  'Data Scientist',
#  'Senior Machine Learning Engineer, Recommendation',
#  'Director, Commercial Data Science & AI',
#  'Machine Learning Infrastructure Engineer',
#  'Machine Learning Infrastructure Engineer',
#  'Machine Learning Engineer',
#  'Senior Data Scientist',
#  'VP of Product Data Science & Engineering',
#  'Sr. Product Manager, Machine Learning',
#  'Back End Software Engineer for Machine Learning Team',
#  'Computational Biology Data Scientist',
#  'Deep Learning Data Scientist',
#  'Data Scientist – Search (Contract)',
#  'Staff Data Scientist',
#  'Data QA Specialist',
#  'Machine Learning Software Engineer (Predictive Modeling), Ea...',
#  'Senior Data Scientist- Analytics, Business Analytics',
#  'Senior Software Engineer, Machine Learning on Mobile',
#  'Senior Data Scientist',
#  'Lead Data Scientist - Analyst',
#  'Senior Software Engineer, Machine Learning on Mobile',
#  'Senior Data Scientist',
#  'Lead Data Scientist - Analyst',
#  'Product Data Scientist, Discover',
#  'Machine Learning Engineer',
#  'Machine Learning Researcher',
#  'Head of Data Science',
#  'Full Stack Data Scientist',
#  'Behavioral Data Science Manager',
#  'Machine Learning Data Engineer',
#  'Principal Data Science',
#  'Senior Data Scientist',
#  'Deep Learning Researcher',
#  'Senior Machine Learning Scientist, Recommendation',
#  'Data Scientist - Tiktok Ads Integrity',
#  'Staff ML Engineer- Rider Pricing & Incentives',
#  'Data Scientist, Finance Analytics',
#  'Senior Data Scientist, Applied Machine Learning- Risk & Frau...',
#  'Data Science Manager - Notifications & Friending',
#  'Machine Learning Engineer',
#  'Data Scientist - Instagram Stories',
#  'Senior Data Scientist',
#  'Lead Data Scientist, Privacy',
#  'Machine Learning Engineer',
#  'Machine Learning Engineer, Deep Learning & NLP',
#  'Sr. Data Scientist',
#  'Sr. Data Scientist - Marketing Analytics',
#  'Staff Deep Learning Compiler Engineer',
#  'Software Engineer III, Optics Data Pipeline and Analysis',
#  'Senior Data Scientist - Telematics',
#  'Sr. Data Scientist',
#  'Sr. Data Scientist - Marketing Analytics',
#  'Staff Deep Learning Compiler Engineer',
#  'Software Engineer III, Optics Data Pipeline and Analysis',
#  'Senior Data Scientist - Telematics',
#  'Data and Policy Analyst - Statistical Programmer',
#  'Software Engineer - Machine Learning',
#  'Advanced Algorithms / Machine Learning Engineer',
#  'Sr. Data Scientist, Battery Systems',
#  'Health Data Scientist (Multiple Locations)',
#  'Staff Machine Learning Engineer',
#  'Staff Data Scientist - Optimization',
#  'Machine Learning Scientist',
#  'Data Science Engineer, Crypto',
#  'Machine Learning Infrastructure Engineer, 3+ Years Experienc...',
#  'Senior Machine Learning Engineer',
#  'Data Science Consultant',
#  'Machine Learning Evaluation Engineer– Qualcomm Research',
#  'Communications Manager, Health Artificial Intelligence',
#  'Senior NLP Scientist (remote)',
#  'Data Science Specialist',
#  'Senior Data Scientist',
#  'Apple Music Content Data Scientist - Cupertino',
#  'Computer Vision and Machine Learning Engineer - Light Estima...',
#  'ISE, Input Experience - Senior Data Scientist',
#  'ISE, Special Projects - Sr. Machine Learning Engineer (CA or...',
#  'Technical Project Manager - Data & Analytics and Machine Lea...',
#  'E-Commerce Data Scientist',
#  'Perception Research Engineer/Research Scientist - Deep Learn...',
#  'Sr. Machine Learning Engineer, Advertiser Recommendations -...',
#  'Lead Software Engineer, AI/ML',
#  'AI/ML - Sr Software Engineer, Engineering Efficiency',
#  'Sr. Stat Programming Analyst (JO-2108-130260)',
#  'Data Science Specialist',
#  'Senior Data Scientist',
#  'Senior Data Analyst',
#  'Apple Music Content Data Scientist - Cupertino',
#  'Computer Vision and Machine Learning Engineer - Light Estima...',
#  'ISE, Input Experience - Senior Data Scientist',
#  'ISE, Special Projects - Sr. Machine Learning Engineer (CA or...',
#  'E-Commerce Data Scientist',
#  'Perception Research Engineer/Research Scientist - Deep Learn...',
#  'Sr. Machine Learning Engineer, Advertiser Recommendations -...',
#  'Lead Machine Learning Engineer',
#  'Technical Sr Data Analyst',
#  'Senior Software Engineer, Data Platform',
#  'AI/ML - Senior Software Engineer, Siri Experience',
#  'Sr. Data Analyst',
#  'Machine Learning Data Engineer',
#  'Senior Data Analyst',
#  'Manager, Statistician',
#  'Machine Learning Engineering Manager - Online Retail Analyti...',
#  'ISE, Input Experience - Senior Data Scientist',
#  'Data Support Technician-Research Assistant',
#  'SoC Physical Design Engineer, Methodology and Machine Learni...',
#  'AI/ML - Sr Data Engineer, Siri Data',
#  'AI/ML - Software Engineer, Siri Experience',
#  'AI/ML- Tools Engineer- Performance, Siri Search, Knowledge &...',
#  'Sr. Machine Learning Engineer, Apple Maps',
#  'Director Computational Biomarker Discovery CNS or Oncology 1...',
#  'Lead Software Engineer, AI/ML',
#  'AI/ML - Sr Software Engineer, Engineering Efficiency',
#  'Sr. Stat Programming Analyst (JO-2108-130260)',
#  'Senior NLP Scientist (remote)',
#  'Data Science Specialist',
#  'Senior Data Scientist',
#  'Senior Data Analyst',
#  'Apple Music Content Data Scientist - Cupertino',
#  'Computer Vision and Machine Learning Engineer - Light Estima...',
#  'ISE, Input Experience - Senior Data Scientist',
#  ...]

# %%
companies12
# Out:
# ['EOS',
#  'TikTok',
#  'Environmental Risk Management Inc',
#  'Steady Platform',
#  'Discord',
#  'TikTok',
#  'Zscaler',
#  'Intel',
#  'Pocket Gems',
#  'Tubular Labs',
#  'IBM',
#  'National Research Group',
#  'Pluto TV',
#  'Scripps Health',
#  'Doorstead',
#  'Gap Inc.',
#  'J.D. Power',
#  'Blue Shield of California',
#  'Micron Technology',
#  'Dataspace',
#  'Discord',
#  'Tesla',
#  'TikTok',
#  'TikTok',
#  'Hulu',
#  'Activision',
#  'Zipcar, Inc.',
#  'Dataspace',
#  'Cisco Systems',
#  'Avila Trading',
#  'Kaiser Permanente',
#  'Tesla',
#  'Snapchat',
#  'Wealthfront',
#  'TikTok',
#  'Zscaler',
#  'JD.com',
#  'FocusKPI Inc.',
#  'TikTok',
#  'Zest AI',
#  'HG Insights',
#  'Roblox',
#  'Spotify',
#  'WarnerMedia',
#  'Square',
#  'Tinder',
#  'project44',
#  'Experian',
#  'Hewlett Packard Enterprise',
#  'TikTok',
#  'Varo Money',
#  'Fisher Investments',
#  'TikTok',
#  'Snapchat',
#  'Netflix',
#  'Amgen',
#  'Bytedance',
#  'TikTok',
#  'Akili Interactive',
#  'KPI Partners',
#  'Opendoor',
#  'Snapdocs',
#  'Verkada',
#  'Blockchain.com',
#  'ITRenew',
#  'Experian',
#  'Skai',
#  'LendingHome',
#  'Square',
#  'Zscaler',
#  'California State University',
#  'Fast AF',
#  'Adept Consultants',
#  'Deloitte',
#  'Dolby',
#  'Engine No. 1',
#  'Allianz Global Investors',
#  '8k Miles',
#  'information technology sector',
#  'GXO Logistics',
#  'Second Genome',
#  'Exsilio',
#  'TikTok',
#  'GroupM Services',
#  '99',
#  'Upgrade',
#  'Arista Networks',
#  'TeamViewer GmbH',
#  'Experian',
#  '99',
#  'TeleSign',
#  'Snowflake',
#  'Red Bull',
#  'Luxoft',
#  'Pinterest',
#  'Boot Barn',
#  'TikTok',
#  'Prealize Health',
#  'Numerdox',
#  'NumberOne AI',
#  'REVOLVE',
#  'PennyMac',
#  'Blizzard Entertainment',
#  'Transcarent',
#  'Optimum Technologies',
#  'Grimmway Farms',
#  'Confluent',
#  'Joby Aviation',
#  'Clarivate Analytics',
#  'Cognoa',
#  'TikTok',
#  'Opendoor',
#  'Zest AI',
#  'PayPal',
#  'Cognizant Technology Solutions',
#  'Facebook',
#  'Yellow Jacket Inc',
#  'Zest AI',
#  'Faire',
#  'TikTok',
#  'TikTok',
#  'Snapchat',
#  'Ipsos North America',
#  'Tesla',
#  'Extend',
#  'ELT Solutions',
#  'Driveway Finance Corporation',
#  'RMDS Lab',
#  'TikTok',
#  'Instacart',
#  'TikTok',
#  'eBay Inc.',
#  'Dictionary.com',
#  'University of California San Francisco',
#  'Recruiter.com',
#  'Aeva',
#  'Microsoft',
#  'TikTok',
#  'AutoZone',
#  'Grimmway Enterprises',
#  'project44',
#  'Booz Allen Hamilton',
#  'TikTok',
#  'Amply Power',
#  'Xerox',
#  'Snapchat',
#  'Facebook',
#  'NumberOne AI',
#  'Cuker',
#  'Waymo',
#  'eBay Inc.',
#  'Facebook',
#  'AstraZeneca',
#  'Gap Inc.',
#  'AutoZone',
#  'Netflix',
#  'Cape Analytics',
#  'Blue River Technology',
#  'Visa',
#  'RMDS Lab',
#  'Uber',
#  'Driveway Finance Corporation',
#  'Sony AI America Inc.',
#  'Enquero Inc',
#  'Facebook',
#  'Enquero Inc',
#  'Facebook',
#  '99',
#  'Fisher Investments',
#  'Opendoor',
#  'Snapchat',
#  'KPI Partners',
#  'Upgrade',
#  'TikTok',
#  'Capital One - US',
#  '99',
#  'Snapchat',
#  'Apple',
#  'Doorstead',
#  'The RealReal',
#  'Facebook',
#  "McDonald's Corporate",
#  'Facebook',
#  'CyberCoders',
#  "McDonald's Corporate",
#  'California State University',
#  'Opendoor',
#  'Upgrade',
#  'Google',
#  'TikTok',
#  'Verkada',
#  'Snapchat',
#  'TikTok',
#  'Hulu',
#  'NVIDIA',
#  'Netflix',
#  'Oracle',
#  'Microsoft',
#  'LendingHome',
#  'CyberCoders',
#  'TAE Technologies, Inc.',
#  'CALSTART',
#  'TikTok',
#  'KPI Partners',
#  'project44',
#  'GoGuardian',
#  'Snapchat',
#  'Pngme',
#  'Bytedance',
#  'Tubular Labs',
#  'The RealReal',
#  'Airtable',
#  'Snapchat',
#  'eHealth',
#  'Visa',
#  'TikTok',
#  'Genentech',
#  'University of California San Francisco',
#  'Harbor Freight Tools USA, Inc.',
#  'San Diego State University',
#  'Next Insurance',
#  'Masimo',
#  'Zscaler',
#  'magnitude',
#  'Snapchat',
#  'ITRenew',
#  'Second Genome',
#  'Snapchat',
#  '99',
#  'Snapchat',
#  'Confluent',
#  'GE Healthcare',
#  'Southern California Edison',
#  'Grimmway Farms',
#  'TikTok',
#  'CODA Biotherapeutics',
#  'magnitude',
#  'TikTok',
#  'project44',
#  'Luxoft',
#  'Facebook',
#  'Insight Research & Trading',
#  'Mercedes-Benz Research & Development North...',
#  'dunnhumby',
#  'Fractal.ai',
#  'Driveway Finance Corporation',
#  'Snapchat',
#  'Snark AI',
#  'Luxoft',
#  'Surya Systems',
#  'Google',
#  'TikTok',
#  'Joby Aviation',
#  'Facebook',
#  'Snapchat',
#  'Providence',
#  'TikTok',
#  'Discord',
#  'University of California San Francisco',
#  'Mercedes-Benz Research & Development North...',
#  'Spring Discovery',
#  'GE Healthcare',
#  'RAND Corporation',
#  'Microsoft',
#  'Genentech',
#  'Snapchat',
#  'Driveway Finance Corporation',
#  'QuinStreet',
#  'Thermo Fisher Scientific',
#  '0x',
#  'Discord',
#  'Discord',
#  'CLARA analytics',
#  'Genentech',
#  'Adobe',
#  'Akili Interactive',
#  'TeamViewer GmbH',
#  'Snapchat',
#  'EasyPost',
#  'Joby Aviation',
#  'Facebook',
#  'Quora',
#  'DeepMap, Inc',
#  'GE Healthcare',
#  'Akraya Inc.',
#  'Tempus Ex',
#  'Second Genome',
#  'Thermo Fisher Scientific',
#  'Toyota Research Institute',
#  'Square',
#  'Blue River Technology',
#  'CoreLogic',
#  'Transform Data',
#  'Stitch Fix',
#  'USC',
#  'Cape Analytics',
#  'Modern Health',
#  'Allianz Global Investors',
#  'AIG',
#  'GE Healthcare',
#  'f5',
#  'PG&E Corporation',
#  'ITRenew',
#  'Genentech',
#  'Cavnue',
#  'Grimmway Farms',
#  'Bytedance',
#  'AstraZeneca',
#  'NVIDIA',
#  'Square',
#  'Infogen Labs',
#  'Cepheid',
#  'Cadence Design Systems',
#  'Facebook',
#  'Providence',
#  'Driveway Finance Corporation',
#  'Roblox',
#  'Niantic',
#  'Branch',
#  'NVIDIA',
#  'Adobe',
#  'Stealth Mode Startup',
#  'Fractal.ai',
#  '0x',
#  'Square',
#  'Standard Cognition',
#  'Engine No. 1',
#  'Qualcomm Technologies, Inc.',
#  'Genentech',
#  'AstraZeneca',
#  '99',
#  'Niantic',
#  'Engine No. 1',
#  'Modern Health',
#  'Rivian Automotive',
#  'Square',
#  'Bolt',
#  'Myriad Genetics Inc.',
#  'Adobe',
#  'Square',
#  'Stealth Mode Startup',
#  'Joby Aviation',
#  'RAND Corporation',
#  'Qualcomm Technologies, Inc.',
#  'Square',
#  'Colsh Consultants',
#  'ITRenew',
#  'UnitedHealth Group',
#  'KPMG',
#  'First Republic Bank',
#  'Honey',
#  'Arista Networks',
#  'TikTok',
#  'Modern Health',
#  'Cavnue',
#  'NVIDIA',
#  'Weee! Inc',
#  'Facebook',
#  'Reddit',
#  'LendingClub',
#  'Deloitte',
#  'Modern Health',
#  'Jefferies & Company, Inc.',
#  'Exponent',
#  'Medtronic',
#  'Dropbox',
#  'Weee! Inc',
#  'Bolt',
#  'CyberCoders',
#  'Ipsos North America',
#  'Houzz',
#  'Rivian Automotive',
#  'UnitedHealth Group',
#  'Roblox',
#  'Transcarent',
#  'Discord',
#  'Cavnue',
#  'SIS',
#  'Deloitte',
#  'Modern Health',
#  'Qualcomm Technologies, Inc.',
#  'Deloitte',
#  'Akraya Inc.',
#  'Reddit',
#  'Facebook',
#  'Aspiration Partners',
#  'Deloitte',
#  'Centerfield',
#  'Genentech',
#  'Luxoft',
#  'Toyota Research Institute',
#  'Masimo',
#  'Step',
#  'Fractal.ai',
#  'Deloitte',
#  'Motional',
#  'Instacart',
#  'Facebook',
#  'Stanford University',
#  'Transcarent',
#  'Bytedance',
#  'TikTok',
#  'Bolt',
#  'SymphonyAI',
#  'Myriad Genetics Inc.',
#  'Abbott Laboratories',
#  'Accenture',
#  'Transcarent',
#  'Akraya Inc.',
#  'Formation',
#  'Zscaler',
#  'Modern Health',
#  'Google',
#  'Cool Minds LLC',
#  'Slalom Consulting',
#  'Jefferies & Company, Inc.',
#  'Bytedance',
#  'Acubed',
#  'Enview',
#  'Ciitizen',
#  'Deloitte',
#  'Embark Trucks',
#  'Deloitte',
#  'Stanford University',
#  'Discord',
#  'Andreessen Horowitz',
#  'REDICA Systems',
#  'Blue River Technology',
#  'Aspiration Partners',
#  'SymphonyAI',
#  'Snark AI',
#  'Tesla',
#  'LendingClub',
#  'Southern California Edison',
#  'Facebook',
#  'Uber',
#  'FriendFinder Networks',
#  'Slack',
#  'Snark AI',
#  'Deloitte',
#  'CareDx',
#  'LendingClub',
#  'Step',
#  'Spectra Infosystems',
#  'Adobe',
#  'Cool Minds LLC',
#  'Cavnue',
#  'Metromile',
#  'Gap Inc.',
#  'Ericsson',
#  'Intel',
#  'Genentech',
#  'Gilead Sciences',
#  'Cadence Design Systems',
#  'ShareThis, Inc',
#  'Benchling',
#  'Automat Solutions, Inc.',
#  'SB Energy',
#  'Deloitte',
#  'NVIDIA',
#  'Flock Freight',
#  'Microsoft',
#  'Verizon',
#  'Slalom Consulting',
#  'Next Insurance',
#  'FriendFinder Networks',
#  'SB Energy',
#  'Roblox',
#  'Inari Medical',
#  'Facebook',
#  'Byte',
#  'Cottage Health',
#  'Lawrence Berkeley National Laboratory',
#  'Projas Technologies',
#  'Intel',
#  'Genentech',
#  'Tesla',
#  'WarnerMedia',
#  'Afterpay Touch',
#  'OnSpecta',
#  'Afterpay Touch',
#  'OnSpecta',
#  'Tesla',
#  'CyberCoders',
#  'Akraya Inc.',
#  'Sisu',
#  'BOLD',
#  'GE Healthcare',
#  'Carta',
#  'CarParts.com',
#  'Ritual',
#  'Zscaler',
#  'Metromile',
#  'Lawrence Livermore National Laboratory',
#  "Rady Children's Hospital-San Diego",
#  "Rady Children's Hospital-San Diego",
#  'Spectra Infosystems',
#  'KPI Partners',
#  'Deloitte',
#  'Google',
#  'Bytedance',
#  'Amgen',
#  'Cruise',
#  'SAMBA TV',
#  'iRhythm Technologies',
#  'Thumbtack',
#  'XIFIN',
#  'Cotocus',
#  'omega solutions inc',
#  'Stanford University',
#  'Kaiser Permanente',
#  'Honey',
#  'Slalom Consulting',
#  'SupportLogic',
#  'VMware',
#  'Luxoft',
#  'Thermo Fisher Scientific',
#  'TikTok',
#  'Powerhouse Gaming',
#  'Insight Research & Trading',
#  'Cash App',
#  'EasyPost',
#  'eHealth',
#  'Harbor Freight Tools USA, Inc.',
#  'Ezoic',
#  'Harbor Freight Tools USA, Inc.',
#  'Ezoic',
#  'UnitedHealth Group',
#  'Electronic Arts',
#  'CyberCoders',
#  'Teknatio',
#  'Benchling',
#  'Houzz',
#  'UC San Diego',
#  'Quora',
#  'Adobe',
#  'Bayer',
#  'Mattel',
#  'Quantifind',
#  'Enview',
#  'Verizon',
#  'CyberCoders',
#  'Video.io',
#  'Tesla',
#  'Affirm',
#  'Amazon.com Services LLC',
#  'Verdigris Technologies',
#  'Prealize Health',
#  'Levi Strauss & Co.',
#  'Cadence Design Systems',
#  'Adobe',
#  'Citrine Informatics',
#  'Instacart',
#  'Deloitte',
#  'SoFi',
#  'SoFi',
#  'Riot Games',
#  'NVIDIA',
#  'Deloitte',
#  'Apartment List',
#  'FieldLevel',
#  'Pendulum.co',
#  'Happy Elements',
#  'Southern California Association of Governments',
#  'Electronic Arts',
#  'Deloitte',
#  'Cowbell Cyber Inc.',
#  'REDICA Systems',
#  'ScaleMonk',
#  'Bytedance',
#  'C3 AI',
#  'Instacart',
#  'Slack',
#  'SK hynix',
#  'CyberCoders',
#  'TeleSign',
#  'Whiterabbit.ai',
#  'Lark Health',
#  'SLAC National Accelerator Laboratory',
#  'Yumi',
#  'Apple',
#  'Pit.AI Technologies Inc.',
#  'University of California San Francisco',
#  'Foundry',
#  'Disney Media & Entertainment Distribution',
#  'Varo Money',
#  'Salesforce',
#  'Keck Medical Center of USC',
#  'Allscripts',
#  'Tesla',
#  'NephroSant',
#  'Tesla',
#  'McD Tech Labs',
#  'Apple',
#  'TikTok',
#  'Amgen',
#  'Bytedance',
#  'Supplyframe',
#  'Plaid',
#  'Robinhood',
#  'Bytedance',
#  'Instacart',
#  'WarnerMedia',
#  'NVIDIA',
#  'Bytedance',
#  'Atlas Executive Consulting',
#  'Loon',
#  'Qualcomm Technologies, Inc.',
#  'Samsung Electronics',
#  'Acubed',
#  'Cruise',
#  'Niagara Bottling',
#  'Bio-Rad Laboratories, Inc.',
#  'Internet Brands',
#  'BusinesStaff',
#  'Internet Brands',
#  'BusinesStaff',
#  'Kuaishou Technology',
#  'Netflix',
#  'Tesla',
#  'Bytedance',
#  'Facebook',
#  'SLAC National Accelerator Laboratory',
#  'Atlassian',
#  'Amazon.com Services LLC',
#  'Google',
#  'Bolt',
#  'Gallagher',
#  'KLA-Tencor',
#  'Dexcom',
#  'STAR Labs',
#  'Abbott Laboratories',
#  'Alphatec Spine, Inc.',
#  'Amazon.com Services LLC',
#  'Ericsson',
#  'Google',
#  'TikTok',
#  'Advanced Nutrients',
#  'ACL Digital',
#  'First American',
#  'Obsidian Security',
#  'Pinnacle Group',
#  'Oracle',
#  'Amgen',
#  'Blizzard Entertainment',
#  'Willow Biosciences',
#  'Oracle',
#  'Agilent Technologies, Inc.',
#  'Beshton Software',
#  'Change Healthcare',
#  'Quantcast',
#  'Koreminds LLC',
#  'Tempus',
#  'Clari',
#  'Plume',
#  'Demandbase',
#  'AE Studio',
#  'Faire',
#  'Uber',
#  'Criteo',
#  'Uber',
#  'Criteo',
#  'thredUP Inc',
#  'Facebook',
#  'CyberCoders',
#  'Standard Cognition',
#  'Span.IO',
#  'Motional',
#  'Energy Solutions',
#  'Kharon',
#  'Commure',
#  'Intel',
#  'Snapchat',
#  'GSK',
#  'Chartboost',
#  'Cerebras Systems',
#  'Carta',
#  'Kaiser Permanente',
#  'Bristol Myers Squibb',
#  'Mythical Games',
#  'Zoom Video Communications, Inc.',
#  'CyberCoders',
#  'Mythical Games',
#  'Tempus',
#  'Clari',
#  'Freedom Financial Network',
#  'Western Union',
#  'Square',
#  'Airtable',
#  'Sigma Connectivity',
#  'LatentView Analytics',
#  'Opendoor',
#  'Fandom',
#  'Netflix',
#  'Cedars-Sinai',
#  'Juji',
#  'Synapse Financial Technologies Inc',
#  'National General Insurance',
#  'Johnson & Johnson Family of Companies',
#  'The Trade Desk',
#  'RAND Corporation',
#  'Good Eggs',
#  'Optimum Technologies',
#  'Providence',
#  'Walmart',
#  'National General Insurance',
#  'Uber',
#  'Upstart',
#  'The Topps Company',
#  'Adobe',
#  'Spartan Technologies',
#  'The Climate Corporation',
#  'Crossover Health',
#  'FieldLevel',
#  'Big Data Federation',
#  'Snapchat',
#  'Motional',
#  'ESRI, Inc.',
#  'Capital One - US',
#  'JLL',
#  'Motional',
#  'TWO NIL',
#  'BICP',
#  'Internet Brands',
#  'Qualcomm Technologies, Inc.',
#  'Accenture',
#  'Family Health Centers of San Diego',
#  'Advanced Nutrients',
#  'Chartboost',
#  'Snapchat',
#  'Span.IO',
#  'Uber',
#  'Niantic',
#  'Quora',
#  'Capital One - US',
#  'DocuSign',
#  'Oracle',
#  'Spartan Technologies',
#  'Genentech',
#  'Moonshot Brands',
#  'Airtable',
#  'Sony Interactive Entertainment PlayStation',
#  'Uber',
#  'Johnson & Johnson Family of Companies',
#  'Gurucul',
#  'Intel',
#  'Clari',
#  'Rivian Automotive',
#  'Wish',
#  'Plus',
#  'Petco',
#  'hims & hers',
#  'REVOLVE',
#  'Robby Technologies',
#  'TikTok',
#  'Clari',
#  'Good Eggs',
#  'Rhombus Power',
#  'Alldus',
#  'Tempus',
#  'Quantcast',
#  'Heluna Health',
#  'The Trade Desk',
#  'Cash App',
#  'Optimum Technologies',
#  'Optimum Technologies',
#  'Splunk',
#  'Sigma Connectivity',
#  'Upstart',
#  'VideoAmp Careers Website',
#  'Linqia',
#  'Tile',
#  'Stitch Fix',
#  'Adobe',
#  'Robinhood',
#  'NCIRE',
#  'Faire',
#  'Facebook',
#  'Salesforce',
#  'Facebook',
#  'Amazon Dev Center U.S., Inc.',
#  'Robinhood',
#  'StubHub',
#  'Pit.AI Technologies Inc.',
#  'TechStyle Fashion Group',
#  'Quora',
#  'Tesla',
#  'Stitch Fix',
#  'Samsung Semiconductor, Inc.',
#  'Plus',
#  'TikTok',
#  'Freedom Financial Network',
#  'Alldus',
#  'TikTok',
#  '99',
#  'Freedom Financial Network',
#  'Alldus',
#  'TikTok',
#  '99',
#  'Abbott Laboratories',
#  'Wish',
#  'Intrado',
#  'ServiceNow',
#  'Genentech',
#  'Facebook',
#  'Rhombus Power',
#  'Fiserv',
#  'Discord',
#  'Western Union',
#  'Clari',
#  'Thermo Fisher Scientific',
#  'NVIDIA',
#  'Tile',
#  'Facebook',
#  'Amazon.com Services LLC',
#  'Levi Strauss & Co.',
#  'Quantcast',
#  'Pearson',
#  'UC San Diego',
#  'Big Data Federation',
#  'Wayfair',
#  'Capgemini',
#  'Grammarly',
#  'Chegg',
#  'Square',
#  'Square',
#  'Experian',
#  'TikTok',
#  'LendingClub',
#  'Tempus',
#  'Octave Bioscience',
#  'Toyota Research Institute',
#  'Glidewell Dental',
#  'The/Studio',
#  'Google',
#  'Google',
#  'EPAM Systems',
#  'Stitch Fix',
#  'Tempus',
#  'Nielsen',
#  'Nielsen',
#  'The Climate Corporation',
#  'Blue Owl',
#  'Facebook',
#  'Skai',
#  'Providence',
#  'Accenture',
#  'Honda Research Institute USA',
#  'University of California San Francisco',
#  'Xen.ai',
#  'Epic Sciences',
#  'Chegg',
#  'GroundTruth',
#  'Amobee',
#  'Afterpay Touch',
#  'Honda Research Institute USA',
#  'TikTok',
#  'Deloitte',
#  'Wurl, Inc',
#  'Sojern',
#  'JLL',
#  'Exponent',
#  'Blackhawk Network',
#  'NextRoll',
#  'Tesla',
#  'Foursquare',
#  'Tiktok Pte. Ltd.',
#  'Amgen',
#  'SADA',
#  'Mercari',
#  'Noodle.ai',
#  'Mission Support and Test Services, LLC',
#  'Pinterest',
#  'SiriusXM',
#  'Toyota Research Institute',
#  'Abnormal Security',
#  'Kaiser Permanente',
#  'Embark Trucks',
#  'WuXi AppTec Inc',
#  'Tesla',
#  'SunPower',
#  'TikTok',
#  'AstraZeneca',
#  'XPeng Motors',
#  'Skydio',
#  'Metropolis',
#  'Shift',
#  'Netflix',
#  'Sony Interactive Entertainment PlayStation',
#  'Sony Interactive Entertainment PlayStation',
#  'Stanford University',
#  'Intel',
#  'Getty Images',
#  'Opendoor',
#  'Embark Trucks',
#  'Loon',
#  'Robinhood',
#  'TikTok',
#  'Tiktok Pte. Ltd.',
#  'Sony Corporation of America',
#  'TikTok',
#  'Tiktok Pte. Ltd.',
#  'Sony Corporation of America',
#  'Snapchat',
#  'Liftoff',
#  'Qualcomm Technologies, Inc.',
#  'Datatron Technologies',
#  'Sensor Tower',
#  'Accenture',
#  'Toyota Research Institute',
#  'Xerox',
#  'Bolt',
#  'Dolby',
#  'TikTok',
#  'TikTok',
#  'Uber',
#  'Extend',
#  'Robinhood',
#  'Facebook',
#  'CrowdAI',
#  'Facebook',
#  'Petco',
#  'TikTok',
#  'UnifyID',
#  'Forethought',
#  'Vectra',
#  'Plume',
#  'Cruise',
#  'Google',
#  'Blue Owl',
#  'Vectra',
#  'Plume',
#  'Cruise',
#  'Google',
#  'Blue Owl',
#  'Acumen LLC',
#  'Abacus.AI',
#  'Penumbra US',
#  'Lucid Motors',
#  'Evidation',
#  'Wish',
#  'Geli',
#  'Enevate Corporation',
#  'a16z',
#  'Snapchat',
#  'Komodo Health',
#  'ProCogia',
#  'Qualcomm Technologies, Inc.',
#  'Google',
#  'aiXplain',
#  'UC San Francisco Academic',
#  'Pollen',
#  'Apple',
#  'Apple',
#  'Apple',
#  'Apple',
#  'Clear Capital',
#  'Abbyson Living Corporate',
#  'TuSimple, Inc.',
#  'Apple',
#  'CyberCoders',
#  'Apple',
#  'Ultimate Staffing Services',
#  'UC San Francisco Academic',
#  'Pollen',
#  'Reliant Funding',
#  'Apple',
#  'Apple',
#  'Apple',
#  'Apple',
#  'Abbyson Living Corporate',
#  'TuSimple, Inc.',
#  'Apple',
#  'Harnham',
#  'Ursus',
#  'TuSimple, Inc.',
#  'Apple',
#  'MATRIX Resources',
#  'Toyota Research Institute',
#  'Reliant Funding',
#  'Hyundai Capital America',
#  'Apple',
#  'Apple',
#  'Opeeka, Inc.',
#  'Apple',
#  'Apple',
#  'Apple',
#  'Apple',
#  'Apple',
#  'JGB BioPharma Consulting Inc.',
#  'CyberCoders',
#  'Apple',
#  'Ultimate Staffing Services',
#  'aiXplain',
#  'UC San Francisco Academic',
#  'Pollen',
#  'Reliant Funding',
#  'Apple',
#  'Apple',
#  'Apple',
#  ...]

# %%
locations12
# Out:
# ['Fremont, CA',
#  'Mountain View, CA',
#  'Sunnyvale, CA+1 location•Temporarily Remote',
#  'Playa Vista, CA•Remote',
#  'San Francisco, CA',
#  'Mountain View, CA',
#  'San Jose, CA 95134 (North San Jose area)',
#  'Folsom, CA 95630',
#  'San Francisco, CA',
#  'Mountain View, CA 94041 (Old Mountain View area)',
#  'San Jose, CA 95101 (North Valley area)',
#  'Los Angeles, CA+1 location',
#  'Los Angeles, CA 90069',
#  'San Diego, CA 92121 (Sorrento Valley area)',
#  'San Francisco, CA•Remote',
#  'San Francisco, CA 94105 (Financial District area)',
#  'California•Remote',
#  'Oakland, CA',
#  'San Jose, CA 95131 (North San Jose area)+1 location',
#  'Santa Clara, CA•Temporarily Remote',
#  'San Francisco, CA',
#  'Palo Alto, CA',
#  'Los Angeles, CA',
#  'Mountain View, CA',
#  'Santa Monica, CA',
#  'Santa Monica, CA',
#  'South San Francisco, CA 94080',
#  'Santa Clara, CA•Temporarily Remote',
#  'San Jose, CA',
#  'San Francisco, CA',
#  'Oakland, CA',
#  'Palo Alto, CA',
#  'Los Angeles, CA 90291 (Venice area)',
#  'Palo Alto, CA 94301 (University South area)•Remote',
#  'Mountain View, CA',
#  'San Jose, CA 95134 (North San Jose area)',
#  'Mountain View, CA 94043',
#  'San Francisco Bay Area, CA',
#  'Los Angeles, CA',
#  'Burbank, CA',
#  'California•Remote',
#  'San Mateo, CA',
#  'Los Angeles, CA•Remote',
#  'Burbank, CA 91505',
#  'San Francisco, CA',
#  'Los Angeles, CA',
#  'San Francisco, CA',
#  'Costa Mesa, CA 92626',
#  'San Jose, CA 95002 (North San Jose area)',
#  'Mountain View, CA',
#  'San Francisco, CA',
#  'San Mateo, CA 94404 (Mariners Island area)',
#  'Mountain View, CA',
#  'Los Angeles, CA 90291 (Venice area)',
#  'Los Gatos, CA',
#  'Thousand Oaks, CA',
#  'Mountain View, CA',
#  'Mountain View, CA',
#  'Larkspur, CA',
#  'Newark, CA 94560•Temporarily Remote',
#  'San Francisco Bay Area, CA•Remote',
#  'San Francisco, CA 94102 (Downtown area)',
#  'San Mateo, CA',
#  'California•Remote',
#  'Newark, CA 94560•Temporarily Remote',
#  'Costa Mesa, CA 92626',
#  'San Francisco, CA 94103 (South Of Market area)',
#  'San Francisco, CA 94108 (Downtown area)•Remote',
#  'San Francisco, CA',
#  'San Jose, CA 95134 (North San Jose area)',
#  'San Diego, CA',
#  'San Francisco, CA•Remote',
#  'Irvine, CA 92602•Temporarily Remote',
#  'San Jose, CA 95113 (Downtown area)+1 location',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'San Diego, CA 92101 (Core-Columbia area)',
#  'Pleasanton, CA',
#  'San Francisco, CA',
#  'Bloomington, CA 92316',
#  'Brisbane, CA 94005',
#  'Irvine, CA 92614',
#  'Mountain View, CA',
#  'San Francisco, CA 94107 (South Of Market area)+1 location',
#  'Mountain View, CA',
#  'San Francisco, CA',
#  'Santa Clara, CA 95054',
#  'San Jose, CA',
#  'Costa Mesa, CA 92626',
#  'Mountain View, CA',
#  'California•Remote',
#  'San Mateo, CA 94401 (Central Business District area)',
#  'Santa Monica, CA',
#  'Los Angeles, CA',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Irvine, CA 92618 (Irvine Health and Science Complex area)',
#  'Los Angeles, CA',
#  'Palo Alto, CA 94301 (Professorville area)',
#  'Sacramento, CA•Remote',
#  'Tustin, CA 92780•Remote',
#  'Cerritos, CA 90703',
#  'Westlake Village, CA 91361',
#  'Irvine, CA 92618',
#  'California•Remote',
#  'Mountain View, CA 94043',
#  'Bakersfield, CA',
#  'Mountain View, CA',
#  'San Carlos, CA 94070',
#  'San Francisco, CA 94111 (Financial District area)•Remote',
#  'Palo Alto, CA 94306 (College Terrace area)•Remote',
#  'Mountain View, CA+1 location',
#  'San Francisco Bay Area, CA•Remote',
#  'Burbank, CA',
#  'San Jose, CA 95131 (North Valley area)',
#  'Campbell, CA',
#  'San Francisco, CA 94105 (South Beach area)+1 location',
#  'Menlo Park, CA•Temporarily Remote',
#  'Burbank, CA',
#  'California•Remote',
#  'Mountain View, CA',
#  'Mountain View, CA',
#  'San Francisco, CA',
#  'San Francisco, CA 94105 (South Beach area)',
#  'Palo Alto, CA',
#  'San Francisco, CA',
#  'San Jose, CA',
#  'California•Remote',
#  'Pasadena, CA 91101 (South area)•Remote',
#  'Mountain View, CA',
#  'California•Remote',
#  'San Francisco, CA',
#  'San Jose, CA',
#  'Oakland, CA 94607 (Acorn-Acorn Industrial area)',
#  'San Francisco, CA 94143 (Haight-Ashbury area)',
#  'Los Angeles, CA',
#  'Mountain View, CA',
#  'Sunnyvale, CA 94085 (West Murphy area)',
#  'Mountain View, CA',
#  'Elk Grove, CA 95757',
#  'Bakersfield, CA 93307',
#  'San Francisco, CA',
#  'El Segundo, CA',
#  'Mountain View, CA',
#  'San Jose, CA',
#  'Palo Alto, CA',
#  'Los Angeles, CA 90291 (Venice area)',
#  'Menlo Park, CA 94025',
#  'Tustin, CA 92780•Remote',
#  'Carlsbad, CA 92008',
#  'Mountain View, CA',
#  'San Jose, CA',
#  'Menlo Park, CA 94025',
#  'South San Francisco, CA 94080',
#  'San Francisco, CA 94105 (Financial District area)',
#  'Elk Grove, CA 95757',
#  'Los Gatos, CA',
#  'Mountain View, CA',
#  'Sunnyvale, CA',
#  'Foster City, CA',
#  'Pasadena, CA 91101 (South area)•Remote',
#  'San Francisco, CA 94103 (South of Market area)',
#  'California•Remote',
#  'California•Remote',
#  'Milpitas, CA 95035•Remote',
#  'San Francisco, CA 94105 (South Beach area)+1 location',
#  'Milpitas, CA 95035•Remote',
#  'San Francisco, CA 94105 (South Beach area)+1 location',
#  'Mountain View, CA',
#  'San Mateo, CA 94404 (Mariners Island area)',
#  'San Francisco Bay Area, CA•Remote',
#  'Los Angeles, CA 90291 (Venice area)',
#  'Newark, CA 94560•Temporarily Remote',
#  'San Francisco, CA',
#  'Mountain View, CA',
#  'San Francisco, CA 94108 (Downtown area)',
#  'Mountain View, CA',
#  'Los Angeles, CA 90291 (Venice area)',
#  'San Francisco, CA',
#  'San Francisco, CA•Remote',
#  'California•Remote',
#  'Menlo Park, CA 94025',
#  'Mountain View, CA',
#  'Menlo Park, CA 94025+5 locations',
#  'Inglewood, CA 90301',
#  'Mountain View, CA',
#  'San Diego, CA',
#  'San Francisco Bay Area, CA•Remote',
#  'San Francisco, CA',
#  'Mountain View, CA',
#  'Mountain View, CA',
#  'San Mateo, CA',
#  'Los Angeles, CA 90291 (Venice area)',
#  'San Francisco, CA',
#  'Santa Monica, CA 90404',
#  'Santa Clara, CA',
#  'Los Gatos, CA',
#  'Redwood City, CA 94065 (Marine area)',
#  'Sunnyvale, CA 94085 (West Murphy area)',
#  'San Francisco, CA 94108 (Downtown area)•Remote',
#  'Inglewood, CA 90301',
#  'Foothill Ranch, CA',
#  'Pasadena, CA 91106 (South area)•Remote',
#  'Mountain View, CA',
#  'Newark, CA 94560•Temporarily Remote',
#  'San Francisco, CA',
#  'El Segundo, CA•Remote',
#  'Los Angeles, CA 90291 (Venice area)',
#  'San Francisco, CA•Remote',
#  'Mountain View, CA',
#  'Mountain View, CA 94041 (Old Mountain View area)',
#  'California•Remote',
#  'San Francisco, CA',
#  'Los Angeles, CA 90291 (Venice area)',
#  'Santa Clara, CA',
#  'Foster City, CA',
#  'Mountain View, CA',
#  'South San Francisco, CA 94080',
#  'San Francisco, CA 94143 (Haight-Ashbury area)',
#  'Calabasas, CA 91302•Remote',
#  'San Diego, CA 92182 (College West area)',
#  'Palo Alto, CA 94306 (Evergreen Park area)',
#  'Irvine, CA',
#  'San Jose, CA 95134 (North San Jose area)',
#  'San Francisco, CA',
#  'Los Angeles, CA 90291 (Venice area)',
#  'Newark, CA 94560•Temporarily Remote',
#  'Brisbane, CA 94005',
#  'Los Angeles, CA 90291 (Venice area)',
#  'Mountain View, CA',
#  'Los Angeles, CA 90291 (Venice area)',
#  'Mountain View, CA•Remote',
#  'San Ramon, CA 94583',
#  'Irvine, CA 92603',
#  'Bakersfield, CA',
#  'Mountain View, CA',
#  'South San Francisco, CA 94080',
#  'San Francisco, CA',
#  'Mountain View, CA',
#  'San Francisco, CA',
#  'Los Angeles, CA',
#  'Menlo Park, CA 94025',
#  'Beverly Hills, CA',
#  'Sunnyvale, CA 94085 (West Murphy area)',
#  'West Sacramento, CA',
#  'California•Remote',
#  'California•Remote',
#  'Mountain View, CA 94041 (Old Mountain View area)',
#  'Menlo Park, CA 94025',
#  'Los Angeles, CA',
#  'San Francisco, CA•Temporarily Remote',
#  'Mountain View, CA',
#  'San Francisco, CA',
#  'San Carlos, CA 94070',
#  'Menlo Park, CA 94025',
#  'Los Angeles, CA 90291 (Venice area)',
#  'Torrance, CA 90509+1 location•Remote',
#  'Mountain View, CA',
#  'San Francisco, CA',
#  'San Francisco, CA 94143 (Haight-Ashbury area)',
#  'Sunnyvale, CA 94085 (West Murphy area)',
#  'San Carlos, CA 94070',
#  'San Ramon, CA 94583',
#  'Los Angeles, CA',
#  'Sunnyvale, CA 94085 (West Murphy area)',
#  'South San Francisco, CA 94080',
#  'Los Angeles, CA 90291 (Venice area)',
#  'California•Remote',
#  'Foster City, CA 94404•Temporarily Remote',
#  'South San Francisco, CA 94080',
#  'San Francisco, CA•Remote',
#  'San Francisco, CA',
#  'California+1 location•Remote',
#  'Santa Clara, CA•Remote',
#  'South San Francisco, CA 94080',
#  'San Francisco, CA',
#  'Larkspur, CA',
#  'San Jose, CA',
#  'Los Angeles, CA 90291 (Venice area)',
#  'California•Remote',
#  'Santa Cruz, CA 95060',
#  'Menlo Park, CA 94025',
#  'California•Remote',
#  'Palo Alto, CA 94303',
#  'San Ramon, CA 94583',
#  'San Bruno, CA 94066',
#  'California•Remote',
#  'Brisbane, CA 94005',
#  'South San Francisco, CA 94080',
#  'Los Altos, CA 94022•Remote',
#  'Oakland, CA 94612 (Downtown area)',
#  'Sunnyvale, CA',
#  'San Diego, CA 92131 (Scripps Ranch area)',
#  'San Francisco, CA•Remote',
#  'San Francisco, CA',
#  'Los Angeles, CA',
#  'Mountain View, CA',
#  'California+1 location•Remote',
#  'San Diego, CA 92101 (Core-Columbia area)',
#  'Woodland Hills, CA',
#  'San Ramon, CA 94583',
#  'San Jose, CA',
#  'San Francisco, CA 94105 (Financial District area)',
#  'Newark, CA 94560•Temporarily Remote',
#  'South San Francisco, CA 94080',
#  'Palo Alto, CA',
#  'Bakersfield, CA',
#  'Mountain View, CA',
#  'South San Francisco, CA 94080',
#  'Santa Clara, CA',
#  'Oakland, CA 94612 (Downtown area)',
#  'Valencia, CA 91355',
#  'Sunnyvale, CA 94089 (Lakewood area)',
#  'San Jose, CA 95134 (North San Jose area)',
#  'Menlo Park, CA 94025',
#  'Torrance, CA 90509+1 location•Remote',
#  'California•Remote',
#  'San Mateo, CA',
#  'San Francisco, CA+1 location',
#  'Redwood City, CA 94061 (Palm area)',
#  'Santa Clara, CA',
#  'San Francisco, CA',
#  'Newark, CA',
#  'California•Remote',
#  'San Francisco, CA•Remote',
#  'San Francisco, CA',
#  'San Francisco, CA•Remote',
#  'San Francisco, CA',
#  'San Diego, CA',
#  'South San Francisco, CA 94080',
#  'South San Francisco, CA 94080',
#  'Mountain View, CA',
#  'San Francisco, CA+1 location',
#  'San Francisco, CA',
#  'California+1 location•Remote',
#  'Palo Alto, CA+2 locations',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'South San Francisco, CA 94080•Remote',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'Newark, CA',
#  'Santa Cruz, CA 95060',
#  'Los Angeles, CA',
#  'San Diego, CA',
#  'San Francisco, CA',
#  'Santa Clara, CA',
#  'Newark, CA 94560•Temporarily Remote',
#  'Santa Ana, CA 92702•Remote',
#  'San Francisco, CA 94105 (South Beach area)+2 locations',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Los Angeles, CA 90064 (Sawtelle area)',
#  'Santa Clara, CA 95054',
#  'Mountain View, CA',
#  'California+1 location•Remote',
#  'Palo Alto, CA',
#  'Santa Clara, CA',
#  'Fremont, CA',
#  'Menlo Park, CA 94025',
#  'California•Remote',
#  'San Francisco, CA',
#  'Sacramento, CA 95814 (Downtown area)+4 locations',
#  'California+1 location•Remote',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Menlo Park, CA 94025',
#  'Northridge, CA 91325',
#  'California•Remote',
#  'Fremont, CA',
#  'San Francisco, CA',
#  'Inglewood, CA 90301',
#  'San Francisco, CA 94105 (South Beach area)',
#  'Santa Monica, CA+1 location',
#  'Palo Alto, CA+2 locations',
#  'Santa Ana, CA 92702•Remote',
#  'San Mateo, CA',
#  'California•Remote',
#  'San Francisco, CA+1 location',
#  'Palo Alto, CA',
#  'Sunnyvale, CA',
#  'San Jose, CA 95113 (Downtown area)+1 location',
#  'California+1 location•Remote',
#  'Santa Clara, CA 95051',
#  'Costa Mesa, CA 92626',
#  'Costa Mesa, CA 92626',
#  'California•Remote',
#  'Menlo Park, CA 94025',
#  'Los Angeles, CA•Remote',
#  'Costa Mesa, CA 92626+3 locations',
#  'Los Angeles, CA',
#  'South San Francisco, CA 94080',
#  'Los Angeles, CA',
#  'Los Altos, CA 94022',
#  'Irvine, CA',
#  'Palo Alto, CA',
#  'California•Remote',
#  'San Jose, CA 95113 (Downtown area)+1 location',
#  'Santa Monica, CA',
#  'California•Remote',
#  'Menlo Park, CA 94025',
#  'Stanford, CA',
#  'California•Remote',
#  'Mountain View, CA',
#  'Mountain View, CA',
#  'San Francisco, CA',
#  'Palo Alto, CA',
#  'South San Francisco, CA 94080•Remote',
#  'Santa Clara, CA+1 location•Remote',
#  'San Diego, CA+1 location',
#  'California•Remote',
#  'Costa Mesa, CA 92626',
#  'San Francisco, CA•Remote',
#  'San Jose, CA 95134 (North San Jose area)',
#  'California+1 location•Remote',
#  'Goleta, CA',
#  'San Francisco, CA 94103 (South of Market area)•Temporarily Remote',
#  'San Francisco, CA 94105 (South Beach area)',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Mountain View, CA',
#  'Sunnyvale, CA',
#  'California•Remote',
#  'Palo Alto, CA 94301 (Professorville area)•Remote',
#  'Costa Mesa, CA 92626',
#  'San Francisco, CA',
#  'Sacramento, CA 95814 (Downtown area)+2 locations',
#  'Stanford, CA',
#  'California+1 location•Remote',
#  'Menlo Park, CA 94025',
#  'Pleasanton, CA 94566',
#  'Sunnyvale, CA',
#  'Los Angeles, CA•Remote',
#  'Palo Alto, CA',
#  'Menlo Park, CA 94025',
#  'Palo Alto, CA',
#  'San Francisco, CA',
#  'Irvine, CA 92603',
#  'Menlo Park, CA 94025',
#  'San Francisco, CA 94103 (South of Market area)',
#  'San Jose, CA 95128 (Willow Glen area)•Temporarily Remote',
#  'San Francisco, CA',
#  'Menlo Park, CA 94025',
#  'Costa Mesa, CA 92626+4 locations',
#  'South San Francisco, CA+1 location',
#  'San Francisco, CA',
#  'Palo Alto, CA',
#  'San Francisco, CA (Financial District area)',
#  'San Francisco, CA',
#  'San Francisco, CA 94103 (South of Market area)•Temporarily Remote',
#  'Palo Alto, CA',
#  'San Francisco, CA 94107 (Yerba Buena area)',
#  'San Francisco, CA 94105 (Financial District area)',
#  'Santa Clara, CA 95054',
#  'Santa Clara, CA 95052',
#  'South San Francisco, CA 94080',
#  'Temporarily Remote',
#  'San Jose, CA 95134 (North San Jose area)',
#  'Palo Alto, CA 94304',
#  'San Francisco, CA 94103 (South of Market area)•Temporarily Remote',
#  'Fremont, CA 94538 (Baylands area)',
#  'Redwood City, CA•Remote',
#  'Costa Mesa, CA 92626+4 locations',
#  'Santa Clara, CA',
#  'California•Remote',
#  'Sunnyvale, CA 94085 (West Murphy area)',
#  'Irvine, CA 92618+1 location',
#  'San Francisco, CA 94105 (South Beach area)',
#  'Palo Alto, CA 94306 (Evergreen Park area)',
#  'San Jose, CA 95128 (Willow Glen area)•Temporarily Remote',
#  'Redwood City, CA•Remote',
#  'San Mateo, CA',
#  'Irvine, CA 92618 (East Industrial Complex area)',
#  'Menlo Park, CA 94025',
#  'Santa Monica, CA 90404',
#  'Santa Barbara, CA 93105 (Oak Park area)',
#  'San Francisco Bay Area, CA•Remote',
#  'San Jose, CA 95126 (Downtown area)•Temporarily Remote',
#  'Santa Clara, CA 95052',
#  'South San Francisco, CA 94080',
#  'Palo Alto, CA',
#  'Culver City, CA',
#  'San Francisco, CA•Temporarily Remote',
#  'Redwood City, CA',
#  'San Francisco, CA•Temporarily Remote',
#  'Redwood City, CA',
#  'Palo Alto, CA',
#  'Inglewood, CA 90301',
#  'Costa Mesa, CA 92626',
#  'San Francisco, CA',
#  'California•Remote',
#  'San Ramon, CA 94583',
#  'San Francisco, CA',
#  'Torrance, CA 90504',
#  'Culver City, CA•Remote',
#  'San Jose, CA 95134 (North San Jose area)',
#  'San Francisco, CA 94107 (Yerba Buena area)',
#  'Livermore, CA 94550',
#  'San Diego, CA',
#  'San Diego, CA',
#  'San Francisco, CA (Financial District area)',
#  'Newark, CA 94560•Temporarily Remote',
#  'Pleasanton, CA 94588+4 locations',
#  'San Francisco, CA',
#  'Mountain View, CA',
#  'Thousand Oaks, CA',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'California•Remote',
#  'California•Remote',
#  'San Diego, CA 92130',
#  'Sacramento, CA 95822 (Airport area)',
#  'Santa Ana, CA',
#  'Stanford, CA',
#  'Burbank, CA 91504+1 location',
#  'Los Angeles, CA 90064 (Sawtelle area)',
#  'San Francisco, CA 94105 (South Beach area)',
#  'Santa Clara, CA',
#  'Palo Alto, CA+1 location•Remote',
#  'Los Angeles, CA',
#  'Carlsbad, CA 92008',
#  'Mountain View, CA',
#  'Loomis, CA•Remote',
#  'Beverly Hills, CA',
#  'San Francisco, CA 94103 (South of Market area)',
#  'California•Remote',
#  'Santa Clara, CA',
#  'Calabasas, CA 91302•Remote',
#  'Carlsbad, CA',
#  'Calabasas, CA 91302•Remote',
#  'Carlsbad, CA',
#  'Santa Ana, CA 92702•Remote',
#  'Redwood City, CA 94065 (Dolphin area)',
#  'Inglewood, CA 90301',
#  'Menlo Park, CA•Remote',
#  'San Francisco, CA 94103 (South of Market area)•Temporarily Remote',
#  'Santa Monica, CA',
#  'San Diego, CA',
#  'California•Remote',
#  'San Jose, CA',
#  'San Francisco, CA 94103 (South Of Market area)',
#  'El Segundo, CA 90245',
#  'Palo Alto, CA',
#  'California•Remote',
#  'Irvine, CA 92618+1 location',
#  'Inglewood, CA 90301',
#  'San Francisco, CA•Remote',
#  'Palo Alto, CA',
#  'California•Remote',
#  'Irvine, CA',
#  'Moffett Field, CA 94035',
#  'Palo Alto, CA 94301 (Professorville area)',
#  'San Francisco, CA (North Waterfront area)•Remote',
#  'San Jose, CA 95134 (North San Jose area)',
#  'San Jose, CA',
#  'Furnace Creek, CA+2 locations•Remote',
#  'California•Remote',
#  'Sacramento, CA 95814 (Downtown area)+2 locations',
#  'San Francisco, CA 94129 (Presidio area)',
#  'San Francisco, CA 94129 (Presidio area)',
#  'Los Angeles, CA 90064 (Sawtelle area)',
#  'Santa Clara, CA',
#  'Costa Mesa, CA 92626+4 locations',
#  'California•Remote',
#  'California•Remote',
#  'San Francisco, CA',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Los Angeles, CA 90017 (Downtown area)•Temporarily Remote',
#  'Sacramento, CA•Remote',
#  'San Jose, CA 95113 (Downtown area)',
#  'Pleasanton, CA 94566',
#  'Pleasanton, CA 94566',
#  'Palo Alto, CA',
#  'Mountain View, CA',
#  'Redwood City, CA',
#  'California•Remote',
#  'San Francisco, CA',
#  'Folsom, CA',
#  'Inglewood, CA 90301',
#  'Los Angeles, CA',
#  'Santa Clara, CA',
#  'California•Remote',
#  'Menlo Park, CA',
#  'Los Angeles, CA•Remote',
#  'Culver City, CA',
#  'San Jose, CA 95131 (North Valley area)',
#  'San Francisco, CA 94143 (Haight-Ashbury area)•Remote',
#  'California•Remote',
#  'Glendale, CA',
#  'San Francisco, CA',
#  'San Francisco, CA 94105 (South Beach area)',
#  'Los Angeles, CA 90015 (Downtown area)',
#  'San Francisco, CA+2 locations•Remote',
#  'Palo Alto, CA',
#  'South San Francisco, CA',
#  'Palo Alto, CA',
#  'Mountain View, CA 94040',
#  'Santa Clara Valley, CA 95014',
#  'Mountain View, CA',
#  'Thousand Oaks, CA+1 location',
#  'Mountain View, CA',
#  'Pasadena, CA',
#  'San Francisco, CA',
#  'Menlo Park, CA',
#  'Mountain View, CA',
#  'California•Remote',
#  'Burbank, CA 91505',
#  'Santa Clara, CA',
#  'Mountain View, CA',
#  'San Diego, CA 92108 (Mission Valley West area)',
#  'Mountain View, CA',
#  'Santa Clara, CA 95051',
#  'Mountain View, CA',
#  'Sunnyvale, CA',
#  'San Francisco, CA',
#  'Diamond Bar, CA 91765',
#  'Hercules, CA',
#  'Los Angeles, CA',
#  'Los Angeles, CA',
#  'Los Angeles, CA',
#  'Los Angeles, CA',
#  'Palo Alto, CA 94303',
#  'Los Angeles, CA',
#  'Palo Alto, CA',
#  'Mountain View, CA',
#  'Los Angeles, CA 90066 (Del Rey area)+1 location',
#  'Menlo Park, CA•Temporarily Remote',
#  'San Francisco, CA',
#  'Sunnyvale, CA',
#  'Goleta, CA',
#  'Los Angeles, CA',
#  'San Diego, CA',
#  'Milpitas, CA 95035',
#  'San Diego, CA',
#  'Los Gatos, CA',
#  'Alameda, CA',
#  'Carlsbad, CA',
#  'Irvine, CA',
#  'Santa Clara, CA 95054',
#  'San Francisco, CA',
#  'Mountain View, CA',
#  'West Hollywood, CA 90069',
#  'Menlo Park, CA',
#  'Santa Ana, CA 92707',
#  'Redwood City, CA 94063+1 location',
#  'Sunnyvale, CA',
#  'Redwood City, CA 94065 (Marine area)',
#  'Thousand Oaks, CA',
#  'Irvine, CA 92618',
#  'Mountain View, CA•Remote',
#  'Redwood City, CA 94065 (Marine area)',
#  'Santa Clara, CA 95051',
#  'San Francisco Bay Area, CA',
#  'California+1 location',
#  'San Francisco, CA 94103 (Yerba Buena area)',
#  'South San Francisco, CA•Temporarily Remote',
#  'Redwood City, CA',
#  'Sunnyvale, CA',
#  'California•Remote',
#  'California•Remote',
#  'Venice, CA',
#  'California•Remote',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Los Angeles, CA',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Los Angeles, CA',
#  'Oakland, CA',
#  'Fremont, CA 94555 (Northgate area)',
#  'Inglewood, CA 90301',
#  'San Francisco, CA•Remote',
#  'San Francisco, CA',
#  'Los Angeles, CA 90401',
#  'Oakley, CA 94561',
#  'Los Angeles, CA',
#  'San Francisco, CA',
#  'Santa Clara, CA 95052',
#  'Los Angeles, CA 90291 (Venice area)',
#  'San Francisco, CA',
#  'Oakland, CA',
#  'California•Remote',
#  'San Francisco, CA',
#  'Oakland, CA',
#  'Redwood City, CA',
#  'California•Remote',
#  'San Francisco Bay Area, CA•Remote',
#  'Inglewood, CA 90301',
#  'California•Remote',
#  'Redwood City, CA',
#  'San Francisco Bay Area, CA',
#  'San Mateo, CA 94402 (Beresford area)',
#  'San Francisco, CA',
#  'Oakland, CA 94612 (Downtown area)',
#  'San Francisco, CA',
#  'San Francisco Bay Area, CA+1 location',
#  'San Jose, CA•Temporarily Remote',
#  'San Francisco Bay Area, CA•Remote',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Los Angeles, CA',
#  'Los Angeles, CA',
#  'San Jose, CA 95117 (West San Jose area)',
#  'San Francisco, CA 94105 (Yerba Buena area)',
#  'Ontario, CA 91764•Remote',
#  'Vacaville, CA+7 locations',
#  'San Francisco, CA 94105 (South Beach area)',
#  'Los Angeles, CA',
#  'San Francisco Bay Area, CA•Remote',
#  'Mountain View, CA 94043',
#  'Irvine, CA 92604',
#  'Sunnyvale, CA 94087',
#  'Ontario, CA 91764•Remote',
#  'San Francisco, CA 94103 (South of Market area)',
#  'California•Remote',
#  'Encino, CA 91436',
#  'San Jose, CA',
#  'Palo Alto, CA',
#  'San Francisco, CA 94103 (Yerba Buena area)',
#  'San Clemente, CA',
#  'California•Remote',
#  'Silicon Valley, CA',
#  'Los Angeles, CA 90291 (Venice area)',
#  'Santa Monica, CA 90401 (Downtown/Third Street Promenade area)',
#  'Redlands, CA 92373',
#  'San Francisco, CA 94108 (Downtown area)',
#  'San Francisco, CA',
#  'Santa Monica, CA 90401 (Downtown/Third Street Promenade area)',
#  'California•Remote',
#  'San Francisco, CA',
#  'Los Angeles, CA',
#  'Santa Clara, CA 95051',
#  'San Francisco, CA+1 location',
#  'San Diego, CA 92102 (Mt. Hope area)',
#  'West Hollywood, CA 90069',
#  'Oakland, CA',
#  'Los Angeles, CA 90291 (Venice area)',
#  'San Francisco, CA',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Sunnyvale, CA+1 location',
#  'California•Remote',
#  'San Francisco, CA 94108 (Downtown area)',
#  'San Francisco, CA 94105 (South Beach area)',
#  'Redwood City, CA 94065 (Marine area)',
#  'Palo Alto, CA',
#  'California•Remote',
#  'San Francisco, CA•Remote',
#  'San Francisco, CA',
#  'San Diego, CA',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Los Angeles, CA+1 location',
#  'El Segundo, CA 90245',
#  'Santa Clara, CA 95052',
#  'San Francisco Bay Area, CA',
#  'Palo Alto, CA',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Cupertino, CA',
#  'San Diego, CA 92127 (Rancho Bernardo area)',
#  'California•Remote',
#  'Cerritos, CA 90703',
#  'Palo Alto, CA',
#  'Mountain View, CA',
#  'Sunnyvale, CA',
#  'San Francisco Bay Area, CA•Remote',
#  'Mountain View, CA',
#  'California',
#  'Redwood City, CA',
#  'San Francisco, CA 94103 (Yerba Buena area)',
#  'Richmond, CA',
#  'San Francisco, CA 94105 (South Beach area)',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Mountain View, CA 94043',
#  'Mountain View, CA 94043',
#  'San Jose, CA 95131 (North Valley area)+1 location•Remote',
#  'San Francisco Bay Area, CA+1 location',
#  'California•Remote',
#  'California•Remote',
#  'San Francisco, CA 94108 (Downtown area)',
#  'San Mateo, CA•Remote',
#  'San Francisco, CA',
#  'San Jose, CA',
#  'Menlo Park, CA',
#  'San Francisco, CA',
#  'San Francisco, CA+1 location',
#  'Fremont, CA 94555 (Northgate area)',
#  'Palo Alto, CA 94301 (Downtown North area)',
#  'Burlingame, CA 94010',
#  'East Palo Alto, CA',
#  'Menlo Park, CA',
#  'San Francisco, CA 94105 (South Beach area)',
#  'San Jose, CA 95131 (North Valley area)',
#  'El Segundo, CA',
#  'California•Remote',
#  'Palo Alto, CA',
#  'San Francisco, CA',
#  'San Jose, CA',
#  'Cupertino, CA',
#  'Mountain View, CA',
#  'San Mateo, CA 94402 (Beresford area)',
#  'California',
#  'Mountain View, CA',
#  'Mountain View, CA',
#  'San Mateo, CA 94402 (Beresford area)',
#  'California',
#  'Mountain View, CA',
#  'Mountain View, CA',
#  'Alameda, CA',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Westlake Village, CA',
#  'Santa Clara, CA 95054',
#  'South San Francisco, CA 94080',
#  'Burlingame, CA 94010',
#  'Mountain View, CA',
#  'Sunnyvale, CA 94087',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'Sunnyvale, CA',
#  'Carlsbad, CA 92008•Remote',
#  'Santa Clara, CA',
#  'San Mateo, CA•Remote',
#  'Burlingame, CA 94010',
#  'East Palo Alto, CA',
#  'San Francisco, CA (North Waterfront area)',
#  'San Francisco, CA 94103 (Yerba Buena area)',
#  'Sacramento, CA•Remote',
#  'San Diego, CA 92093 (Torrey Pines area)',
#  'Silicon Valley, CA',
#  'San Francisco, CA',
#  'Burbank, CA',
#  'California+1 location•Remote',
#  'Santa Clara, CA 95054',
#  'Oakland, CA 94612 (Downtown area)',
#  'Oakland, CA 94612 (Downtown area)',
#  'Costa Mesa, CA 92626',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'Redwood City, CA',
#  'Menlo Park, CA',
#  'Los Altos, CA 94022•Remote',
#  'Irvine, CA 92612',
#  'California•Remote',
#  'Mountain View, CA',
#  'Los Angeles, CA (Venice area)',
#  'San Diego, CA',
#  'San Francisco, CA',
#  'Redwood City, CA',
#  'San Francisco, CA•Remote',
#  'San Francisco, CA•Remote',
#  'San Francisco, CA 94103 (Yerba Buena area)',
#  'San Francisco, CA•Remote',
#  'Menlo Park, CA 94025+1 location',
#  'San Francisco, CA 94103 (South Of Market area)',
#  'Irvine, CA 92604',
#  'San Francisco, CA+2 locations',
#  'San Jose, CA',
#  'San Francisco, CA 94143 (Haight-Ashbury area)',
#  'San Diego, CA+3 locations•Remote',
#  'San Diego, CA 92121 (University City area)',
#  'Santa Clara, CA 95054',
#  'Mountain View, CA 94043',
#  'Redwood Shores, CA',
#  'San Francisco, CA•Temporarily Remote',
#  'San Jose, CA',
#  'Mountain View, CA',
#  'Los Angeles, CA 90013 (Downtown area)+1 location',
#  'California•Remote',
#  'San Francisco, CA 94111 (Financial District area)•Remote',
#  'San Francisco, CA',
#  'Menlo Park, CA 94025',
#  'Pleasanton, CA 94588',
#  'California•Remote',
#  'Fremont, CA',
#  'Los Angeles, CA',
#  'Mountain View, CA•Temporarily Remote',
#  'Thousand Oaks, CA',
#  'Los Angeles, CA•Temporarily Remote',
#  'Palo Alto, CA',
#  'San Francisco, CA',
#  'Santa Barbara, CA 93111',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Oakland, CA 94612',
#  'Los Altos, CA 94022•Remote',
#  'California•Remote',
#  'Oakland, CA•Remote',
#  'San Francisco, CA',
#  'San Diego, CA 92121',
#  'Palo Alto, CA',
#  'Richmond, CA 94804 (Marina Bay area)',
#  'Mountain View, CA',
#  'South San Francisco, CA 94080',
#  'Mountain View, CA',
#  'Redwood City, CA',
#  'Los Angeles, CA',
#  'California•Remote',
#  'Los Gatos, CA',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'Stanford, CA',
#  'Santa Clara, CA 95052',
#  'San Francisco, CA+1 location',
#  'San Francisco Bay Area, CA•Remote',
#  'San Francisco, CA',
#  'Mountain View, CA',
#  'Menlo Park, CA',
#  'Mountain View, CA',
#  'Los Angeles, CA•Temporarily Remote',
#  'San Jose, CA',
#  'Mountain View, CA',
#  'Los Angeles, CA•Temporarily Remote',
#  'San Jose, CA',
#  'San Francisco, CA',
#  'Redwood City, CA',
#  'San Diego, CA',
#  'California•Remote',
#  'San Francisco, CA+1 location',
#  'San Jose, CA 95113 (Downtown area)+3 locations',
#  'Los Altos, CA 94022•Remote',
#  'Palo Alto, CA',
#  'Los Angeles, CA',
#  'San Francisco, CA',
#  'Mountain View, CA',
#  'Mountain View, CA',
#  'San Francisco, CA 94103 (South of Market area)',
#  'San Francisco, CA',
#  'Menlo Park, CA',
#  'Menlo Park, CA 94025',
#  'San Francisco, CA',
#  'San Francisco, CA 94105 (South Beach area)',
#  'San Diego, CA 92127 (Rancho Bernardo area)',
#  'Mountain View, CA',
#  'Redwood City, CA',
#  'San Francisco, CA',
#  'San Jose, CA 95128 (West San Jose area)',
#  'California•Remote',
#  'San Francisco, CA',
#  'Mountain View, CA',
#  'San Francisco, CA•Remote',
#  'San Jose, CA 95128 (West San Jose area)',
#  'California•Remote',
#  'San Francisco, CA',
#  'Mountain View, CA',
#  'San Francisco, CA•Remote',
#  'Los Angeles, CA 90064 (Sawtelle area)+1 location',
#  'San Francisco, CA',
#  'Alameda, CA',
#  'Newark, CA 94560',
#  'California•Remote',
#  'San Francisco, CA 94103 (South of Market area)',
#  'San Francisco, CA 94105 (Financial District area)',
#  'Orange County, CA',
#  'Menlo Park, CA',
#  'Mountain View, CA 94041 (Old Mountain View area)',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'San Diego, CA',
#  'San Francisco, CA',
#  'Los Gatos, CA•Remote',
#  'San Francisco, CA',
#  'Los Angeles, CA',
#  'Santa Clara Valley, CA 95014',
#  'Santa Clara Valley, CA 95014',
#  'Santa Clara Valley, CA 95014',
#  'Santa Clara Valley, CA 95014',
#  'United States',
#  'Los Angeles, CA 91367',
#  'Mountain View, CA•Temporarily Remote',
#  'Santa Clara Valley, CA 95014',
#  'Atherton, CA 94027',
#  'Santa Clara Valley, CA 95014',
#  'Irvine, CA 92614•Remote',
#  'San Francisco, CA',
#  'Los Angeles, CA',
#  'San Diego, CA 92121 (University City area)',
#  'Santa Clara Valley, CA 95014',
#  'Santa Clara Valley, CA 95014',
#  'Santa Clara Valley, CA 95014',
#  'Santa Clara Valley, CA 95014',
#  'Los Angeles, CA 91367',
#  'Mountain View, CA•Temporarily Remote',
#  'Santa Clara Valley, CA 95014',
#  'San Francisco, CA•Remote',
#  'Rancho Cordova, CA 95670•Remote',
#  'San Francisco, CA•Temporarily Remote',
#  'Santa Clara Valley, CA 95014',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Los Altos, CA 94022•Remote',
#  'San Diego, CA 92121 (University City area)',
#  'Irvine, CA 92612 (Business District area)+1 location•Temporarily Remote',
#  'Santa Clara Valley, CA 95014',
#  'Santa Clara Valley, CA 95014',
#  'Folsom, CA 95630',
#  'Santa Clara Valley, CA 95014',
#  'Santa Clara Valley, CA 95014',
#  'Santa Clara Valley, CA 95014',
#  'Santa Clara Valley, CA 95014',
#  'Santa Clara Valley, CA 95014',
#  'San Francisco, CA 94105 (South Beach area)',
#  'Atherton, CA 94027',
#  'Santa Clara Valley, CA 95014',
#  'Irvine, CA 92614•Remote',
#  'Los Gatos, CA•Remote',
#  'San Francisco, CA',
#  'Los Angeles, CA',
#  'San Diego, CA 92121 (University City area)',
#  'Santa Clara Valley, CA 95014',
#  'Santa Clara Valley, CA 95014',
#  'Santa Clara Valley, CA 95014',
#  ...]

# %%
summaries12
# Out:
# ['Experience with data visualization libraries such as Matplotlib, Pyplot, ggplot2.\n2+ years of industry or graduate research experience solving analytical…',
#  'Lead data-driven projects from definition to execution, from gathering data, defining metrics to communicating actionable insights;',
#  'Responsible for managing and developing the companies data utilization and translation into measurable, quantitative action points.\nTemporarily due to COVID-19.',
#  'We are looking for detail-oriented individuals who will collaborate with our team, label large amounts of data, and provide feedback to our data scientists and…',
#  "If you're passionate about data, impact, and working on an amazing team, read on!\xa0 You will:\xa0 Apply state-of-the-art machine learning techniques to…",
#  'Hands on experience handling terabyte size datasets, applying statistics and machine learning techniques and algorithms, using visualization tools to present…',
#  'We are looking for data scientists with experience applying machine learning and modeling techniques, including natural language processing, anomaly detection,…',
#  'Uses predictive modeling, statistics, Machine Learning, Data Mining, and other data analysis techniques to collect, explore, and extract insights from structure…',
#  "Collaborate with other data analysts and data scientists on the analytics team.\nYou'll carry out research and development projects aimed at optimizing player…",
#  'Opportunity for mentorship with data science and technology experts with decades of subject matter expertise.\nCompetitive salary, equity and benefits.',
#  '1-5 yrs experience in applying machine learning to applied use-cases.\nCollaborating with data and subject matter experts within IBM and its clients to…',
#  'We are looking for a data scientist with a very strong background in analytics and problem-solving abilities.\nBuild predictive models, classification models and…',
#  '1 to 3 years of commercial experience in a data analyst or data scientist role.\nProviding data analysis and recommendations to the business group to make…',
#  'We are looking for a sharp, strong communicator who can provide strategic data input to evolve Advanced care planning and Disease management to increase quality…',
#  'Experience with data visualization tools, such as Plotly.\nEnhancing data collection procedures to include information that is relevant for building analytic…',
#  'Proven experience in areas of optimization, statistics, machine learning, and inventory theory.\nSkills to collaborate with cross-functional teams and influence…',
#  'The data, analytics, insights, best practices, and action plans clients need are available whenever and wherever they need them, to help them make data-driven…',
#  'You are conscientious and forward-thinking, ensuring on-time, on-target and within-budget analytics, data quality and relevant ongoing maintenance, refinements…',
#  'Backed by more than 40 years of technology leadership, our memory and storage solutions enable disruptive trends, including artificial intelligence, 5G, machine…',
#  'Permanent offsite arrangements are, therefore, not available.\nThis is a senior level position with the opportunity to make a major impact.',
#  '2+ years experience autonomously translating ambiguous business problems into deep informative insights through hands-on analytics.',
#  'You will lead our Prognostics application, where we build machine learning pipelines to help identify which cars may need service so we can address issues…',
#  'Perform statistical analysis such as KPI deep dives, performance marketing efficiency, behavioral clustering, and user journey analytics.',
#  'Collaborate with a cross functional team of PMs, designers, and data scientists to build an optimized marketplace product.',
#  'Apply advanced analytics techniques (data mining, data visualization, statistical analysis, machine learning) on large-scale, high-dimensional data to help…',
#  'The Associate/Intermediate Data Scientist will develop and operationalize machine learning models in order to personalize players experience in Call Of Duty…',
#  'You will have time to dig deep into subject areas of importance.\nExperience working with spatial data.\nComfortable writing SQL and evaluating the quality of…',
#  'To support that mission, they are now looking for a strong data analyst / data scientist who understands B2C marketing and can drive analytics in this space.',
#  'Technical knowledge regarding data models, database design development, data mining and segmentation techniques.\nWho You’ll Work With.',
#  '(Ability to write functions, clean and efficient data manipulation are mandatory for this role).\nConceptual understanding in Machine Learning models like Nai¨ve…',
#  'Under supervision, coordinates solution development with machine learning scientists, physicians, and other stakeholders.',
#  'Additional requirements include the ability to read and implement related academic literature and experience in applying state of the art deep learning models…',
#  'Apply your expertise in quantitative analysis, data mining, and statistical modeling to deliver impactful, objective, and actionable data insights that enable…',
#  'Curiosity to discover business-relevant patterns in the data.\nBuild statistical and machine learning models for statistical inference and prediction.',
#  'Mine massive amounts of data and extract useful product insights.\nApply your expertise in quantitative analysis, data mining, and the presentation of data to…',
#  '5+ years of industry experience in data-driven machine learning.\nSolid foundation in computer science, software development, and machine learning.',
#  'Hands-on project experience is a plus.\nUse data and cutting-edge methodologies to infer causality, assess attribution and answer strategic questions.',
#  'Experience of handling large scale data with efficiency.\nProficient in SQL and/or other data query languages.\nSupport the internal Business Intelligence product…',
#  '2+ years of experience in data science, data analytics, or quantitative analysis.\nCollaborate with data teams across the globe to form best practices regarding…',
#  'Machine Learning Engineers at Zest AI build software that enables our customers to quickly create, adopt, and operate machine learning models in production.',
#  'Conduct cutting edge research and experiments in and around machine learning, text classification, entity linking, and entity extraction and other related…',
#  'We cover a wide area of the data spectrum including analytical data engineering, product analytics, experimentation, causal inference, statistical modeling and…',
#  'Conduct analysis of large datasets, extracting insights from user listening data that will drive content decision-making.',
#  'The data scientist will be responsible for predictive modeling and analysis of customer data, as well as researching best practices in analytics and data…',
#  'Ability to bring data to life for any audience via written communication, verbal communication and data visualization.',
#  'Comprehensive health coverage, competitive salary, 401(k) employer match, Employee Stock Purchase Plan (ESPP).',
#  'Build tools to enable other data scientists to scale their knowledge and increase impact.\nMaking a high quality data science project available in a public forum…',
#  'Work closely with our data scientists to pilot our products with beta customers.\nDesign and development of complex frameworks for applying ML / data science…',
#  'You have 2+ years of experience working in the machine learning space.\nYou will work closely with our data science, engineering, customer support and product…',
#  'Experience in applying machine learning techniques and collaborating with ML/AI scientist.\nCollaborate with engineering, other data scientists, and partner…',
#  'Have the opportunity to mentor junior data scientists.\nWe rely on advanced techniques in machine learning, cloud platforms, and big data to drive decisions…',
#  'Be a part of our data modernization efforts through the implementation of new data architecture, cloud, and machine learning technology.',
#  'Good knowledge of machine learning, data mining, deep learning, statistics;\nThe team is made up of machine learning researchers and engineers, who support and…',
#  'Working alongside engineering, product design, product management and our Augmented Reality design team, you will create data-based approaches to solving…',
#  'This is a demanding role supporting a high-impact team that needs someone who is highly proactive and self-motivated, flexible, and solution-oriented while…',
#  'Amgen’s Digital Integration and Predictive Technologies organization is a Process Development function that develops and deploys advanced computational…',
#  'Lead data-driven projects from definition to execution, from gathering data, defining metrics to communicating actionable insights;',
#  'Responsible for the development of state-of-the-art applied machine learning projects.\n1+ years of experience in applied machine learning teams or products.',
#  '2+ years of relevant experience applying statistical/machine learning methods to large datasets in an industry setting.\nKnowledge and experience with SQL.',
#  'Extensive expereince developing sofrware with python, SQL, Spark and leveraging leading numerical and machine learning libraries(NumPy, Pandas, Scikit-learn,…',
#  'As a senior data scientist on the Homebase data platform team, you will be responsible for building customer-facing data products in partnership with our…',
#  "Additionally, you'll build and maintain production quality machine learning models and explore and prepare disparate data sources for machine learning work.",
#  'Lead data analytics projects: translate complex business questions into concrete data analysis problems, improve on existing or build new models, deliver…',
#  'Fluency in the data science tech stack, including Python (pandas, numpy, scipy, matplotlib, scikit-learn) for data science/machine learning, analytics…',
#  'Minimum 2 years of experience with utilizing business intelligence / analytics / data visualization tools including Tableau, Power BI, and Microsoft NAV.',
#  'Holistic and end to end approach to data, including querying, aggregation, deep analysis, visualization and models; communicate and present findings/actionable…',
#  '2+ years in consulting/data science/marketing analytics roles.\nIdeally in a relevant field to analytics (finance, business, engineering, information systems,…',
#  'Build production grade machine learning pipelines and data products that solve critical, complex problems and deliver business value.',
#  '[Bonus] Experience applying both data-backed heuristics and machine-learning techniques to solve personalization and recommendation problems.',
#  '5+ years of industry experience in one or more machine/deep learning frameworks.\nYou might not be an expert in every stage of a Machine Learning project, but…',
#  'The ASIR Data Scientist will develop and maintain a learning/data analytics infrastructure for the campus, including novel machine learning innovations for the…',
#  'Skilled with Looker, Jupyter Notebook and other data visualization tools.\nAs a Data Scientist, you will partner closely with product managers, engineering,…',
#  'Experience in data visualization e.g. Tableau and ability to communicate results to a nontechnical audience.\nData analytics: 10 years (Preferred).',
#  'Deep understanding of data science principles, including machine learning, deep learning and artificial intelligence concepts.',
#  'With an eye to capture analytics value for the business unit, you will also drive and enable operational excellence in our Sales and Sales Operations…',
#  'The DS will identify, procure, and integrate both traditional data and ESG data from multiple sources and combine that data with relevant financial information…',
#  'This position will provide active engagement in experiencing the correlation between data science, especially deep learning and NLP, and real-world applications…',
#  'Strong experience in analyzing time series data and finding trends.\n3+ years of data science experience.\nStrong in python, R, SQL and experience in Statistics,…',
#  'The candidate should also have had experience working on projects with data scientists building models and deploying.\nJob Types: Full-time, Contract.',
#  'Identify, analyze and interpret trends, patterns and relationships in complex data sets, using advanced analytics tools and models.',
#  'You have demonstrated experience in developing, implementing and communicating machine learning algorithms or high-dimensional data analyses.',
#  'Perform data mining on large sets of data for various industries.\nUnderstanding and working with multiple data sources to create a unified solution that…',
#  'Knowledge in basic machine learning and deep learning.\nAdvanced degree in statistics, math, econometrics, quantitative sociology or a related scientific major,…',
#  'This role requires excellent technical skills and experience in data matching, analytical and machine learning applications, data mining, reporting, and…',
#  'Requires skills and experience to include: Data modeling skillset; Data manipulation and Data analytics tools; SQL, R, Python, Hive, or Spark; Tableau and…',
#  'Develop and implement statistical/machine learning models for various business areas, including Credit Risk, Fraud, Marketing, and Operations.',
#  'Invent data science algorithms and measure their effectiveness.\n4+ years of experience in data science/AI technologies.\nKnowledge of Python and SQL.',
#  '5+ years of industry experience in one or more machine/deep learning frameworks.\nYou might not be an expert in every stage of a Machine Learning project, but…',
#  'Evaluate new data sources identifying the most appropriate machine learning/deep learning/data mining/text mining techniques to uncover the value of the data.',
#  'Have data analytical skills to build the strategies.\nB.S. or M.S. Degree in a quantitative field such as statistics, economics, applied math, operations…',
#  'Practical and theoretical understanding of common machine learning processes.\nUse domain leadership and deep understanding of customer problems to yield…',
#  'Conduct ad-hoc analysis to understand unexpected metric movements and communicate results to other data scientists, product managers and company leadership.',
#  'As the Senior Data Scientist, you will apply your advanced analytics, data wrangling, and visualization skills to solve problems across marketing, sales, and…',
#  'Work with complex data structures and provide innovative ways to a solution for complex data delivery requirements.',
#  '5+ years of leadership experience managing a team of 15+ data scientists and product analysts across multiple locations at a technology company.',
#  'Experience with data visualization; creation of metrics reports and dashboard views.\nWorking collaboratively within the Leadership team and with outside…',
#  "Deeply understand the business landscape, various teams' needs/painpoints, and have the foresight to drive insights & constant improvement to TikTok's analytics…",
#  'You will work closely with our other data scientists, engineers, and product managers to help develop data-driven products and machine learning systems that…',
#  'You will be performing thorough testing and validation of models, and support various aspects of the business with data analytics.',
#  'Expertise in data analysis and data mining.\nResponsible for algorithm design, development, implementation, testing, and documentation for machine learning model…',
#  'Knowledge of quantitative methods in statistics and machine learning.\nExperience with E-commerce marketing and product analytics is a plus.',
#  'Utilize and implement machine learning models for data analysis.\nSupport project leads to identify valuable data sources, and work with our IT team to collect…',
#  'The ideal candidate is passionate about applying machine learning, artificial intelligence and statistics to real-world problems; has experience in implementing…',
#  'Master our varied types of data from healthcare claims data, digital engagement data, third party point solution member utilization data, operational data,…',
#  'Experience managing a team of data scientists.\nRecruit top talent and build/ retain a stellar team of data scientists.\nTech Lead experience is a plus.',
#  'Develop custom data models and algorithms to apply to data sets.\nAssess the effectiveness and accuracy of new data sources and data gathering techniques.',
#  'Collaborate with other data scientists across our organization to share best practices, learn new analytical techniques, and champion an organizational culture…',
#  'Work with the data engineering team to develop and maintain efficient data pipelines.\nAbility to support and work closely with a myriad of colleagues who are…',
#  'Explores existing data for insights and recommends additional sources of data for improvements.\nStrong modeling foundation – hands-on expertise with data mining…',
#  'Collaborate with data engineers, other data scientists, product managers, and clinical researchers to align R&D with business objectives.',
#  "Master's degree in data analytics related fields.\nDesign and implement reporting dashboards and the associated data pipeline to deliver insights and improve the…",
#  'Full medical, dental, and vision with optional 70% coverage for dependents.\nPaid time off to volunteer.',
#  '2+ years managing a team of data scientists.\nLead a team of 5+ data scientists in developing high-quality, robust, predictive and explainable algorithms that…',
#  'Work with Engineering teams to ensure best practices are followed for product deployment and solution implementation.',
#  'Our clients need flexible data structures and a streamlined data architecture that quickly turns data resources in.\nEmployee Status : Full Time Employee.',
#  'As an analytics leader, and given the role of the IG Shop Tab in the overall Family of Apps Commerce strategy, you would work with cross-functional partners and…',
#  'Build and maintain data pipelines for analytics, measurement, and dashboarding purposes.\nExperience problem solving and providing business insights and…',
#  'Translate unstructured business problems into well-defined machine learning projects.\nExpert experience designing, developing, and implementing machine learning…',
#  '2+ years of industry experience using experimentation, machine learning, and analytics to solve real world problems with large datasets.',
#  'Mentor and partner with embedded data scientists on individual channel teams to drive business performance.\nExamples of projects you would work on include, but…',
#  'We are looking for data scientist candidates with strong data analytics background and solid software development skills, who can utilize data-driven techniques…',
#  'Set product goals, design and evaluate experiments, monitor the health of our products and understand changes to our KPIs.',
#  'Experience with multiple modern techniques and algorithms in machine learning and statistical computing such as regression, clustering/segmentation, time-series…',
#  'Experience and interest in data visualization techniques (e.g. Matplotlib, Superset, Tableau).\nApply statistical analysis to test (accelerated life) and field …',
#  'Work with our Risk & Insurance team to build deep-dive analytics to help drive step-change improvements in efficiency (beyond day-to-day workforce management).',
#  'Perform impact assessment and deep-dive analysis in collaboration with stakeholders to ensure data integrity, consistency, usability, and completeness.',
#  'Strong predictive data modeling experience is required with proven application in applying Decision Trees, Regression analysis, and other data mining techniques…',
#  'Present information using data visualization techniques.\nWe want to see a passion for machine-learning and research.\nCombine models through ensemble modeling.',
#  'Familarity with machine learning or social/content online platform analytics.\nBachelor or degrees above in computer science, statistics, math, internet security…',
#  'Use expertise in causal inference, machine learning, complex systems modeling, behavioral decision theory etc. to shape the future of Instacart.',
#  'Expertise in data visualization tools such as Tableau.\n3+ years of experience in a data analytics role with strong exposure or interest in strategy.',
#  'We are seeking a data mining scientist to provide applied research and data modeling expertise in this area.\nWork with business partners to support overall eBay…',
#  'Passion for machine learning (ML) and understanding of industry trends, especially as it relates to NLP (deep learning, large language models, transfer learning…',
#  'Experience working with other data scientists, software engineers, clinicians and neuroradiologists.\nExperience working with and developing deep learning based…',
#  'Experience building statistical modeling and applying machine learning techniques.\nIdentify needs, explore relevant data and develop applicable tools to drive…',
#  'The data scientist is also a source of new insights into the capabilities of our system, identifying new opportunities and use cases for our system that can…',
#  'We are hiring talented, highly motivated applied scientists with expertise in deep learning, machine learning, natural language processing, information…',
#  'Hands on experience handling terabyte size datasets, applying statistics and machine learning techniques and algorithms, using visualization tools to present…',
#  'Contribute to expand the knowledge base within area of expertise, which includes IaaS, DaaS, visualization, analytics, OR techniques, and strategy…',
#  'Develop custom data models and algorithms to apply to data sets.\nAssess the effectiveness and accuracy of new data sources and data gathering techniques.',
#  'Build tools to enable other data scientists to scale their knowledge and increase impact.\nMaking a high quality data science project available in a public forum…',
#  'You’ll develop algorithms, write scripts, build predictive analytics, apply machine learning, and use the right combination of tools and frameworks to turn that…',
#  'Familiarity with data mining, data science or machine learning.\nBachelor or degrees above in computer science, computer engineering, electrical engineering,…',
#  'Lead, grow, and foster high-performance teams of in-house data scientists and ML experts.\nIdentify areas where improvements in data analytics can bring more…',
#  'We are looking for a Data Scientist who will be responsible for developing algorithms for anomaly detection, diagnostics, and prognostics of failure using…',
#  'Partner with other data scientists, product managers, product designers, engineers and apply your expertise in quantitative analysis, data mining, and…',
#  'Apply your expertise in quantitative analysis, data mining, and the presentation of data to see beyond the numbers and understand how our users interact with…',
#  'Expertise in data analysis and data mining.\nResponsible for algorithm design, development, implementation, testing, and documentation for machine learning model…',
#  'Organize data from multiple analytics platforms.\nThis is a full time position with benefits.\nManage spreadsheets and performance reports.',
#  'Waymo data scientists work closely with engineering and ensure high-quality reasoning and validation about data and models in our production systems.',
#  'We are seeking a data mining scientist to provide applied research and data modeling expertise in this area.\nWork with business partners to support overall eBay…',
#  'Basic experience or basic understanding of machine learning, data mining, and natural language processing.\n3+ years of experience in data analysis, data science…',
#  'Delivery of the Clinical Study Report (CSR), Study Data Tabulation Model (SDTM)/Analysis Data Model (ADaM) databases and Tables, Figures and Listings (TFL)…',
#  'Degree in operations research, industrial engineering, computer science, applied math, physics, economics, or other quantitative science preferred.',
#  'Contribute to expand the knowledge base within area of expertise, which includes IaaS, DaaS, visualization, analytics, OR techniques, and strategy…',
#  'This is a demanding role supporting a high-impact team that needs someone who is highly proactive and self-motivated, flexible, and solution-oriented while…',
#  'Incorporate machine learning and data-driven decisioning into the core of our infrastructure.\nDemonstrated expertise in building data tools for ETL and data…',
#  'Up to date on current research papers and industry trends in the field of Machine Learning.\nCreate plans and schedules, track progress and provide educational…',
#  'Conduct transaction data analyses with Hadoop/Spark and big data tools for internal and external product owners, and develop deeper insights into the products…',
#  'Present information using data visualization techniques.\nWe want to see a passion for machine-learning and research.\nCombine models through ensemble modeling.',
#  'Excellent project management skills and the ability to develop and maintain collaborative and productive research relationships with external research partners.',
#  'Strong predictive data modeling experience is required with proven application in applying Decision Trees, Regression analysis, and other data mining techniques…',
#  'Setup, execute, and analyze experiments applying deep RL to target domains.\nWrite code to support research programs and contribute to our AI codebase.',
#  'Solid fundamentals, knowledge of supervised, unsupervised, machine learning and deep learning algorithms, such as classifiers, cluster analysis, dimension…',
#  'As an analytics leader, and given the role of the IG Shop Tab in the overall Family of Apps Commerce strategy, you would work with cross-functional partners and…',
#  'Solid fundamentals, knowledge of supervised, unsupervised, machine learning and deep learning algorithms, such as classifiers, cluster analysis, dimension…',
#  'As an analytics leader, and given the role of the IG Shop Tab in the overall Family of Apps Commerce strategy, you would work with cross-functional partners and…',
#  'Have data analytical skills to build the strategies.\nB.S. or M.S. Degree in a quantitative field such as statistics, economics, applied math, operations…',
#  'Be a part of our data modernization efforts through the implementation of new data architecture, cloud, and machine learning technology.',
#  'Full medical, dental, and vision with optional 70% coverage for dependents.\nPaid time off to volunteer.',
#  'We sit at the cross section of data science and machine learning.\nUnderstand patterns in data to identify key product trends and new product opportunities.',
#  'Extensive expereince developing sofrware with python, SQL, Spark and leveraging leading numerical and machine learning libraries(NumPy, Pandas, Scikit-learn,…',
#  'Develop and implement statistical/machine learning models for various business areas, including Credit Risk, Fraud, Marketing, and Operations.',
#  'Hands on experience in one or more of the areas: machine learning, deep learning, pattern recognition, anomaly detection, data mining, computer vision, NLP or…',
#  'Bachelor’s Degree plus 5 years of experience in data analytics, or Master’s Degree plus 3 years in data analytics, or PhD.',
#  'From a research perspective, exploring, prototyping, validating, and iterating new machine learning algorithms.',
#  'Partner closely with data scientists, engineers, and PMs to improve Snap’s causal analysis platforms.\n7+ years of experience in data science or another relevant…',
#  'This requires being persistent and flexible, extracting data from various sources, cleaning and curating these data, and clearly and concisely communicating…',
#  'Experience with data visualization tools, such as Plotly.\nEnhancing data collection procedures to include information that is relevant for building analytic…',
#  '5+ years experience in building and evaluating machine learning & deep learning models.\nThe Staff Machine Learning Engineer will set the technical direction of…',
#  'Basic experience or basic understanding of machine learning, data mining, and natural language processing.\n3+ years of experience in data analysis, data science…',
#  'Bonus qualification having experience in designing and automating ML analysis at scale and leveraging data-mining techniques to identify insights and patterns…',
#  'Work closely with Product or Engineering & Operations teams to proactively create rule and manage decisions.\nCandidates will help own analytics for a particular…',
#  'Write scripts to analyze data and perform specific data queries.\nLook for data in our operational systems that can be the base for new dashboards and analytics…',
#  'Ability to build NLP data pipelines and perform data transformations to fit deep learning models for language learning.\nYou have some C++ experience.',
#  'The ASIR Data Scientist will develop and maintain a learning/data analytics infrastructure for the campus, including novel machine learning innovations for the…',
#  'Full medical, dental, and vision with optional 70% coverage for dependents.\nPaid time off to volunteer.',
#  'Develop and implement statistical/machine learning models for various business areas, including Credit Risk, Fraud, Marketing, and Operations.',
#  '4 years of relevant work experience (e.g., as a data scientist), including experience applying advanced analytics to planning and infrastructure problems.',
#  'Natural language generation, text summarization, machine translation.\nDialog system, question answering, machine comprehension.',
#  'Lead data analytics projects: translate complex business questions into concrete data analysis problems, improve on existing or build new models, deliver…',
#  'Collaborate with data scientists and business owners across the company to strategically and accurately craft their public facing statements.',
#  'Expertise in data visualization tools such as Tableau.\n3+ years of experience in a data analytics role with strong exposure or interest in strategy.',
#  'Desire to collaborate with other data scientists, data analysts, and key business partners.\nPartnership: Partner closely with business stakeholders to identify…',
#  'Work with state-of-art CI/CD systems to automate, deploy and monitor machine learning workloads.\nPreferably compiler or machine learning software.',
#  'This is a demanding role supporting a high-impact team that needs someone who is highly proactive and self-motivated, flexible, and solution-oriented while…',
#  'Partner closely with other data scientists and data engineers to help inform, build, and test hypotheses delivering actionable insights.',
#  'Enable other machine learning scientists in the broader group to experiment quickly and accurately.\nExperience with large scale data mining tools such as Spark.',
#  'Build production grade machine learning pipelines and data products that solve critical, complex problems and deliver business value.',
#  'Write scripts to analyze data and perform specific data queries.\nLook for data in our operational systems that can be the base for new dashboards and analytics…',
#  'All Scientists will also actively participate the Fusion Power research program by designing and performing experiments, performing data analysis, occasional…',
#  "A bachelor's degree in a scientific field including coursework in computer science and/or data science.\nCode in a scientific programming language (e.g. R or…",
#  '4+ years of strong industry experience in relevant data mining domains.\nDrive and take responsibility for exercising data science best practices around risk…',
#  'Extensive expereince developing sofrware with python, SQL, Spark and leveraging leading numerical and machine learning libraries(NumPy, Pandas, Scikit-learn,…',
#  'Build tools to enable other data scientists to scale their knowledge and increase impact.\nMaking a high quality data science project available in a public forum…',
#  'You will help us set a standard for data-driven, scientific decision-making throughout the business.\nBuilding machine learning models and deploying them as…',
#  'Partner with other data scientists, product managers, product designers, engineers and apply your expertise in quantitative analysis, data mining, and…',
#  'Expert in statistics and data science, and machine learning models.\nCollaborate with product, design and the broader engineering team on data science models,…',
#  'Familarity with machine learning or social/content online platform analytics.\nBachelor or degrees above in computer science, statistics, math, internet security…',
#  'Opportunity for mentorship with data science and technology experts with decades of subject matter expertise.\nCompetitive salary, equity and benefits.',
#  '5+ years experience in building and evaluating machine learning & deep learning models.\nThe Staff Machine Learning Engineer will set the technical direction of…',
#  'You have 4+ years previous experience as a data scientist, data analyst, or data engineer.\nYou have the ability to translate raw data into meaningful business…',
#  'Partner closely with data scientists, engineers, and PMs to create Airflow pipelines that power dashboards.\nWork cross-functionally and partner with brand and…',
#  'Participate in all aspects of the project lifecycle from requirements gathering, data acquisition and preparation, hypothesis generation, ideation, coding,…',
#  'Conduct transaction data analyses with Hadoop/Spark and big data tools for internal and external product owners, and develop deeper insights into the products…',
#  'Natural language generation, text summarization, machine translation.\nDialog system, question answering, machine comprehension.',
#  'Provides data science subject matter expertise in the planning and execution of cell and gene therapy projects that require advanced analytics methods, ensuring…',
#  'Under direct supervision, the Research Data Analyst acquires skills and knowledge of professional concepts in research data analysis, with a focus on machine…',
#  'This individual’s primary focus will be applying data mining techniques, doing statistical analysis, and building high quality prediction systems to evaluate…',
#  'The ASIR Data Scientist will develop and maintain a learning/data analytics infrastructure for the campus, including novel machine learning innovations for the…',
#  '3+ years of hands-on experience in data mining, machine learning and/or statistical analysis.\nUnderstand the data and dig deep to extract actionable insights.',
#  'You will dive deep into data to uncover trends, identify key insights, and craft machine learning models to improve the accuracies, minimize resource usage and…',
#  '5+ years of industry experience in one or more machine/deep learning frameworks.\nYou might not be an expert in every stage of a Machine Learning project, but…',
#  'Present information using data visualization techniques.\nWe will rely on you to build data products to extract valuable business insights.',
#  'Collaborate with data scientists and business owners across the company to strategically and accurately craft their public facing statements.',
#  'Minimum 2 years of experience with utilizing business intelligence / analytics / data visualization tools including Tableau, Power BI, and Microsoft NAV.',
#  'You have demonstrated experience in developing, implementing and communicating machine learning algorithms or high-dimensional data analyses.',
#  'Partner with other data scientists, product managers, product designers, engineers and apply your expertise in quantitative analysis, data mining, and…',
#  'From a research perspective, exploring, prototyping, validating, and iterating new machine learning algorithms.',
#  'Collaborate with data scientists and business owners across the company to strategically and accurately craft their public facing statements.',
#  '1+ years of experience in data manipulations and analytics.\n3+ years of experience in data manipulations and analytics.',
#  'Design and implement neural networks to provide automation of clinical tasks using one or more of medical images, electronic medical records, waveforms, and…',
#  'Experience applying innovative solutions based on data mining analytics.\nYou will be using and developing tools and techniques such as statistical algorithms,…',
#  'Develop custom data models and algorithms to apply to data sets.\nAssess the effectiveness and accuracy of new data sources and data gathering techniques.',
#  'We are looking for experienced data scientists to join us in using advanced analytics and machine learning to help optimize product and user experience, and to…',
#  'We invite applications both from dry-lab scientists and from wet-lab scientists with substantial quantitative experience.',
#  'Present information using data visualization techniques.\nWe will rely on you to build data products to extract valuable business insights.',
#  'Hands on experience in one or more of the areas: machine learning, deep learning, pattern recognition, anomaly detection, data mining, computer vision, NLP or…',
#  'Build tools to enable other data scientists to scale their knowledge and increase impact.\nMaking a high quality data science project available in a public forum…',
#  'Work with complex data structures and provide innovative ways to a solution for complex data delivery requirements.',
#  'Apply your expertise in quantitative analysis, data mining, and the presentation of data to see beyond the numbers and understand how our users interact with…',
#  'Art financial data analysis applications.\nDeveloping statistic models using historical and real-time price data.\nHours: 10-15 hours per week.',
#  'Ability to quickly and effectively diagnose issues, evaluate fixes, and propose solutions for statistical data analysis and machine learning techniques (e.g.…',
#  'Degree / experience in a relevant subject.\nUsing big data, deep expertise and AI-driven platforms to decode the 21st century human experience – then redefine it…',
#  'Conduct research and prototyping innovations; data and requirements gathering; solution scoping and architecture; consulting clients and client facing teams on…',
#  'Strong predictive data modeling experience is required with proven application in applying Decision Trees, Regression analysis, and other data mining techniques…',
#  'Collaborate with machine learning engineers, build tools to understand complex machine learning models and identify areas of improvements for the model.',
#  'Familiarity with Machine Learning frameworks (Tensorflow, Pytorch, XGBoost, etc.).\nStrong Programming Skills (Python, C++, etc.).',
#  'Work with complex data structures and provide innovative ways to a solution for complex data delivery requirements.',
#  'Inform, influence, support, and execute analysis that feeds into one of our many analytics domains - Customer analytics, product analytics, business operation…',
#  '4 years of relevant work experience (e.g., as a data scientist), including experience applying advanced analytics to planning and infrastructure problems.',
#  'Expertise in data visualization tools such as Tableau.\n3+ years of experience in a data analytics role with strong exposure or interest in strategy.',
#  'Work with the data engineering team to develop and maintain efficient data pipelines.\nAbility to support and work closely with a myriad of colleagues who are…',
#  'Mine massive amounts of data and extract useful product insights.\nApply your expertise in quantitative analysis, data mining, and the presentation of data to…',
#  'Collaborate with data scientists and business owners across the company to strategically and accurately craft their public facing statements.',
#  'This role will primarily focus on performing exploratory data analysis, engineering features using domain knowledge, and building relevant machine learning…',
#  'Hands on experience in one or more of the areas: machine learning, deep learning, pattern recognition, anomaly detection, data mining, computer vision, NLP or…',
#  'Ideally, your team would have had technical expertise covering at least two of the following: BI analytics, machine learning, and A/B experimentation.\xa0…',
#  'Under direct supervision, the Research Data Analyst acquires skills and knowledge of professional concepts in research data analysis, with a focus on machine…',
#  'Ability to quickly and effectively diagnose issues, evaluate fixes, and propose solutions for statistical data analysis and machine learning techniques (e.g.…',
#  'You have cultural familiarity with scientists and labs from personal experience.\nExperience. You have 3+ years of real-world experience in data science,…',
#  'Design and implement networks to provide automation of clinical tasks using one or more of medical images, electronic medical records, waveforms, and clinical…',
#  'Statistical Research Programmers are expected to acquire a basic understanding of the research topic and a thorough knowledge of the data involved while…',
#  'We are hiring talented, highly motivated applied scientists with expertise in deep learning, machine learning, natural language processing, information…',
#  'The Machine Learning (ML) group within Prescient Design seeks exceptional researchers who have a demonstrated research background in machine learning, a passion…',
#  'Partner closely with data scientists, engineers, and PMs to create Airflow pipelines that power dashboards.\nWork cross-functionally and partner with brand and…',
#  'Strong predictive data modeling experience is required with proven application in applying Decision Trees, Regression analysis, and other data mining techniques…',
#  'Deep experience in applied machine learning, statistical learning, mathematical optimization and scalable computing.',
#  'Leverage your intellectual curiosity, a broad array of statistical and machine learning techniques to investigate problems, detect patterns and trends in the…',
#  'Build up product analytics taxonomy and documentation framework to ensure a sustainable workflow for cross-team data availability.\n12-week paid parental leave.',
#  'Ideally, your team would have had technical expertise covering at least two of the following: BI analytics, machine learning, and A/B experimentation.\xa0…',
#  'Build the machine learning platform that empowers our Data Science and Product Engineering teams, powering product features used by millions of users every day.',
#  '5+ years experience at a software company as a machine learning engineer, data scientist, or in related fields.',
#  'The successful candidate will lead the development and execution of novel machine learning methods for the analysis of biological data, with focus on scRNA-seq…',
#  'Exposure to applied machine learning in an enterprise setting.\nTraining data – Adobe’s training datasets often contain digital art, photos, videos, text, or…',
#  '2+ years of relevant experience applying statistical/machine learning methods to large datasets in an industry setting.\nKnowledge and experience with SQL.',
#  '5+ years of industry experience in one or more machine/deep learning frameworks.\nYou might not be an expert in every stage of a Machine Learning project, but…',
#  'Partner closely with data scientists, engineers, and PMs to create Airflow pipelines that power dashboards.\nWork cross-functionally and partner with brand and…',
#  'Contribute to existing internal and external machine learning-based products via researching new methodologies, creating new measurement/validation techniques,…',
#  'You should be able to work cohesively with subject matter experts, understand both data systems and physical systems, and have an eye for anomalies in physical…',
#  'We are applied quantitative and computational experts using math, statistics, and machine learning to measure & optimize cost, performance, reliability and…',
#  'Improve the work of other data scientists through mentorship and by bringing industry best practices to the team.\nB.S., M.S., or Ph.D. in a quantitative field.',
#  'Ability to investigate down to data source to ensure accuracy of data.\nAdvanced relevant degree (Statistics, Mathematics, Physics, Economics, Engineering,…',
#  'Design and implement networks to provide automation of clinical tasks using one or more of medical images, electronic medical records, waveforms, and clinical…',
#  'Knowledge of machine learning, information retrieval, data mining, statistics, NLP or related field.\nExperience managing end-to-end machine learning pipeline…',
#  'With our real-time 3D tracking technology, we create data models for live predictive analytics.\nRun machine learning tests and experiments.',
#  'You have demonstrated experience in developing, implementing and communicating machine learning algorithms or high-dimensional data analyses.',
#  'Leverage your intellectual curiosity, a broad array of statistical and machine learning techniques to investigate problems, detect patterns and trends in the…',
#  'HireArt is helping Toyota Research Institute (TRI) find a Machine Learning Data Engineer to contribute to state-of-the-art machine learning data infrastructure…',
#  'Experience in applying both data-backed heuristics and machine-learning techniques to solve practical product problems such as funnel optimization.',
#  'Up to date on current research papers and industry trends in the field of Machine Learning.\nCreate plans and schedules, track progress and provide educational…',
#  'Some data mining/data analysis/data profiling experience.\nWorking with other senior staff in data enrichment through the development of machine learning…',
#  'As an analytics engineer at Transform, you will work at the intersection of product, engineering, sales, and customer success to understand current customers’…',
#  'Communicate complicated concepts to a wider audience - both data scientists and broader business partners.\nYou have a theoretical and practical understanding of…',
#  'Perform data linkages with cancer registries, Medicare files, and other data resources.\nAssist in interpretation of large epidemiologic data sets.',
#  'Incorporate machine learning and data-driven decisioning into the core of our infrastructure.\nDemonstrated expertise in building data tools for ETL and data…',
#  'Partner with product, operations, and clinical care teams to understand user journeys and recommend product improvements.',
#  'This position will provide active engagement in experiencing the correlation between data science, especially deep learning and NLP, and real-world applications…',
#  'We consider qualified applicants with criminal histories, consistent with applicable law.\nIn this role, the Reporting Analyst will work with a multidisciplinary…',
#  'Design and implement neural networks to provide automation of clinical tasks using one or more of medical images, electronic medical records, waveforms, and…',
#  'We are looking for a data scientist who has a nose for identifying fraud and anomalous patterns in huge and often messy datasets, and who is adept at using…',
#  'We do this through data analytics, journey mapping, qualitative and quantitative research, process improvement, and project management.',
#  'Minimum 2 years of experience with utilizing business intelligence / analytics / data visualization tools including Tableau, Power BI, and Microsoft NAV.',
#  'The successful candidate will lead the development and execution of novel machine learning methods for the analysis of biological data, with focus on scRNA-seq…',
#  '5+ years of industry experience in analytics, product, or research capacity, applying data-driven insights to product or business problems; experience in a…',
#  'Develop custom data models and algorithms to apply to data sets.\nAssess the effectiveness and accuracy of new data sources and data gathering techniques.',
# ...
#  'Responsible for applying machine learning to improve user experience on mobile apps, such as app security, privacy protection, and malicious content detection;',
#  'Collaborate with members of your team (e.g., data analysts, data scientists, channel managers, product managers) on project goals.\nTemporarily due to COVID-19.',
#  'Good communication skills with engineer side (data scientists, machine learning engineers, system engineers etc.) and business side(business planner, marketer,…',
#  'Responsible for applying machine learning to improve user experience on mobile apps, such as app security, privacy protection, and malicious content detection;',
#  'Collaborate with members of your team (e.g., data analysts, data scientists, channel managers, product managers) on project goals.\nTemporarily due to COVID-19.',
#  'Good communication skills with engineer side (data scientists, machine learning engineers, system engineers etc.) and business side(business planner, marketer,…',
#  'Set product goals, design and evaluate experiments, monitor the health of our products and understand changes to our KPIs.',
#  'Strong core CS fundamentals (data structures, algorithms, architecting systems).\nOwn both the ML models and the underlying software tooling and infrastructure.',
#  "Displays deep knowledge in a specific area of machine learning; acquires advanced knowledge of current and future industry trends, competitors' products, and…",
#  'You will interact with fellow data scientists in different enterprises to understand what and how they deploy, how to effectively manage the necessary…',
#  '3+ years applied experience in business intelligence, data mining, analytics, or statistical modeling in technology or mobile industries OR 2+ years applied…',
#  'Develop custom models based on in-depth understanding of underlying data, data structures, and business problems to ensure analytics deliverables meet client…',
#  'HireArt is helping Toyota Research Institute (TRI) find a Machine Learning Data Engineer to contribute to state-of-the-art machine learning data infrastructure…',
#  '5+ years of experience in data science and machine learning applications.\nExcellent knowledge of statistical and machine learning modeling concepts.',
#  'Knowledge of data mining, and big data analytics techniques.\nBuild statistical models, data pipelines, data mining, data analytics, and production ready…',
#  'Dolby’s Applied AI group is looking for a Deep Learning researcher to contribute to Dolby’s focus on AI and machine learning for audio.',
#  'Experience in one or more of the following areas: applied machine learning, machine learning infrastructure, large-scale recommendation system.',
#  'Design and deep dive experimentation to validate hypothesis and drive product progress with XFN teams.\nCollaborate with engineers, product managers, policy team…',
#  'Lead the machine learning effort in pricing and incentives.\nExperience in large scale causality learning and/or deep learning.',
#  'Work with our Risk & Analytics team to build deep-dive analytics to help drive step-change improvements in efficiency (beyond day-to-day workforce management),…',
#  "Robinhood's benefits include generous time off, 401(k) participation with employer match, comprehensive health coverage, a health savings account (HSA),…",
#  'Mine massive amounts of data and extract useful product insights.\nApply your expertise in quantitative analysis, data mining, and the presentation of data to…',
#  'You will be part of our machine learning team, responsible for developing deep learning solutions end-to-end from data processing to architecture development to…',
#  '7+ years of experience working in an analytics organization.\nDefine problems and opportunities in a complex or ambiguous area.',
#  '2+years of experience applying data science/machine learning/deep learning methodologies to real-world problems.',
#  '5+ years of work experience in data science or quantitative analysis, including 3+ years of hands-on management of high-performing team of data scientists…',
#  'Experience working with high volumes of data, ideally with machine learning playing a critical role.\nStrong foundational knowledge of mathematics, bonus if…',
#  'Experience in modern Deep Learning and Natural Language Processing / Natural Language Understanding (NLP, NLU), including Neural Networks, RNNs, seq2seq…',
#  'Successfully applied machine learning, statistical methods, data mining to academic/work projects.\nBe on the leading edge of applying machine learning and data…',
#  'You have Strong data modeling skills, hands on mastery of data manipulation and experience with data analytics tools (SQL, Python, Spark, etc.) and data…',
#  'Cruise is looking for a deep learning compiler engineer to build the compiler and software tool chain for deploying machine learning models on to a variety of…',
#  'Experience with Python scientific modules, databases, and data processing pipelines.\nBuild data pipelines for collection, storage, processing, and analysis of…',
#  'Expert in Python and core libraries used by data scientists (Numpy, Scipy, Pandas, Scikit-learn, Matplotlib/Seaborn, etc.).',
#  'Successfully applied machine learning, statistical methods, data mining to academic/work projects.\nBe on the leading edge of applying machine learning and data…',
#  'You have Strong data modeling skills, hands on mastery of data manipulation and experience with data analytics tools (SQL, Python, Spark, etc.) and data…',
#  'Cruise is looking for a deep learning compiler engineer to build the compiler and software tool chain for deploying machine learning models on to a variety of…',
#  'Experience with Python scientific modules, databases, and data processing pipelines.\nBuild data pipelines for collection, storage, processing, and analysis of…',
#  'Expert in Python and core libraries used by data scientists (Numpy, Scipy, Pandas, Scikit-learn, Matplotlib/Seaborn, etc.).',
#  'At Acumen, LLC / The SPHERE Institute, Data and Policy Analysts provide analytical support for research and consulting projects for government and private…',
#  'We are looking for machine learning software engineers who have experience building at least one of the following:\nML/AI models which are in production.',
#  'You will use your extensive knowledge of machine learning, statistics, stochastic models, and deterministic models to develop novel approaches to abstract…',
#  'Relevant work experience, including experience applying advanced analytics, and data mining techniques.\nAdapt machine learning and data mining algorithms to…',
#  'Our work lies at the intersection of many diverse fields including machine learning, signal processing, biostatistics, and epidemiology, and in this role you…',
#  'Strong background in one or more of the following areas: machine learning, recommendation system, search ranking, or data mining.',
#  'Our data analytics and cloud platforms use state-of-the-art technologies to set you up for success.\nKnowledge of machine learning algorithms (time series…',
#  'Applying machine learning, time series models, signal processing, and battery physics to develop predictive models and algorithms capable of predicting battery…',
#  'Lead data analysis projects that answer those questions from start to finish: gather and process the necessary data, build or spin-up the right tools, and…',
#  'Combine strong software engineering principles with machine learning to build scalable, reproducible and easy-to-use end-to-end machine learning workflows for…',
#  'Experience with large-scale data and computational technologies (e.g. Spark, Snowflake).\nStrong experience building ML engineering solutions at a enterprise…',
#  'The Data Science Consultant works with our customers to explore data, design and build data pipelines and actionable insights with custom reports, dashboards…',
#  'Qualcomm AI Research looking for talented machine learning algorithm evaluation engineers with experience in machine learning to enable embedded deep learning.',
#  'In this role you’ll work with scientists, product managers, engineers and clinical experts who are developing a range of health applications from AI-powered…',
#  'Collaborate with fellow data scientists and SW engineers to build out various parts of our AI/ML infrastructure, services, and solutions, and effectively…',
#  'You will join a dynamic and multi-disciplinary group of physicians, neuroscientists, and data scientists developing cutting-edge technologies and applications…',
#  'Because the European Union Commission has determined that United States data privacy laws do not ensure an adequate level of protection for personal data…',
#  'Strong passion for applied empirical analytics, data mining, and predictive analytics to develop impactful insights.',
#  'MS in CS or related field with focus on machine/deep learning, computer vision, computer graphics, robotics or similar and 2+ years of relevant industry…',
#  'Foundation in data science, machine learning, and analytics, including statistical data analysis and A/B testing.',
#  'Work includes designing high-performance machine learning models to enable new system experiences in concert with designers, software/hardware engineers, and…',
#  'You can manage all facets of project delivery including but not limited to, stakeholder relationships, work prioritization, planning, project risk assessment,…',
#  'The Account Analyst will report directly to the Operations Manager with a dotted line to the Account Supply Chain Manager, providing reporting and operational…',
#  '3+ years of research or practical experience in applying deep learning algorithms on large scale and real world data.\nStrong coding skills in Python and C++.',
#  'PhD in NLP, Machine Learning, Statistics, Forecasting, Optimization, Reinforcement Learning or related field with experience building production systems or have…',
#  'You will contribute in the decision making process in regards to MLOps processes and the technology roadmap.\n3+ years ML experiences in production.',
#  'You will work on implementing and improving tools, automation and processes around how we build, test and deliver Siri!',
#  'The ability to serve as a subject matter expert (SME) regarding threats and vulnerabilities.\nThis is an exciting opportunity to work for a global leader in life…',
#  'You will join a dynamic and multi-disciplinary group of physicians, neuroscientists, and data scientists developing cutting-edge technologies and applications…',
#  'Because the European Union Commission has determined that United States data privacy laws do not ensure an adequate level of protection for personal data…',
#  'Mine and analyze internal data sets and reports to help stakeholders develop action plans and / or draw conclusions.\nExperience with Salesforce.com a plus.',
#  'Strong passion for applied empirical analytics, data mining, and predictive analytics to develop impactful insights.',
#  'MS in CS or related field with focus on machine/deep learning, computer vision, computer graphics, robotics or similar and 2+ years of relevant industry…',
#  'Foundation in data science, machine learning, and analytics, including statistical data analysis and A/B testing.',
#  'Work includes designing high-performance machine learning models to enable new system experiences in concert with designers, software/hardware engineers, and…',
#  'The Account Analyst will report directly to the Operations Manager with a dotted line to the Account Supply Chain Manager, providing reporting and operational…',
#  '3+ years of research or practical experience in applying deep learning algorithms on large scale and real world data.\nStrong coding skills in Python and C++.',
#  'PhD in NLP, Machine Learning, Statistics, Forecasting, Optimization, Reinforcement Learning or related field with experience building production systems or have…',
#  'Curate and build the data pipelines, working through integration of the models.\nMasters or Ph.D. in Computer Science or relevant field.',
#  'Five years of experience in study design, data mining, data modeling and statistical methodologies.\nPerforms project conceptualization, design, methodology,…',
#  'Collaborates with machine learning, data science, and simulation engineers to deliver the best data processing experience.\nUp to a 30% discretionary bonus.',
#  'Working experiences and deep understanding of large scale software, object-oriented design, performance optimization, and multi-threading on mobile platforms.',
#  'The individual builds use cases, business requirements and technical specifications that ensure the business receives the right data sets for analytics,…',
#  'HireArt is helping Toyota Research Institute (TRI) find a Machine Learning Data Engineer to contribute to state-of-the-art machine learning data infrastructure…',
#  'Mine and analyze internal data sets and reports to help stakeholders develop action plans and / or draw conclusions.\nExperience with Salesforce.com a plus.',
#  'Employees in this class are subject to extended periods of sitting, standing and walking, vision to monitor and moderate noise levels.',
#  '5+ years experience hiring & leading a team of software development / machine learning engineers.\nProvide technical guidance, build, manage and inspire your…',
#  'Foundation in data science, machine learning, and analytics, including statistical data analysis and A/B testing.',
#  'Working in a social health, mental health, behavioral health or primary care field.\nPassionate about digital health and driving operational efficiency.',
#  'Practical experience and knowledge in various machine learning algorithms, from linear and logistic regression to deep neural networks and reinforcement…',
#  'Designing, creating, and maintaining data pipelines that populate a petabyte scale data warehouse.\nExperience required in building batch data processing…',
#  'Solid understanding of computer science algorithms, data structures, and object-oriented programming.\nWe’re looking for the right person who can collaborate…',
#  'Proven experience in building data visualization applications with web technologies and RESTful APIs (HTML, CSS, JS).',
#  'You will collaborate with data scientists to design statistical and machine learning workflows on massive data and use acquired insights to propose and develop…',
#  'Well published in data science, bioinformatics, machine learning or other relevant fields.\nMulti-dimensional genomics/proteomic data analysis, visualization,…',
#  'You will contribute in the decision making process in regards to MLOps processes and the technology roadmap.\n3+ years ML experiences in production.',
#  'You will work on implementing and improving tools, automation and processes around how we build, test and deliver Siri!',
#  'The ability to serve as a subject matter expert (SME) regarding threats and vulnerabilities.\nThis is an exciting opportunity to work for a global leader in life…',
#  'Collaborate with fellow data scientists and SW engineers to build out various parts of our AI/ML infrastructure, services, and solutions, and effectively…',
#  'You will join a dynamic and multi-disciplinary group of physicians, neuroscientists, and data scientists developing cutting-edge technologies and applications…',
#  'Because the European Union Commission has determined that United States data privacy laws do not ensure an adequate level of protection for personal data…',
#  'Mine and analyze internal data sets and reports to help stakeholders develop action plans and / or draw conclusions.\nExperience with Salesforce.com a plus.',
#  'Strong passion for applied empirical analytics, data mining, and predictive analytics to develop impactful insights.',
#  'MS in CS or related field with focus on machine/deep learning, computer vision, computer graphics, robotics or similar and 2+ years of relevant industry…',
#  'Foundation in data science, machine learning, and analytics, including statistical data analysis and A/B testing.',
#  ...]

# %%
summaries12_noreturn = [word.replace('\n',' ') for word in summaries12]

# %%
job_list_max2_df = pd.DataFrame(list(zip(jobs12, companies12, locations12, summaries12_noreturn)),
               columns = ['job_title', 'company_name', 'location', 'summary'])
job_list_max2_df
# Out:
#                                             job_title  \
# 0                                      Data Scientist
# 1                                      Data Scientist
# 2                                      Data Scientist
# 3              Data Annotation Specialist (part-time)
# 4                    Data Scientist, Machine Learning
# ...                                               ...
# 1048   Senior Data Science Engineer, PySpark (REMOTE)
# 1049  Apple Cloud-Sr. Software Engineer / ML Engineer
# 1050          Senior Software Engineer, Data Platform
# 1051                                  Data Engineer 3
# 1052    Sr. Stat Programming Analyst (JO-2108-130260)
#
#                            company_name  \
# 0                                   EOS
# 1                                TikTok
# 2     Environmental Risk Management Inc
# 3                       Steady Platform
# 4                               Discord
# ...                                 ...
# 1048                        CyberCoders
# 1049                              Apple
# 1050                     TuSimple, Inc.
# 1051                    Acara Solutions
# 1052         Ultimate Staffing Services
#
#                                           location  \
# 0                                      Fremont, CA
# 1                                Mountain View, CA
# 2      Sunnyvale, CA+1 location•Temporarily Remote
# 3                           Playa Vista, CA•Remote
# 4                                San Francisco, CA
# ...                                            ...
# 1048  San Jose, CA 95128 (Willow Glen area)•Remote
# 1049                  Santa Clara Valley, CA 95014
# 1050          San Francisco, CA•Temporarily Remote
# 1051                               Santa Clara, CA
# 1052                       Irvine, CA 92614•Remote
#
#                                                 summary
# 0     Experience with data visualization libraries s...
# 1     Lead data-driven projects from definition to e...
# 2     Responsible for managing and developing the co...
# 3     We are looking for detail-oriented individuals...
# 4     If you're passionate about data, impact, and w...
# ...                                                 ...
# 1048  Apply advanced data mining and machine learnin...
# 1049  We’re looking for hardworking data scientists,...
# 1050  Collaborates with machine learning, data scien...
# 1051  Develops technical tools and programming that ...
# 1052  The ability to serve as a subject matter exper...
#
# [1053 rows x 4 columns]

# %%
job_list_max2_df.to_csv('job_list_scientist.csv', index=False)
